# %% [markdown]
# <a href="https://colab.research.google.com/github/taliyameyswara/crypto-system/blob/main/HillcipherQuiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import random

option = 0

# Kamus Huruf ke Angka
substitusi = {
    'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 'L': 11, 'M': 12,
    'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25,
    'a': 26, 'b': 27, 'c': 28, 'd': 29, 'e': 30, 'f': 31, 'g': 32, 'h': 33, 'i': 34, 'j': 35, 'k': 36, 'l': 37, 'm': 38,
    'n': 39, 'o': 40, 'p': 41, 'q': 42, 'r': 43, 's': 44, 't': 45, 'u': 46, 'v': 47, 'w': 48, 'x': 49, 'y': 50, 'z': 51,
    ' ': 52, '.': 53, '?': 54, '!': 55, ',': 56}


# Membalik Variabel Substitusi menjadi "Angka : Huruf" || 0 : 'A' dst.
inverse_substitution = {angka: huruf for huruf, angka in substitusi.items()}


def encrypt(plain_text, key_matrix):
    # Convert Plain Text ke Huruf Besar
    plain_text = plain_text

    # Merubah karakter Spasi menjadi simbol "_"
    plain_text = plain_text.replace(" ", "_")

    # Menghilangkan karakter selain yang ada di variabel substitusi
    hasil = ""

    for i in plain_text:
        if i in substitusi:
            hasil += i

    plain_text = hasil

    # Jika panjang Plain Text tidak sekelipatan dengan besar matriks kita tambahkan huruf 'X'
    # Jika matriksnya 2x2, contoh : "BA MB AN G" maka akan dirubah menjadi "BA MB AN GX"
    # Jika matriksnya 3x3, contoh : "BAM BAN G" maka akan dirubah menjadi "BAM BAN GXX"
    if len(plain_text) % len(key_matrix) != 0:
        padding_length = len(key_matrix) - (len(plain_text) % len(key_matrix))
        plain_text += 'X' * padding_length

    # Tempat untuk menyimpan Cipher Text
    cipher_text = ''

    print('Plain Text Bersih : ', plain_text)
    print('Key Matrix : \n', key_matrix)

    # Looping Enkripsi
    for i in range(0, len(plain_text), len(key_matrix)):
        # Mengambil plaintext huruf ke i sampai i + len(key_matrix)
        block = plain_text[i:i+len(key_matrix)]

        # Konversi plaintext menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nPlaintext : ", block_vector)

        # Perkalian Vector, kemudian di modulokan 27. 26 dari alphabet 1 untuk karakter spasi.
        # encrypted_vector = np.dot(block_vector, key_matrix) % 27
        encrypted_vector = np.dot(key_matrix, block_vector) % 57
        print("Ciphertext : ", encrypted_vector)

        # Konversi Angka ke Huruf
        encrypted_block = ''.join([inverse_substitution[num]
                                  for num in encrypted_vector])
        print("Ciphertext : ", encrypted_block)

        # Cipher Text ditampung di variabel bernama cipher_text
        cipher_text += encrypted_block

    return cipher_text

# Fungsi untuk mencari modulo invers


def mod_inverse(a, m):
    for x in range(1, m):
        if (a * x) % m == 1:
            return x
    return None


def decrypt(cipher_text, key_matrix):

    # Convert Cipher Text ke Huruf Besar
    cipher_text = cipher_text

    # Mencari determinan dengan menggunakan numpy, kemudian angkanya di bulatkan.
    determinant = int(np.round(np.linalg.det(key_matrix)))
    print("\nDeterminan : ", determinant)

    determinant = determinant % 57
    print("K^-1 : ", determinant)

    # Mencari modulo invers dari determinan
    modulo_inverse = mod_inverse(determinant, 57)

    print("Invers Modulo : ", modulo_inverse)

    if modulo_inverse is None:
        return "Determinan tidak memiliki invers modulo 57"
    else:
        # Membuat variabel penampung baru, besarnya sama seperti key_matrix.
        # Jika key_matrix berukuran 3x3, maka adjoint_matrix akan berukuran 3x3 juga.
        adjoint_matrix = np.zeros_like(key_matrix, dtype=np.int64)

        # key_matrix.shape isinya yaitu ukuran matriks.
        # Jika key_matrix berukuran 3x3, maka key_matrix.shape akan bernilai [3,3]
        for i in range(key_matrix.shape[0]):
            for j in range(key_matrix.shape[1]):
                # Axis 0 artinya baris, Axis 1 artinya kolom.
                # Untuk mendapatkan sub_matrix, kita menghapus baris dan kolom pada matriks itu.
                # Contoh : 2 1 1 | Misal pada posisi pertama i = 0 ; j = 0, kita akan menghapus
                #          3 5 2 | baris dan kolom "2" menyisakan | 5 2 | sebagai sub_matrix nya.
                #          3 3 3 |                                | 3 3 |
                sub_matrix = np.delete(
                    np.delete(key_matrix, i, axis=0), j, axis=1)
                # Kemudian, mencari determinan dari sub_matrix tersebut.
                cofactor = int(np.round(np.linalg.det(sub_matrix)))
                # Melihat apakah i+j ganjil/genap. Jika i+j ganjil, maka angka didepan menjadi "1"
                # Jika i+j genap, maka angka didepan menjadi "-1"
                adjoint_matrix[j, i] = ((-1) ** (i + j)) * cofactor

        # Mencari Kunci Matriks Invers dengan mengalikan adjoint_matrix dengan Modulo Invers dan di modulo 27.
        key_matrix_inv = (adjoint_matrix * modulo_inverse) % 57

    # Tempat untuk menyimpan Plain Text hasil dekripsi
    plain_text = ''

    # Looping Dekripsi
    for i in range(0, len(cipher_text), len(key_matrix)):
        # Mengambil Cipher Text huruf ke i sampai i + len(key_matrix)
        block = cipher_text[i:i+len(key_matrix)]

        # Konversi Cipher Text menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nCiphertext : ", block_vector)

        # Dekripsi dengan mengalikan matriks kunci invers dengan vektor ciphertext
        # decrypted_vector = np.dot(block_vector, key_matrix_inv) % 27
        decrypted_vector = np.dot(key_matrix_inv, block_vector) % 57
        print("Plaintext : ", decrypted_vector)

        # Konversi vektor hasil dekripsi menjadi huruf
        decrypted_block = ''.join([inverse_substitution[num]
                                  for num in decrypted_vector])
        print("Plaintext : ", decrypted_block)

        # Plain Text ditampung di variabel bernama plain_text
        plain_text += decrypted_block

    # Mengreplace karakter "_" dengan spasi " ".
    return plain_text.replace('_', ' ')


def buatkeymatrix(string_input):
    # Menghitung panjang string
    panjang_string = len(string_input)

    # Menghitung ukuran matriks m x m
    m = int(math.sqrt(panjang_string))

    # Memastikan bahwa panjang string sesuai dengan ukuran matriks m x m
    if m * m != panjang_string:
        print("Panjang string tidak cocok dengan ukuran matriks m x m.")
        return
    else:
        # Membuat matriks m x m dengan huruf dari string input
        key_matrix = np.array([substitusi[text]
                              for text in string_input]).reshape(m, m)

        return key_matrix


def generatekey(panjang):
    randomtext = []
    # Mengulang berdasarkan panjang yang diinginkan
    for i in range(panjang):
        # Menghasilkan angka acak dari 0-26, kemudian disimpan kedalam array.
        randomtext.append(random.randint(0, 56))
    # Mengubah angka menjadi huruf sesuai substitusi.
    randomtext_array = np.array(
        [inverse_substitution[text] for text in randomtext])
    # Mengabungkan array menjadi satu string utuh.
    result = ''.join(randomtext_array)

    return result


def cekrekomendasi(kunci):
    result = ""
    cek = 0

    # Looping berdasarkan panjang kunci.
    for i in range(len(kunci)):
        # Looping mencoba kombinasi huruf sebanyak 10000 kali.
        for j in range(10000):
            # Menghasilkan huruf untuk mengreplace bagian belakang.
            huruf = generatekey(i+1)
            # Menghapus string belakang yang kemudian di replace oleh huruf random.
            text = kunci[0:len(kunci)-i-1] + huruf
            # Mengubah text menjadi matriks m x m
            text_vector = np.array([substitusi[huruf] for huruf in text]).reshape(
                int(math.sqrt(len(text))), int(math.sqrt(len(text))))
            # Mencari Determinan
            determinant = int(np.round(np.linalg.det(text_vector)))
            # Mencari Modulo Invers
            modulo_inverse = mod_inverse(determinant, 57)
            # Jika Modulo Invers Ditemukan, return result. cek = 1 untuk keluar dari looping.
            if modulo_inverse is not None:
                result = text
                cek = 1
            if cek == 1:
                break
        if cek == 1:
            break
    return result


while (option != "1" or option != "2" or option != "3"):
    option = input(
        '\nHill Cipher\n1. Encrypt\n2. Decrypt\n3. Cek Kunci\n4. Exit\nInput : ')

    if (option == "1"):
        plain_text = input('Insert Plain Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci.replace(' ', '_')
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        cipher_text = encrypt(plain_text, key_matrix)
        print("\nCipher Text : ", cipher_text)
    elif (option == "2"):
        cipher_text = input('Insert Cipher Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci.replace(' ', '_')
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        plain_text_decrypted = decrypt(cipher_text, key_matrix)
        print("\nPlain Text : ", plain_text_decrypted)
    elif (option == "3"):
        kunci = input('Insert Kunci : ')
        kunci = kunci.replace(' ', '_')
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        determinant = int(np.round(np.linalg.det(key_matrix)))
        result = mod_inverse(determinant, 57)
        if result is not None:
            kunciditemukan = 1
            print('Modulo Invers dari {kunci} adalah ', result)
        else:
            rekomendasi = cekrekomendasi(kunci)
            print('Kunci Tersebut Tidak Memiliki Modulo Invers.')
            print('Rekomendasi : ', rekomendasi)
    elif (option == "4"):
        exit()
# Out:
# Plain Text Bersih :  MengenalSejarahdanSpesifikasiCN235VIVAnewsDuniadirgantaraIndonesiakembalidilirikberkatpesawatCN235.PesawatbuatanPTDirgantaraIndonesiadiharapkanbisamenjadimotorpembuatanpesawatdalamnegeri.Apalagi,pesawatCN235sudahmenduniadandibeliberbagainegara,antaralainKoreaSelatandanSpanyol.CN235merupakanpesawatangkutturbopropbermesindua,yangmasukkategorikelasmenengah.Pesawatturbopropmerupakanpesawatterbangdenganturbingasyangterhubungkebalingbaling,untukmenggerakkanpesawat.MemilikinamasandiTetukonamalainGatotkaca,CN235merupakanpesawathasilkerjasamaIndustriPesawatTerbangNusantaracikalbakalPTDIdenganCASAdariSpanyol.Pesawatinisebenarnyataklagiberusiamuda.Sebab,CN235telahmelakukanterbangperdanasejak30Desember1983,kemudiandiperkenalkanpada1Maret1988olehMerpatiNusantara.VarianpertamayangdibuatadalahCN23510,yangmenggunakanmesinGECT77A.Pesawatinipunkemudianmemilikisejumlahvariasi.AntaralainCN235330PhoenixyangdigunakanAngkatanUdaraAustraliadanCN235100yangdigunakanAngkatanUdaraSpanyol.Secaraumum,spesifikasiyangdikenaladalahCN235100110,yangmemilikikapasitas45penumpangdan2kursipilot.Pesawatinimemilikidimensipanjang21,4meter,bentangsayap25,81meter,tinggi8,18meter,danareasayap59.1meterpersegi.Beratnyamencapai9.800kgdalamkeadaankosong,dan15.500dalamkeadaanisi.DenganmenggunakanduamesintenagapenggerakGECT79Cturboprop,denganmasingmasing1,395kW,pesawatinimampumenempuhkecepatanmaksimum509kmperjam.Jarakyangmampuditempuhsekitar796km.Pesawatiniseringdigunakansebagaipesawatangkut.WakilKetuaKomisiIDPRdariFraksiPDIPerjuangan,TubagusHasanuddin,mengatakanCN235jugakerapdigunakanuntukmengangkutpasukan.Untukmengangkutpasukansampai2peleton.Bisajugadipakaiuntukmenerjunkanpasukan.Pesawatserbagunalah.Landasannyajugacukuppendek,ujarnya.CN235itutermasukpesawatyangbandel.SetahusayasampaisekarangbaikdiSpanyolmaupundiIndonesiabelumadaCN235yangjatuh,kataTubagus,yangjugabekasSekretarisMiliterdierapemerintahanPresidenMegawatiSoekarnoputriini.XXXXXXXX
# Key Matrix :
#  [[45 26 37 34 50 26 38 30 50]
#  [44 48 26 43 26 45 26 37 34]
#  [50 26 38 30 50 44 48 26 43]
#  [26 45 26 37 34 50 26 38 30]
#  [50 44 48 26 43 26 45 26 37]
#  [34 50 26 38 30 50 44 48 26]
#  [43 26 45 26 37 34 50 26 38]
#  [30 50 44 48 26 43 26 45 26]
#  [37 34 50 26 38 30 50 44 48]]
#
# Plaintext :  [12 30 39 32 30 39 26 37 18]
# Ciphertext :  [50 36 39  5 11 58 19 60 30]
# Ciphertext :  yknFL6T8e
#
# Plaintext :  [30 35 26 43 26 33 29 26 39]
# Ciphertext :  [21  8 63 18 19 60 63 37 40]
# Ciphertext :  VI.ST8.lo
#
# Plaintext :  [18 41 30 44 34 31 34 36 26]
# Ciphertext :  [ 7 24 54  7 63 60 19 29  1]
# Ciphertext :  HY2H.8TdB
#
# Plaintext :  [44 34  2 13 54 55 57 21  8]
# Ciphertext :  [53  3 35 62 33 44 52 19 27]
# Ciphertext :  1Dj hs0Tb
#
# Plaintext :  [21  0 39 30 48 44  3 46 39]
# Ciphertext :  [11 48 65 51 36 13 24 38 44]
# Ciphertext :  Lw!zkNYms
#
# Plaintext :  [34 26 29 34 43 32 26 39 45]
# Ciphertext :  [33 45 59 50 59 54 42  0 52]
# Ciphertext :  ht7y72qA0
#
# Plaintext :  [26 43 26  8 39 29 40 39 30]
# Ciphertext :  [31  0 41 66 15 58 13 43 50]
# Ciphertext :  fAp,P6Nry
#
# Plaintext :  [44 34 26 36 30 38 27 26 37]
# Ciphertext :  [ 5 15 28 17 28 48 63 18 46]
# Ciphertext :  FPcRcw.Su
#
# Plaintext :  [34 29 34 37 34 43 34 36 27]
# Ciphertext :  [17 60 50 23 24 66 35 23  8]
# Ciphertext :  R8yXY,jXI
#
# Plaintext :  [30 43 36 26 45 41 30 44 26]
# Ciphertext :  [35 20 60 35 59  6  5 57  9]
# Ciphertext :  jU8j7GF5J
#
# Plaintext :  [48 26 45  2 13 54 55 57 63]
# Ciphertext :  [39  0 30 29  4 59 25 44 15]
# Ciphertext :  nAedE7ZsP
#
# Plaintext :  [15 30 44 26 48 26 45 27 46]
# Ciphertext :  [ 4 61 38 36 34 31 51 26 38]
# Ciphertext :  E9mkifzam
#
# Plaintext :  [26 45 26 39 15 19  3 34 43]
# Ciphertext :  [44 52 46 29 45 60 33 63  8]
# Ciphertext :  s0udt8h.I
#
# Plaintext :  [32 26 39 45 26 43 26  8 39]
# Ciphertext :  [32 62 43 16 56 65  6 58  2]
# Ciphertext :  g rQ4!G6C
#
# Plaintext :  [29 40 39 30 44 34 26 29 34]
# Ciphertext :  [60 24 39 19 28 56 31 40  3]
# Ciphertext :  8YnTc4foD
#
# Plaintext :  [33 26 43 26 41 36 26 39 27]
# Ciphertext :  [ 8  6  5 19 26 20  0 55 22]
# Ciphertext :  IGFTaUA3W
#
# Plaintext :  [34 44 26 38 30 39 35 26 29]
# Ciphertext :  [14 55 66 31 43  9  8 22 47]
# Ciphertext :  O3,frJIWv
#
# Plaintext :  [34 38 40 45 40 43 41 30 38]
# Ciphertext :  [ 6  8 30 28 65 55 40  1 56]
# Ciphertext :  GIec!3oB4
#
# Plaintext :  [27 46 26 45 26 39 41 30 44]
# Ciphertext :  [16 50 11 16 50 59 30 66 10]
# Ciphertext :  QyLQy7e,K
#
# Plaintext :  [26 48 26 45 29 26 37 26 38]
# Ciphertext :  [ 0 10 42 34 43 46 47 19 39]
# Ciphertext :  AKqiruvTn
#
# Plaintext :  [39 30 32 30 43 34 63  0 41]
# Ciphertext :  [23 37 13 18  8 35  5 15 19]
# Ciphertext :  XlNSIjFPT
#
# Plaintext :  [26 37 26 32 34 66 41 30 44]
# Ciphertext :  [62 36 54 56 44  1 26 63 41]
# Ciphertext :   k24sBa.p
#
# Plaintext :  [26 48 26 45  2 13 54 55 57]
# Ciphertext :  [41 13 38 44 29 14 61 61 53]
# Ciphertext :  pNmsdO991
#
# Plaintext :  [44 46 29 26 33 38 30 39 29]
# Ciphertext :  [ 7  1 40 29  9 46  9 66 59]
# Ciphertext :  HBodJuJ,7
#
# Plaintext :  [46 39 34 26 29 26 39 29 34]
# Ciphertext :  [14 10  8 35 21 24 29 27 17]
# Ciphertext :  OKIjVYdbR
#
# Plaintext :  [27 30 37 34 27 30 43 27 26]
# Ciphertext :  [ 9 55 55 33 16 59 31 52  9]
# Ciphertext :  J33hQ7f0J
#
# Plaintext :  [32 26 34 39 30 32 26 43 26]
# Ciphertext :  [24  2  8 56 42 16 16 16 66]
# Ciphertext :  YCI4qQQQ,
#
# Plaintext :  [66 26 39 45 26 43 26 37 26]
# Ciphertext :  [40 45 62  4 19 64 53 35 36]
# Ciphertext :  ot ET?1jk
#
# Plaintext :  [34 39 10 40 43 30 26 18 30]
# Ciphertext :  [48 61 50 20 62 12 38 21  6]
# Ciphertext :  w9yU MmVG
#
# Plaintext :  [37 26 45 26 39 29 26 39 18]
# Ciphertext :  [66 30 22 23 56 33 10 11 21]
# Ciphertext :  ,eWX4hKLV
#
# Plaintext :  [41 26 39 50 40 37 63  2 13]
# Ciphertext :  [ 5 20 40 29 21  5  2 20 16]
# Ciphertext :  FUodVFCUQ
#
# Plaintext :  [54 55 57 38 30 43 46 41 26]
# Ciphertext :  [20 39 11  4  7 21 27 40 11]
# Ciphertext :  UnLEHVboL
#
# Plaintext :  [36 26 39 41 30 44 26 48 26]
# Ciphertext :  [48 47 44 15 38 59 65 54 24]
# Ciphertext :  wvsPm7!2Y
#
# Plaintext :  [45 26 39 32 36 46 45 45 46]
# Ciphertext :  [54 25 28 61  4 41 63  8 45]
# Ciphertext :  2Zc9Ep.It
#
# Plaintext :  [43 27 40 41 43 40 41 27 30]
# Ciphertext :  [40  1  5 21  6 51 66  6 22]
# Ciphertext :  oBFVGz,GW
#
# Plaintext :  [43 38 30 44 34 39 29 46 26]
# Ciphertext :  [32 39 57 33 17 13 25 20 48]
# Ciphertext :  gn5hRNZUw
#
# Plaintext :  [66 50 26 39 32 38 26 44 46]
# Ciphertext :  [19 64 62  4  5 10 59 12 52]
# Ciphertext :  T? EFK7M0
#
# Plaintext :  [36 36 26 45 30 32 40 43 34]
# Ciphertext :  [31  4 20 22 40 22 42  5 54]
# Ciphertext :  fEUWoWqF2
#
# Plaintext :  [36 30 37 26 44 38 30 39 30]
# Ciphertext :  [60 12 54 48  0  7 54 25 18]
# Ciphertext :  8M2wAH2ZS
#
# Plaintext :  [39 32 26 33 63 15 30 44 26]
# Ciphertext :  [45 31 11 23 26 13 22 28 23]
# Ciphertext :  tfLXaNWcX
#
# Plaintext :  [48 26 45 45 46 43 27 40 41]
# Ciphertext :  [57 40 22 24  7 49 49 26 59]
# Ciphertext :  5oWYHxxa7
#
# Plaintext :  [43 40 41 38 30 43 46 41 26]
# Ciphertext :  [17 27  4 34 39 22 52 65 36]
# Ciphertext :  RbEinW0!k
#
# Plaintext :  [36 26 39 41 30 44 26 48 26]
# Ciphertext :  [48 47 44 15 38 59 65 54 24]
# Ciphertext :  wvsPm7!2Y
#
# Plaintext :  [45 45 30 43 27 26 39 32 29]
# Ciphertext :  [27 33 34 30 24 49 17 19 41]
# Ciphertext :  bhieYxRTp
#
# Plaintext :  [30 39 32 26 39 45 46 43 27]
# Ciphertext :  [14 27 63 21  0  2 45 27 34]
# Ciphertext :  Ob.VACtbi
#
# Plaintext :  [34 39 32 26 44 50 26 39 32]
# Ciphertext :  [11 60 18 23 61 65 60 56 55]
# Ciphertext :  L8SX9!843
#
# Plaintext :  [45 30 43 33 46 27 46 39 32]
# Ciphertext :  [40 35  5 21 40 63 62  4  1]
# Ciphertext :  ojFVo. EB
#
# Plaintext :  [36 30 27 26 37 34 39 32 27]
# Ciphertext :  [22  0  6 32 31 56 33 10  1]
# Ciphertext :  WAGgf4hKB
#
# Plaintext :  [26 37 34 39 32 66 46 39 45]
# Ciphertext :  [ 1 52 47 19 15 21 11 54 35]
# Ciphertext :  B0vTPVL2j
#
# Plaintext :  [46 36 38 30 39 32 32 30 43]
# Ciphertext :  [18 29 38 47 11 34 23 56 34]
# Ciphertext :  SdmvLiX4i
#
# Plaintext :  [26 36 36 26 39 41 30 44 26]
# Ciphertext :  [43 22 48 15 30 10 32 34 65]
# Ciphertext :  rWwPeKgi!
#
# Plaintext :  [48 26 45 63 12 30 38 34 37]
# Ciphertext :  [ 9 10 31 28  5 26 64 29 11]
# Ciphertext :  JKfcFa?dL
#
# Plaintext :  [34 36 34 39 26 38 26 44 26]
# Ciphertext :  [25 36 56 23 56  8 42 38 16]
# Ciphertext :  Zk4X4IqmQ
#
# Plaintext :  [39 29 34 19 30 45 46 36 40]
# Ciphertext :  [52 45 46 19 37 63 59  8 53]
# Ciphertext :  0tuTl.7I1
#
# Plaintext :  [39 26 38 26 37 26 34 39  6]
# Ciphertext :  [26 18 28 59 41 17 18 14  6]
# Ciphertext :  aSc7pRSOG
#
# Plaintext :  [26 45 40 45 36 26 28 26 66]
# Ciphertext :  [39 58 10 35 41 65 65 22 55]
# Ciphertext :  n6Kjp!!W3
#
# Plaintext :  [ 2 13 54 55 57 38 30 43 46]
# Ciphertext :  [ 0 17 66 50 42  7 58 23 18]
# Ciphertext :  AR,yqH6XS
#
# Plaintext :  [41 26 36 26 39 41 30 44 26]
# Ciphertext :  [56  1  2 22  5 20 15 51 12]
# Ciphertext :  4BCWFUPzM
#
# Plaintext :  [48 26 45 33 26 44 34 37 36]
# Ciphertext :  [ 8 22 22  7 52 15 51 29  0]
# Ciphertext :  IWWH0PzdA
#
# Plaintext :  [30 43 35 26 44 26 38 26  8]
# Ciphertext :  [30 32 62 18 10 29  1 14 24]
# Ciphertext :  eg SKdBOY
#
# Plaintext :  [39 29 46 44 45 43 34 15 30]
# Ciphertext :  [56 35 27 55 65 13  9 54 10]
# Ciphertext :  4jb3!NJ2K
#
# Plaintext :  [44 26 48 26 45 19 30 43 27]
# Ciphertext :  [48 10 24 44 26 28 36 61 27]
# Ciphertext :  wKYsack9b
#
# Plaintext :  [26 39 32 13 46 44 26 39 45]
# Ciphertext :  [ 4 43 25 28  2  0 10 61  8]
# Ciphertext :  ErZcCAK9I
#
# Plaintext :  [26 43 26 28 34 36 26 37 27]
# Ciphertext :  [35 36 47 54 44 27 55 39 60]
# Ciphertext :  jkv2sb3n8
#
# Plaintext :  [26 36 26 37 15 19  3  8 29]
# Ciphertext :  [ 4 39 15 18 11 66 13 60 45]
# Ciphertext :  EnPSL,N8t
#
# Plaintext :  [30 39 32 26 39  2  0 18  0]
# Ciphertext :  [ 6 11 48  7 54 23 34 46 11]
# Ciphertext :  GLwH2XiuL
#
# Plaintext :  [29 26 43 34 18 41 26 39 50]
# Ciphertext :  [29 47 37 34 26 11 28 65 60]
# Ciphertext :  dvliaLc!8
#
# Plaintext :  [40 37 63 15 30 44 26 48 26]
# Ciphertext :  [49 56 59  8 59 46 56 63 65]
# Ciphertext :  x47I7u4.!
#
# Plaintext :  [45 34 39 34 44 30 27 30 39]
# Ciphertext :  [36 62 45 59 16  5 60 39 39]
# Ciphertext :  k t7QF8nn
#
# Plaintext :  [26 43 39 50 26 45 26 36 37]
# Ciphertext :  [27 11 60 38  0 15 35 51  9]
# Ciphertext :  bL8mAPjzJ
#
# Plaintext :  [26 32 34 27 30 43 46 44 34]
# Ciphertext :  [40 30 45  2 63  2 33  2 20]
# Ciphertext :  oetC.ChCU
#
# Plaintext :  [26 38 46 29 26 63 18 30 27]
# Ciphertext :  [65 28 58 52 23 20 20  8 44]
# Ciphertext :  !c60XUUIs
#
# Plaintext :  [26 27 66  2 13 54 55 57 45]
# Ciphertext :  [24 19 52 44 27 42 36 24 24]
# Ciphertext :  YT0sbqkYY
#
# Plaintext :  [30 37 26 33 38 30 37 26 36]
# Ciphertext :  [ 7 24  2 47 65 63 14 37  1]
# Ciphertext :  HYCv!.OlB
#
# Plaintext :  [46 36 26 39 45 30 43 27 26]
# Ciphertext :  [ 8 35 51 35 65 42 32  7 41]
# Ciphertext :  Ijzj!qgHp
#
# Plaintext :  [39 32 41 30 43 29 26 39 26]
# Ciphertext :  [29 46 53 28 63 40 25 29  2]
# Ciphertext :  du1c.oZdC
#
# Plaintext :  [44 30 35 26 36 55 52  3 30]
# Ciphertext :  [10 42 42 53 54 10 17 54  3]
# Ciphertext :  Kqq12KR2D
#
# Plaintext :  [44 30 38 27 30 43 53 61 60]
# Ciphertext :  [ 7 46 60 15 39  6 35 30 15]
# Ciphertext :  Hu8PnGjeP
#
# Plaintext :  [55 66 36 30 38 46 29 34 26]
# Ciphertext :  [63 33 49  0  6 66 43 31  8]
# Ciphertext :  .hxAG,rfI
#
# Plaintext :  [39 29 34 41 30 43 36 30 39]
# Ciphertext :  [ 4 50  6 14 48 45  3 20 21]
# Ciphertext :  EyGOwtDUV
#
# Plaintext :  [26 37 36 26 39 41 26 29 26]
# Ciphertext :  [ 3 14 28 56 40 35  4 42 43]
# Ciphertext :  DOc4ojEqr
#
# Plaintext :  [53 12 26 43 30 45 53 61 60]
# Ciphertext :  [29 44 20 20 58  9 32 61 14]
# Ciphertext :  dsUU6Jg9O
#
# Plaintext :  [60 40 37 30 33 12 30 43 41]
# Ciphertext :  [42 49 48 11 34 55 11 30 52]
# Ciphertext :  qxwLi3Le0
#
# Plaintext :  [26 45 34 13 46 44 26 39 45]
# Ciphertext :  [33 48 56 15 27 17 55 47 44]
# Ciphertext :  hw4PbR3vs
#
# Plaintext :  [26 43 26 63 21 26 43 34 26]
# Ciphertext :  [17 45 32 35 48 40  7 26 42]
# Ciphertext :  RtgjwoHaq
#
# Plaintext :  [39 41 30 43 45 26 38 26 50]
# Ciphertext :  [45 42 23 12 27 64 42 22 56]
# Ciphertext :  tqXMb?qW4
#
# Plaintext :  [26 39 32 29 34 27 46 26 45]
# Ciphertext :  [10 28 47 58 22 56 66 56 20]
# Ciphertext :  Kcv6W4,4U
#
# Plaintext :  [26 29 26 37 26 33  2 13 54]
# Ciphertext :  [21 20 12 16  9 51  2 40  5]
# Ciphertext :  VUMQJzCoF
#
# Plaintext :  [55 57 53 52 66 50 26 39 32]
# Ciphertext :  [31 64 60 17 44 54 47 42 53]
# Ciphertext :  f?8Rs2vq1
#
# Plaintext :  [38 30 39 32 32 46 39 26 36]
# Ciphertext :  [20 13 45 18 65 55 18 30 30]
# Ciphertext :  UNtS!3See
#
# Plaintext :  [26 39 38 30 44 34 39  6  4]
# Ciphertext :  [42 27 35 42  3 40 16 54 16]
# Ciphertext :  qbjqDoQ2Q
#
# Plaintext :  [ 2 19 59 59  0 63 15 30 44]
# Ciphertext :  [31 48 50 38 40 66 63 38 20]
# Ciphertext :  fwymo,.mU
#
# Plaintext :  [26 48 26 45 34 39 34 41 46]
# Ciphertext :  [51  0 47 45  8 34 12 39 39]
# Ciphertext :  zAvtIiMnn
#
# Plaintext :  [39 36 30 38 46 29 34 26 39]
# Ciphertext :  [42  7 64 22 15 12 40 34 27]
# Ciphertext :  qH?WPMoib
#
# Plaintext :  [38 30 38 34 37 34 36 34 44]
# Ciphertext :  [46 19 63 35  6 48 30 52 46]
# Ciphertext :  uT.jGwe0u
#
# Plaintext :  [30 35 46 38 37 26 33 47 26]
# Ciphertext :  [19 53 22 18 45 10 48 33 10]
# Ciphertext :  T1WStKwhK
#
# Plaintext :  [43 34 26 44 34 63  0 39 45]
# Ciphertext :  [42 54 33 30 25 59 49 34 55]
# Ciphertext :  q2heZ7xi3
#
# Plaintext :  [26 43 26 37 26 34 39  2 13]
# Ciphertext :  [40 32 13 10 44 31  4 50 43]
# Ciphertext :  ogNKsfEyr
#
# Plaintext :  [54 55 57 55 55 52 15 33 40]
# Ciphertext :  [24 60  1 37  3 14  5 19 41]
# Ciphertext :  Y8BlDOFTp
#
# Plaintext :  [30 39 34 49 50 26 39 32 29]
# Ciphertext :  [28 45  7  9 12 60  1 63 43]
# Ciphertext :  ctHJM8B.r
#
# Plaintext :  [34 32 46 39 26 36 26 39  0]
# Ciphertext :  [ 2  2 10 23 49 42 29 49 24]
# Ciphertext :  CCKXxqdxY
#
# Plaintext :  [39 32 36 26 45 26 39 20 29]
# Ciphertext :  [ 5  1 37 44 63  9  5 39 61]
# Ciphertext :  FBls.JFn9
#
# Plaintext :  [26 43 26  0 46 44 45 43 26]
# Ciphertext :  [ 6 52 45 49  9 17 39 22 55]
# Ciphertext :  G0txJRnW3
#
# Plaintext :  [37 34 26 29 26 39  2 13 54]
# Ciphertext :  [61  0 46 62 57  1 65 25 18]
# Ciphertext :  9Au 5B!ZS
#
# Plaintext :  [55 57 53 52 52 50 26 39 32]
# Ciphertext :  [ 1 35 30 10 45 36 65 13 57]
# Ciphertext :  BjeKtk!N5
#
# Plaintext :  [29 34 32 46 39 26 36 26 39]
# Ciphertext :  [ 3  4 45 19 45 58 64 48 43]
# Ciphertext :  DEtTt6?wr
#
# Plaintext :  [ 0 39 32 36 26 45 26 39 20]
# Ciphertext :  [ 5 37 64 29 20 63 45 62 59]
# Ciphertext :  Fl?dU.t 7
#
# Plaintext :  [29 26 43 26 18 41 26 39 50]
# Ciphertext :  [25 38 65  6 19 42 21 16 53]
# Ciphertext :  Zm!GTqVQ1
#
# Plaintext :  [40 37 63 18 30 28 26 43 26]
# Ciphertext :  [54 17 52  0 60 58 63 31 46]
# Ciphertext :  2R0A86.fu
#
# Plaintext :  [46 38 46 38 66 44 41 30 44]
# Ciphertext :  [12 43 39 11 60 66 59 25 48]
# Ciphertext :  MrnL8,7Zw
#
# Plaintext :  [34 31 34 36 26 44 34 50 26]
# Ciphertext :  [31 32 37 21 28 48 58 45  9]
# Ciphertext :  fglVcw6tJ
#
# Plaintext :  [39 32 29 34 36 30 39 26 37]
# Ciphertext :  [51  0 36 51 37 21 27 62 10]
# Ciphertext :  zAkzlVb K
#
# Plaintext :  [26 29 26 37 26 33  2 13 54]
# Ciphertext :  [21 20 12 16  9 51  2 40  5]
# Ciphertext :  VUMQJzCoF
#
# Plaintext :  [55 57 53 52 52 53 53 52 66]
# Ciphertext :  [46 30 42 31 53  1 65 35 16]
# Ciphertext :  ueqf1B!jQ
#
# Plaintext :  [50 26 39 32 38 30 38 34 37]
# Ciphertext :  [56 22  5 63 62  9 36 18 34]
# Ciphertext :  4WF. JkSi
#
# Plaintext :  [34 36 34 36 26 41 26 44 34]
# Ciphertext :  [66 46 40 34 17 51 35 30 10]
# Ciphertext :  ,uoiRzjeK
#
# Plaintext :  [45 26 44 56 57 41 30 39 46]
# Ciphertext :  [19 25 21 54  6 46 10 46 17]
# Ciphertext :  TZV2GuKuR
#
# Plaintext :  [38 41 26 39 32 29 26 39 54]
# Ciphertext :  [15 25 55 12 17  2 30 60 11]
# Ciphertext :  PZ3MRCe8L
#
# Plaintext :  [36 46 43 44 34 41 34 37 40]
# Ciphertext :  [ 6 12 33 53 65 28 61 19 24]
# Ciphertext :  GMh1!c9TY
#
# Plaintext :  [45 63 15 30 44 26 48 26 45]
# Ciphertext :  [37  8 16 28 57 27 65 55 26]
# Ciphertext :  lIQc5b!3a
#
# Plaintext :  [34 39 34 38 30 38 34 37 34]
# Ciphertext :  [26 60 46 37  4 62 27 10 50]
# Ciphertext :  a8ulE bKy
#
# Plaintext :  [36 34 29 34 38 30 39 44 34]
# Ciphertext :  [56 44 42 55 16 61 43 52 21]
# Ciphertext :  4sq3Q9r0V
#
# Plaintext :  [41 26 39 35 26 39 32 54 53]
# Ciphertext :  [23 38 26 61 49 14 15 55  3]
# Ciphertext :  Xma9xOP3D
#
# Plaintext :  [66 56 38 30 45 30 43 66 27]
# Ciphertext :  [39 61  0 65 55 39 23  0 40]
# Ciphertext :  n9A!3nXAo
#
# Plaintext :  [30 39 45 26 39 32 44 26 50]
# Ciphertext :  [51 15 34 36  2 54 51 22 14]
# Ciphertext :  zPikC2zWO
#
# Plaintext :  [26 41 54 57 66 60 53 38 30]
# Ciphertext :  [ 8 45  6 59 46  5 13 26 59]
# Ciphertext :  ItG7uFNa7
#
# Plaintext :  [45 30 43 66 45 34 39 32 32]
# Ciphertext :  [14 29 65 38  4 55 53 26 38]
# Ciphertext :  Od!mE31am
#
# Plaintext :  [34 60 66 53 60 38 30 45 30]
# Ciphertext :  [36 31 51 52  4 34 19 33 35]
# Ciphertext :  kfz0EiThj
#
# Plaintext :  [43 66 29 26 39 26 43 30 26]
# Ciphertext :  [ 8 34  7 11 20 51 66 62 10]
# Ciphertext :  IiHLUz, K
#
# Plaintext :  [44 26 50 26 41 57 61 63 53]
# Ciphertext :  [35 11  8 52 63 36 40 41 36]
# Ciphertext :  jLI0.kopk
#
# Plaintext :  [38 30 45 30 43 41 30 43 44]
# Ciphertext :  [23  7 26  5 39 39 32  3 22]
# Ciphertext :  XHaFnngDW
#
# Plaintext :  [30 32 34 63  1 30 43 26 45]
# Ciphertext :  [21 45 35 40 21 13 29  2  2]
# Ciphertext :  VtjoVNdCC
#
# Plaintext :  [39 50 26 38 30 39 28 26 41]
# Ciphertext :  [59 52 49  6 16 14 16 66 59]
# Ciphertext :  70xGQOQ,7
#
# Plaintext :  [26 34 61 63 60 52 52 36 32]
# Ciphertext :  [51  3  6 38  9  0 50 43 18]
# Ciphertext :  zDGmJAyrS
#
# Plaintext :  [29 26 37 26 38 36 30 26 29]
# Ciphertext :  [55 24 37 64 62 46 55 35 55]
# Ciphertext :  3Yl? u3j3
#
# Plaintext :  [26 26 39 36 40 44 40 39 32]
# Ciphertext :  [21 21 54 45 54 35 33 23 27]
# Ciphertext :  VV2t2jhXb
#
# Plaintext :  [66 29 26 39 53 57 63 57 52]
# Ciphertext :  [31 27 22 14 23  0  2 18 66]
# Ciphertext :  fbWOXACS,
#
# Plaintext :  [52 29 26 37 26 38 36 30 26]
# Ciphertext :  [48  7 57 24 30 22 23 13 10]
# Ciphertext :  wH5YeWXNK
#
# Plaintext :  [29 26 26 39 34 44 34 63  3]
# Ciphertext :  [60  3 63 47 21  1 62 34 42]
# Ciphertext :  8D.vVB iq
#
# Plaintext :  [30 39 32 26 39 38 30 39 32]
# Ciphertext :  [24 55 36 57 50 25 31 64 26]
# Ciphertext :  Y3k5yZf?a
#
# Plaintext :  [32 46 39 26 36 26 39 29 46]
# Ciphertext :  [31 48 10 44 11 14 13  1 25]
# Ciphertext :  fwKsLONBZ
#
# Plaintext :  [26 38 30 44 34 39 45 30 39]
# Ciphertext :  [45 26 51 57 19 44 38 13  5]
# Ciphertext :  taz5TsmNF
#
# Plaintext :  [26 32 26 41 30 39 32 32 30]
# Ciphertext :  [29 37 35 43 55 36 10 13 52]
# Ciphertext :  dljr3kKN0
#
# Plaintext :  [43 26 36  6  4  2 19 59 61]
# Ciphertext :  [25 33 16  7 65 20  6  7 62]
# Ciphertext :  ZhQH!UGH
#
# Plaintext :  [ 2 45 46 43 27 40 41 43 40]
# Ciphertext :  [ 4 20 30 24 57  2 34 64 45]
# Ciphertext :  EUeY5Ci?t
#
# Plaintext :  [41 66 29 30 39 32 26 39 38]
# Ciphertext :  [32 17 24 64 26 29 61 57  7]
# Ciphertext :  gRY?ad95H
#
# Plaintext :  [26 44 34 39 32 38 26 44 34]
# Ciphertext :  [37 27 39 16 26 55 30 26  1]
# Ciphertext :  lbnQa3eaB
#
# Plaintext :  [39 32 53 66 55 61 57 36 22]
# Ciphertext :  [64 63 11 31  5 39 65 51 26]
# Ciphertext :  ?.LfFn!za
#
# Plaintext :  [66 41 30 44 26 48 26 45 34]
# Ciphertext :  [29  8 48 63 51 44 24 52 18]
# Ciphertext :  dIw.zsY0S
#
# Plaintext :  [39 34 38 26 38 41 46 38 30]
# Ciphertext :  [22 50 49 53 17 23 48 33 62]
# Ciphertext :  Wyx1RXwh
#
# Plaintext :  [39 30 38 41 46 33 36 30 28]
# Ciphertext :  [34 62  4 11 37 27 43 13 35]
# Ciphertext :  i ELlbrNj
#
# Plaintext :  [30 41 26 45 26 39 38 26 36]
# Ciphertext :  [57 47 42  2 48 49  7 43 45]
# Ciphertext :  5vqCwxHrt
#
# Plaintext :  [44 34 38 46 38 57 52 61 36]
# Ciphertext :  [15 46  0 52 15 61 41 29 33]
# Ciphertext :  PuA0P9pdh
#
# Plaintext :  [38 41 30 43 35 26 38 63  9]
# Ciphertext :  [34 48 12 23 64 38 38 63 36]
# Ciphertext :  iwMX?mm.k
#
# Plaintext :  [26 43 26 36 50 26 39 32 38]
# Ciphertext :  [66  2  6  1  1 58 46  4 60]
# Ciphertext :  ,CGBB6uE8
#
# Plaintext :  [26 38 41 46 29 34 45 30 38]
# Ciphertext :  [23  9 16 34 16 47 58 21 18]
# Ciphertext :  XJQiQv6VS
#
# Plaintext :  [41 46 33 44 30 36 34 45 26]
# Ciphertext :  [ 9 66 27 24 27 57 55  9 25]
# Ciphertext :  J,bYb53JZ
#
# Plaintext :  [43 59 61 58 36 38 63 15 30]
# Ciphertext :  [23 57 39  2 40 44 66 28 34]
# Ciphertext :  X5nCos,ci
#
# Plaintext :  [44 26 48 26 45 34 39 34 44]
# Ciphertext :  [20 25  5 57 10 45  1 39  7]
# Ciphertext :  UZF5KtBnH
#
# Plaintext :  [30 43 34 39 32 29 34 32 46]
# Ciphertext :  [32 56  3  5 38 47 12 24 25]
# Ciphertext :  g4DFmvMYZ
#
# Plaintext :  [39 26 36 26 39 44 30 27 26]
# Ciphertext :  [ 3 22 61 10 10 23 58 25 17]
# Ciphertext :  DW9KKX6ZR
#
# Plaintext :  [32 26 34 41 30 44 26 48 26]
# Ciphertext :  [18  9 56 49  0 61  3 49 28]
# Ciphertext :  SJ4xA9Dxc
#
# Plaintext :  [45 26 39 32 36 46 45 63 22]
# Ciphertext :  [64  9  0 25 53 13 21 60 20]
# Ciphertext :  ?JAZ1NV8U
#
# Plaintext :  [26 36 34 37 10 30 45 46 26]
# Ciphertext :  [41 60 11 37 17 47 52 62 59]
# Ciphertext :  p8LlRv0 7
#
# Plaintext :  [10 40 38 34 44 34  8  3 15]
# Ciphertext :  [39  5 30 33 27 17 57 32 16]
# Ciphertext :  nFehbR5gQ
#
# Plaintext :  [17 29 26 43 34  5 43 26 36]
# Ciphertext :  [ 4 33 40 30 44 36 15 44 45]
# Ciphertext :  EhoeskPst
#
# Plaintext :  [44 34 15  3  8 15 30 43 35]
# Ciphertext :  [49 22 23 23 13  6 42 61 58]
# Ciphertext :  xWXXNGq96
#
# Plaintext :  [46 26 39 32 26 39 66 19 46]
# Ciphertext :  [38 16  4 27 46 39  6 59  1]
# Ciphertext :  mQEbunG7B
#
# Plaintext :  [27 26 32 46 44  7 26 44 26]
# Ciphertext :  [43 44 54  0 57 15 56 51 57]
# Ciphertext :  rs2A5P4z5
#
# Plaintext :  [39 46 29 29 34 39 66 38 30]
# Ciphertext :  [ 8 43 44 17 63 24 13 41 15]
# Ciphertext :  IrsR.YNpP
#
# Plaintext :  [39 32 26 45 26 36 26 39  2]
# Ciphertext :  [59 28 34 49 38 39 45 61 64]
# Ciphertext :  7cixmnt9?
#
# Plaintext :  [13 54 55 57 35 46 32 26 36]
# Ciphertext :  [41 45 55 34 31 12 28  2 63]
# Ciphertext :  pt3ifMcC.
#
# Plaintext :  [30 43 26 41 29 34 32 46 39]
# Ciphertext :  [46 41 64 21 57  8 29 33 27]
# Ciphertext :  up?V5Idhb
#
# Plaintext :  [26 36 26 39 46 39 45 46 36]
# Ciphertext :  [ 2 11 48  1 28 30 20 49 20]
# Ciphertext :  CLwBceUxU
#
# Plaintext :  [38 30 39 32 26 39 32 36 46]
# Ciphertext :  [ 5  3 59 29  7 24 49 34 28]
# Ciphertext :  FD7dHYxic
#
# Plaintext :  [45 41 26 44 46 36 26 39 63]
# Ciphertext :  [23 59  7  1  6 27 18  2 33]
# Ciphertext :  X7HBGbSCh
#
# Plaintext :  [20 39 45 46 36 38 30 39 32]
# Ciphertext :  [49 65 11 36 29 23 59 12 42]
# Ciphertext :  x!LkdX7Mq
#
# Plaintext :  [26 39 32 36 46 45 41 26 44]
# Ciphertext :  [ 4 14 26 58 55 63 11 49 29]
# Ciphertext :  EOa63.Lxd
#
# Plaintext :  [46 36 26 39 44 26 38 41 26]
# Ciphertext :  [17 16 16  2 57 63 40 41 48]
# Ciphertext :  RQQC5.opw
#
# Plaintext :  [34 54 41 30 37 30 45 40 39]
# Ciphertext :  [30  2  8 48 35 52 56  1 42]
# Ciphertext :  eCIwj04Bq
#
# Plaintext :  [63  1 34 44 26 35 46 32 26]
# Ciphertext :  [41 56 56 38  3 57 23 53  9]
# Ciphertext :  p44mD5X1J
#
# Plaintext :  [29 34 41 26 36 26 34 46 39]
# Ciphertext :  [30 55 61 52 57 46 57 53 36]
# Ciphertext :  e3905u51k
#
# Plaintext :  [45 46 36 38 30 39 30 43 35]
# Ciphertext :  [10 57 34 23 59 21 63  8 66]
# Ciphertext :  K5iX7V.I,
#
# Plaintext :  [46 39 36 26 39 41 26 44 46]
# Ciphertext :  [60 14 52 27 47 45 56 61 59]
# Ciphertext :  8O0bvt497
#
# Plaintext :  [36 26 39 63 15 30 44 26 48]
# Ciphertext :  [ 2 40 40 45 50 53 33 34 58]
# Ciphertext :  Cooty1hi6
#
# Plaintext :  [26 45 44 30 43 27 26 32 46]
# Ciphertext :  [28 38 43 51 32  8 47  4 35]
# Ciphertext :  cmrzgIvEj
#
# Plaintext :  [39 26 37 26 33 63 11 26 39]
# Ciphertext :  [65 55 55 37 28  5 45 60 39]
# Ciphertext :  !33lcFt8n
#
# Plaintext :  [29 26 44 26 39 39 50 26 35]
# Ciphertext :  [28 19 28 58 33 37 62 35 12]
# Ciphertext :  cTc6hl jM
#
# Plaintext :  [46 32 26 28 46 36 46 41 41]
# Ciphertext :  [15 35 12 38 52 10 29 58 50]
# Ciphertext :  PjMm0Kd6y
#
# Plaintext :  [30 39 29 30 36 66 46 35 26]
# Ciphertext :  [11 55 56 35 65 23 36 57 37]
# Ciphertext :  L34j!Xk5l
#
# Plaintext :  [43 39 50 26 63  2 13 54 55]
# Ciphertext :  [14 56  8 27 59 23  4 14  9]
# Ciphertext :  O4Ib7XEOJ
#
# Plaintext :  [57 34 45 46 45 30 43 38 26]
# Ciphertext :  [47 17 25 62 31 63 34 28 53]
# Ciphertext :  vRZ f.ic1
#
# Plaintext :  [44 46 36 41 30 44 26 48 26]
# Ciphertext :  [13  8 46 40 35 47 57 23 46]
# Ciphertext :  NIuojv5Xu
#
# Plaintext :  [45 50 26 39 32 27 26 39 29]
# Ciphertext :  [66 26 12 17 54  7 16 51 53]
# Ciphertext :  ,aMR2HQz1
#
# Plaintext :  [30 37 63 18 30 45 26 33 46]
# Ciphertext :  [ 9 49 29  6 13  5 41 63 36]
# Ciphertext :  JxdGNFp.k
#
# Plaintext :  [44 26 50 26 44 26 38 41 26]
# Ciphertext :  [46 49 44 45 63 27 34 47 27]
# Ciphertext :  uxst.bivb
#
# Plaintext :  [34 44 30 36 26 43 26 39 32]
# Ciphertext :  [62 29 35  6 25 21 59 63 27]
# Ciphertext :   djGZV7.b
#
# Plaintext :  [27 26 34 36 29 34 18 41 26]
# Ciphertext :  [ 5 38  7 66 48 24 39 20  7]
# Ciphertext :  FmH,wYnUH
#
# Plaintext :  [39 50 40 37 38 26 46 41 46]
# Ciphertext :  [46 50 39  4 43 31 11 15 35]
# Ciphertext :  uynErfLPj
#
# Plaintext :  [39 29 34  8 39 29 40 39 30]
# Ciphertext :  [12 41 28 49 31  8 32 18 53]
# Ciphertext :  MpcxfIgS1
#
# Plaintext :  [44 34 26 27 30 37 46 38 26]
# Ciphertext :  [ 4 13 63 53 59 45 36 23 62]
# Ciphertext :  EN.17tkX
#
# Plaintext :  [29 26  2 13 54 55 57 50 26]
# Ciphertext :  [ 2 41  2 16 16 56 34  4  0]
# Ciphertext :  CpCQQ4iEA
#
# Plaintext :  [39 32 35 26 45 46 33 66 36]
# Ciphertext :  [47 46 11  6 45 27 60  3 58]
# Ciphertext :  vuLGtb8D6
#
# Plaintext :  [26 45 26 19 46 27 26 32 46]
# Ciphertext :  [ 9 46 50 15 16 16  0 35 35]
# Ciphertext :  JuyPQQAjj
#
# Plaintext :  [44 66 50 26 39 32 35 46 32]
# Ciphertext :  [55  8  2 56 38 29 28 66 60]
# Ciphertext :  3IC4mdc,8
#
# Plaintext :  [26 27 30 36 26 44 18 30 36]
# Ciphertext :  [51 42 64 60 65 11 31 48 53]
# Ciphertext :  zq?8!Lfw1
#
# Plaintext :  [43 30 45 26 43 34 44 12 34]
# Ciphertext :  [37 24 21 64 60 49 22 44 22]
# Ciphertext :  lYV?8xWsW
#
# Plaintext :  [37 34 45 30 43 29 34 30 43]
# Ciphertext :  [18  8 33 10 60  2 45 21 11]
# Ciphertext :  SIhK8CtVL
#
# Plaintext :  [26 41 30 38 30 43 34 39 45]
# Ciphertext :  [42 38 23  2 22 16 61 17 53]
# Ciphertext :  qmXCWQ9R1
#
# Plaintext :  [26 33 26 39 15 43 30 44 34]
# Ciphertext :  [26 49 16 27 10 17 63  6  3]
# Ciphertext :  axQbKR.GD
#
# Plaintext :  [29 30 39 12 30 32 26 48 26]
# Ciphertext :  [13 20  8 15  4 61 46 12 60]
# Ciphertext :  NUIPE9uM8
#
# Plaintext :  [45 34 18 40 30 36 26 43 39]
# Ciphertext :  [ 8  1 18 27 16 13 49 57 52]
# Ciphertext :  IBSbQNx50
#
# Plaintext :  [40 41 46 45 43 34 34 39 34]
# Ciphertext :  [28 59 49 33 49 24 49  3 43]
# Ciphertext :  c7xhxYxDr
#
# Plaintext :  [63 23 23 23 23 23 23 23 23]
# Ciphertext :  [14 14 48 42 19  5 16 63 43]
# Ciphertext :  OOwqTFQ.r
#
# Cipher Text :  yknFL6T8eVI.ST8.loHY2H.8TdB1Dj hs0TbLw!zkNYmsht7y72qA0fAp,P6NryFPcRcw.SuR8yXY,jXIjU8j7GF5JnAedE7ZsPE9mkifzams0udt8h.Ig rQ4!G6C8YnTc4foDIGFTaUA3WO3,frJIWvGIec!3oB4QyLQy7e,KAKqiruvTnXlNSIjFPT k24sBa.ppNmsdO991HBodJuJ,7OKIjVYdbRJ33hQ7f0JYCI4qQQQ,ot ET?1jkw9yU MmVG,eWX4hKLVFUodVFCUQUnLEHVboLwvsPm7!2Y2Zc9Ep.ItoBFVGz,GWgn5hRNZUwT? EFK7M0fEUWoWqF28M2wAH2ZStfLXaNWcX5oWYHxxa7RbEinW0!kwvsPm7!2YbhieYxRTpOb.VACtbiL8SX9!843ojFVo. EBWAGgf4hKBB0vTPVL2jSdmvLiX4irWwPeKgi!JKfcFa?dLZk4X4IqmQ0tuTl.7I1aSc7pRSOGn6Kjp!!W3AR,yqH6XS4BCWFUPzMIWWH0PzdAeg SKdBOY4jb3!NJ2KwKYsack9bErZcCAK9Ijkv2sb3n8EnPSL,N8tGLwH2XiuLdvliaLc!8x47I7u4.!k t7QF8nnbL8mAPjzJoetC.ChCU!c60XUUIsYT0sbqkYYHYCv!.OlBIjzj!qgHpdu1c.oZdCKqq12KR2DHu8PnGjeP.hxAG,rfIEyGOwtDUVDOc4ojEqrdsUU6Jg9OqxwLi3Le0hw4PbR3vsRtgjwoHaqtqXMb?qW4Kcv6W4,4UVUMQJzCoFf?8Rs2vq1UNtS!3SeeqbjqDoQ2Qfwymo,.mUzAvtIiMnnqH?WPMoibuT.jGwe0uT1WStKwhKq2heZ7xi3ogNKsfEyrY8BlDOFTpctHJM8B.rCCKXxqdxYFBls.JFn9G0txJRnW39Au 5B!ZSBjeKtk!N5DEtTt6?wrFl?dU.t 7Zm!GTqVQ12R0A86.fuMrnL8,7ZwfglVcw6tJzAkzlVb KVUMQJzCoFueqf1B!jQ4WF. JkSi,uoiRzjeKTZV2GuKuRPZ3MRCe8LGMh1!c9TYlIQc5b!3aa8ulE bKy4sq3Q9r0VXma9xOP3Dn9A!3nXAozPikC2zWOItG7uFNa7Od!mE31amkfz0EiThjIiHLUz, KjLI0.kopkXHaFnngDWVtjoVNdCC70xGQOQ,7zDGmJAyrS3Yl? u3j3VV2t2jhXbfbWOXACS,wH5YeWXNK8D.vVB iqY3k5yZf?afwKsLONBZtaz5TsmNFdljr3kKN0ZhQH!UGH EUeY5Ci?tgRY?ad95HlbnQa3eaB?.LfFn!zadIw.zsY0SWyx1RXwh i ELlbrNj5vqCwxHrtPuA0P9pdhiwMX?mm.k,CGBB6uE8XJQiQv6VSJ,bYb53JZX5nCos,ciUZF5KtBnHg4DFmvMYZDW9KKX6ZRSJ4xA9Dxc?JAZ1NV8Up8LlRv0 7nFehbR5gQEhoeskPstxWXXNGq96mQEbunG7Brs2A5P4z5IrsR.YNpP7cixmnt9?pt3ifMcC.up?V5IdhbCLwBceUxUFD7dHYxicX7HBGbSChx!LkdX7MqEOa63.LxdRQQC5.opweCIwj04Bqp44mD5X1Je3905u51kK5iX7V.I,8O0bvt497Cooty1hi6cmrzgIvEj!33lcFt8ncTc6hl jMPjMm0Kd6yL34j!Xk5lO4Ib7XEOJvRZ f.ic1NIuojv5Xu,aMR2HQz1JxdGNFp.kuxst.bivb djGZV7.bFmH,wYnUHuynErfLPjMpcxfIgS1EN.17tkX CpCQQ4iEAvuLGtb8D6JuyPQQAjj3IC4mdc,8zq?8!Lfw1lYV?8xWsWSIhK8CtVLqmXCWQ9R1axQbKR.GDNUIPE9uM8IBSbQNx50c7xhxYxDrOOwqTFQ.r
#
# Determinan :  1007600813482
# K^-1 :  45
# Invers Modulo :  3
#
# Ciphertext :  [50 36 39  5 11 58 19 60 30]
# Plaintext :  [12 30 39 32 30 39 26 37 18]
# Plaintext :  MengenalS
#
# Ciphertext :  [21  8 63 18 19 60 63 37 40]
# Plaintext :  [30 35 26 43 26 33 29 26 39]
# Plaintext :  ejarahdan
#
# Ciphertext :  [ 7 24 54  7 63 60 19 29  1]
# Plaintext :  [18 41 30 44 34 31 34 36 26]
# Plaintext :  Spesifika
#
# Ciphertext :  [53  3 35 62 33 44 52 19 27]
# Plaintext :  [44 34  2 13 54 55 57 21  8]
# Plaintext :  siCN235VI
#
# Ciphertext :  [11 48 65 51 36 13 24 38 44]
# Plaintext :  [21  0 39 30 48 44  3 46 39]
# Plaintext :  VAnewsDun
#
# Ciphertext :  [33 45 59 50 59 54 42  0 52]
# Plaintext :  [34 26 29 34 43 32 26 39 45]
# Plaintext :  iadirgant
#
# Ciphertext :  [31  0 41 66 15 58 13 43 50]
# Plaintext :  [26 43 26  8 39 29 40 39 30]
# Plaintext :  araIndone
#
# Ciphertext :  [ 5 15 28 17 28 48 63 18 46]
# Plaintext :  [44 34 26 36 30 38 27 26 37]
# Plaintext :  siakembal
#
# Ciphertext :  [17 60 50 23 24 66 35 23  8]
# Plaintext :  [34 29 34 37 34 43 34 36 27]
# Plaintext :  idilirikb
#
# Ciphertext :  [35 20 60 35 59  6  5 57  9]
# Plaintext :  [30 43 36 26 45 41 30 44 26]
# Plaintext :  erkatpesa
#
# Ciphertext :  [39  0 30 29  4 59 25 44 15]
# Plaintext :  [48 26 45  2 13 54 55 57 63]
# Plaintext :  watCN235.
#
# Ciphertext :  [ 4 61 38 36 34 31 51 26 38]
# Plaintext :  [15 30 44 26 48 26 45 27 46]
# Plaintext :  Pesawatbu
#
# Ciphertext :  [44 52 46 29 45 60 33 63  8]
# Plaintext :  [26 45 26 39 15 19  3 34 43]
# Plaintext :  atanPTDir
#
# Ciphertext :  [32 62 43 16 56 65  6 58  2]
# Plaintext :  [32 26 39 45 26 43 26  8 39]
# Plaintext :  gantaraIn
#
# Ciphertext :  [60 24 39 19 28 56 31 40  3]
# Plaintext :  [29 40 39 30 44 34 26 29 34]
# Plaintext :  donesiadi
#
# Ciphertext :  [ 8  6  5 19 26 20  0 55 22]
# Plaintext :  [33 26 43 26 41 36 26 39 27]
# Plaintext :  harapkanb
#
# Ciphertext :  [14 55 66 31 43  9  8 22 47]
# Plaintext :  [34 44 26 38 30 39 35 26 29]
# Plaintext :  isamenjad
#
# Ciphertext :  [ 6  8 30 28 65 55 40  1 56]
# Plaintext :  [34 38 40 45 40 43 41 30 38]
# Plaintext :  imotorpem
#
# Ciphertext :  [16 50 11 16 50 59 30 66 10]
# Plaintext :  [27 46 26 45 26 39 41 30 44]
# Plaintext :  buatanpes
#
# Ciphertext :  [ 0 10 42 34 43 46 47 19 39]
# Plaintext :  [26 48 26 45 29 26 37 26 38]
# Plaintext :  awatdalam
#
# Ciphertext :  [23 37 13 18  8 35  5 15 19]
# Plaintext :  [39 30 32 30 43 34 63  0 41]
# Plaintext :  negeri.Ap
#
# Ciphertext :  [62 36 54 56 44  1 26 63 41]
# Plaintext :  [26 37 26 32 34 66 41 30 44]
# Plaintext :  alagi,pes
#
# Ciphertext :  [41 13 38 44 29 14 61 61 53]
# Plaintext :  [26 48 26 45  2 13 54 55 57]
# Plaintext :  awatCN235
#
# Ciphertext :  [ 7  1 40 29  9 46  9 66 59]
# Plaintext :  [44 46 29 26 33 38 30 39 29]
# Plaintext :  sudahmend
#
# Ciphertext :  [14 10  8 35 21 24 29 27 17]
# Plaintext :  [46 39 34 26 29 26 39 29 34]
# Plaintext :  uniadandi
#
# Ciphertext :  [ 9 55 55 33 16 59 31 52  9]
# Plaintext :  [27 30 37 34 27 30 43 27 26]
# Plaintext :  beliberba
#
# Ciphertext :  [24  2  8 56 42 16 16 16 66]
# Plaintext :  [32 26 34 39 30 32 26 43 26]
# Plaintext :  gainegara
#
# Ciphertext :  [40 45 62  4 19 64 53 35 36]
# Plaintext :  [66 26 39 45 26 43 26 37 26]
# Plaintext :  ,antarala
#
# Ciphertext :  [48 61 50 20 62 12 38 21  6]
# Plaintext :  [34 39 10 40 43 30 26 18 30]
# Plaintext :  inKoreaSe
#
# Ciphertext :  [66 30 22 23 56 33 10 11 21]
# Plaintext :  [37 26 45 26 39 29 26 39 18]
# Plaintext :  latandanS
#
# Ciphertext :  [ 5 20 40 29 21  5  2 20 16]
# Plaintext :  [41 26 39 50 40 37 63  2 13]
# Plaintext :  panyol.CN
#
# Ciphertext :  [20 39 11  4  7 21 27 40 11]
# Plaintext :  [54 55 57 38 30 43 46 41 26]
# Plaintext :  235merupa
#
# Ciphertext :  [48 47 44 15 38 59 65 54 24]
# Plaintext :  [36 26 39 41 30 44 26 48 26]
# Plaintext :  kanpesawa
#
# Ciphertext :  [54 25 28 61  4 41 63  8 45]
# Plaintext :  [45 26 39 32 36 46 45 45 46]
# Plaintext :  tangkuttu
#
# Ciphertext :  [40  1  5 21  6 51 66  6 22]
# Plaintext :  [43 27 40 41 43 40 41 27 30]
# Plaintext :  rbopropbe
#
# Ciphertext :  [32 39 57 33 17 13 25 20 48]
# Plaintext :  [43 38 30 44 34 39 29 46 26]
# Plaintext :  rmesindua
#
# Ciphertext :  [19 64 62  4  5 10 59 12 52]
# Plaintext :  [66 50 26 39 32 38 26 44 46]
# Plaintext :  ,yangmasu
#
# Ciphertext :  [31  4 20 22 40 22 42  5 54]
# Plaintext :  [36 36 26 45 30 32 40 43 34]
# Plaintext :  kkategori
#
# Ciphertext :  [60 12 54 48  0  7 54 25 18]
# Plaintext :  [36 30 37 26 44 38 30 39 30]
# Plaintext :  kelasmene
#
# Ciphertext :  [45 31 11 23 26 13 22 28 23]
# Plaintext :  [39 32 26 33 63 15 30 44 26]
# Plaintext :  ngah.Pesa
#
# Ciphertext :  [57 40 22 24  7 49 49 26 59]
# Plaintext :  [48 26 45 45 46 43 27 40 41]
# Plaintext :  watturbop
#
# Ciphertext :  [17 27  4 34 39 22 52 65 36]
# Plaintext :  [43 40 41 38 30 43 46 41 26]
# Plaintext :  ropmerupa
#
# Ciphertext :  [48 47 44 15 38 59 65 54 24]
# Plaintext :  [36 26 39 41 30 44 26 48 26]
# Plaintext :  kanpesawa
#
# Ciphertext :  [27 33 34 30 24 49 17 19 41]
# Plaintext :  [45 45 30 43 27 26 39 32 29]
# Plaintext :  tterbangd
#
# Ciphertext :  [14 27 63 21  0  2 45 27 34]
# Plaintext :  [30 39 32 26 39 45 46 43 27]
# Plaintext :  enganturb
#
# Ciphertext :  [11 60 18 23 61 65 60 56 55]
# Plaintext :  [34 39 32 26 44 50 26 39 32]
# Plaintext :  ingasyang
#
# Ciphertext :  [40 35  5 21 40 63 62  4  1]
# Plaintext :  [45 30 43 33 46 27 46 39 32]
# Plaintext :  terhubung
#
# Ciphertext :  [22  0  6 32 31 56 33 10  1]
# Plaintext :  [36 30 27 26 37 34 39 32 27]
# Plaintext :  kebalingb
#
# Ciphertext :  [ 1 52 47 19 15 21 11 54 35]
# Plaintext :  [26 37 34 39 32 66 46 39 45]
# Plaintext :  aling,unt
#
# Ciphertext :  [18 29 38 47 11 34 23 56 34]
# Plaintext :  [46 36 38 30 39 32 32 30 43]
# Plaintext :  ukmengger
#
# Ciphertext :  [43 22 48 15 30 10 32 34 65]
# Plaintext :  [26 36 36 26 39 41 30 44 26]
# Plaintext :  akkanpesa
#
# Ciphertext :  [ 9 10 31 28  5 26 64 29 11]
# Plaintext :  [48 26 45 63 12 30 38 34 37]
# Plaintext :  wat.Memil
#
# Ciphertext :  [25 36 56 23 56  8 42 38 16]
# Plaintext :  [34 36 34 39 26 38 26 44 26]
# Plaintext :  ikinamasa
#
# Ciphertext :  [52 45 46 19 37 63 59  8 53]
# Plaintext :  [39 29 34 19 30 45 46 36 40]
# Plaintext :  ndiTetuko
#
# Ciphertext :  [26 18 28 59 41 17 18 14  6]
# Plaintext :  [39 26 38 26 37 26 34 39  6]
# Plaintext :  namalainG
#
# Ciphertext :  [39 58 10 35 41 65 65 22 55]
# Plaintext :  [26 45 40 45 36 26 28 26 66]
# Plaintext :  atotkaca,
#
# Ciphertext :  [ 0 17 66 50 42  7 58 23 18]
# Plaintext :  [ 2 13 54 55 57 38 30 43 46]
# Plaintext :  CN235meru
#
# Ciphertext :  [56  1  2 22  5 20 15 51 12]
# Plaintext :  [41 26 36 26 39 41 30 44 26]
# Plaintext :  pakanpesa
#
# Ciphertext :  [ 8 22 22  7 52 15 51 29  0]
# Plaintext :  [48 26 45 33 26 44 34 37 36]
# Plaintext :  wathasilk
#
# Ciphertext :  [30 32 62 18 10 29  1 14 24]
# Plaintext :  [30 43 35 26 44 26 38 26  8]
# Plaintext :  erjasamaI
#
# Ciphertext :  [56 35 27 55 65 13  9 54 10]
# Plaintext :  [39 29 46 44 45 43 34 15 30]
# Plaintext :  ndustriPe
#
# Ciphertext :  [48 10 24 44 26 28 36 61 27]
# Plaintext :  [44 26 48 26 45 19 30 43 27]
# Plaintext :  sawatTerb
#
# Ciphertext :  [ 4 43 25 28  2  0 10 61  8]
# Plaintext :  [26 39 32 13 46 44 26 39 45]
# Plaintext :  angNusant
#
# Ciphertext :  [35 36 47 54 44 27 55 39 60]
# Plaintext :  [26 43 26 28 34 36 26 37 27]
# Plaintext :  aracikalb
#
# Ciphertext :  [ 4 39 15 18 11 66 13 60 45]
# Plaintext :  [26 36 26 37 15 19  3  8 29]
# Plaintext :  akalPTDId
#
# Ciphertext :  [ 6 11 48  7 54 23 34 46 11]
# Plaintext :  [30 39 32 26 39  2  0 18  0]
# Plaintext :  enganCASA
#
# Ciphertext :  [29 47 37 34 26 11 28 65 60]
# Plaintext :  [29 26 43 34 18 41 26 39 50]
# Plaintext :  dariSpany
#
# Ciphertext :  [49 56 59  8 59 46 56 63 65]
# Plaintext :  [40 37 63 15 30 44 26 48 26]
# Plaintext :  ol.Pesawa
#
# Ciphertext :  [36 62 45 59 16  5 60 39 39]
# Plaintext :  [45 34 39 34 44 30 27 30 39]
# Plaintext :  tiniseben
#
# Ciphertext :  [27 11 60 38  0 15 35 51  9]
# Plaintext :  [26 43 39 50 26 45 26 36 37]
# Plaintext :  arnyatakl
#
# Ciphertext :  [40 30 45  2 63  2 33  2 20]
# Plaintext :  [26 32 34 27 30 43 46 44 34]
# Plaintext :  agiberusi
#
# Ciphertext :  [65 28 58 52 23 20 20  8 44]
# Plaintext :  [26 38 46 29 26 63 18 30 27]
# Plaintext :  amuda.Seb
#
# Ciphertext :  [24 19 52 44 27 42 36 24 24]
# Plaintext :  [26 27 66  2 13 54 55 57 45]
# Plaintext :  ab,CN235t
#
# Ciphertext :  [ 7 24  2 47 65 63 14 37  1]
# Plaintext :  [30 37 26 33 38 30 37 26 36]
# Plaintext :  elahmelak
#
# Ciphertext :  [ 8 35 51 35 65 42 32  7 41]
# Plaintext :  [46 36 26 39 45 30 43 27 26]
# Plaintext :  ukanterba
#
# Ciphertext :  [29 46 53 28 63 40 25 29  2]
# Plaintext :  [39 32 41 30 43 29 26 39 26]
# Plaintext :  ngperdana
#
# Ciphertext :  [10 42 42 53 54 10 17 54  3]
# Plaintext :  [44 30 35 26 36 55 52  3 30]
# Plaintext :  sejak30De
#
# Ciphertext :  [ 7 46 60 15 39  6 35 30 15]
# Plaintext :  [44 30 38 27 30 43 53 61 60]
# Plaintext :  sember198
#
# Ciphertext :  [63 33 49  0  6 66 43 31  8]
# Plaintext :  [55 66 36 30 38 46 29 34 26]
# Plaintext :  3,kemudia
#
# Ciphertext :  [ 4 50  6 14 48 45  3 20 21]
# Plaintext :  [39 29 34 41 30 43 36 30 39]
# Plaintext :  ndiperken
#
# Ciphertext :  [ 3 14 28 56 40 35  4 42 43]
# Plaintext :  [26 37 36 26 39 41 26 29 26]
# Plaintext :  alkanpada
#
# Ciphertext :  [29 44 20 20 58  9 32 61 14]
# Plaintext :  [53 12 26 43 30 45 53 61 60]
# Plaintext :  1Maret198
#
# Ciphertext :  [42 49 48 11 34 55 11 30 52]
# Plaintext :  [60 40 37 30 33 12 30 43 41]
# Plaintext :  8olehMerp
#
# Ciphertext :  [33 48 56 15 27 17 55 47 44]
# Plaintext :  [26 45 34 13 46 44 26 39 45]
# Plaintext :  atiNusant
#
# Ciphertext :  [17 45 32 35 48 40  7 26 42]
# Plaintext :  [26 43 26 63 21 26 43 34 26]
# Plaintext :  ara.Varia
#
# Ciphertext :  [45 42 23 12 27 64 42 22 56]
# Plaintext :  [39 41 30 43 45 26 38 26 50]
# Plaintext :  npertamay
#
# Ciphertext :  [10 28 47 58 22 56 66 56 20]
# Plaintext :  [26 39 32 29 34 27 46 26 45]
# Plaintext :  angdibuat
#
# Ciphertext :  [21 20 12 16  9 51  2 40  5]
# Plaintext :  [26 29 26 37 26 33  2 13 54]
# Plaintext :  adalahCN2
#
# Ciphertext :  [31 64 60 17 44 54 47 42 53]
# Plaintext :  [55 57 53 52 66 50 26 39 32]
# Plaintext :  3510,yang
#
# Ciphertext :  [20 13 45 18 65 55 18 30 30]
# Plaintext :  [38 30 39 32 32 46 39 26 36]
# Plaintext :  menggunak
#
# Ciphertext :  [42 27 35 42  3 40 16 54 16]
# Plaintext :  [26 39 38 30 44 34 39  6  4]
# Plaintext :  anmesinGE
#
# Ciphertext :  [31 48 50 38 40 66 63 38 20]
# Plaintext :  [ 2 19 59 59  0 63 15 30 44]
# Plaintext :  CT77A.Pes
#
# Ciphertext :  [51  0 47 45  8 34 12 39 39]
# Plaintext :  [26 48 26 45 34 39 34 41 46]
# Plaintext :  awatinipu
#
# Ciphertext :  [42  7 64 22 15 12 40 34 27]
# Plaintext :  [39 36 30 38 46 29 34 26 39]
# Plaintext :  nkemudian
#
# Ciphertext :  [46 19 63 35  6 48 30 52 46]
# Plaintext :  [38 30 38 34 37 34 36 34 44]
# Plaintext :  memilikis
#
# Ciphertext :  [19 53 22 18 45 10 48 33 10]
# Plaintext :  [30 35 46 38 37 26 33 47 26]
# Plaintext :  ejumlahva
#
# Ciphertext :  [42 54 33 30 25 59 49 34 55]
# Plaintext :  [43 34 26 44 34 63  0 39 45]
# Plaintext :  riasi.Ant
#
# Ciphertext :  [40 32 13 10 44 31  4 50 43]
# Plaintext :  [26 43 26 37 26 34 39  2 13]
# Plaintext :  aralainCN
#
# Ciphertext :  [24 60  1 37  3 14  5 19 41]
# Plaintext :  [54 55 57 55 55 52 15 33 40]
# Plaintext :  235330Pho
#
# Ciphertext :  [28 45  7  9 12 60  1 63 43]
# Plaintext :  [30 39 34 49 50 26 39 32 29]
# Plaintext :  enixyangd
#
# Ciphertext :  [ 2  2 10 23 49 42 29 49 24]
# Plaintext :  [34 32 46 39 26 36 26 39  0]
# Plaintext :  igunakanA
#
# Ciphertext :  [ 5  1 37 44 63  9  5 39 61]
# Plaintext :  [39 32 36 26 45 26 39 20 29]
# Plaintext :  ngkatanUd
#
# Ciphertext :  [ 6 52 45 49  9 17 39 22 55]
# Plaintext :  [26 43 26  0 46 44 45 43 26]
# Plaintext :  araAustra
#
# Ciphertext :  [61  0 46 62 57  1 65 25 18]
# Plaintext :  [37 34 26 29 26 39  2 13 54]
# Plaintext :  liadanCN2
#
# Ciphertext :  [ 1 35 30 10 45 36 65 13 57]
# Plaintext :  [55 57 53 52 52 50 26 39 32]
# Plaintext :  35100yang
#
# Ciphertext :  [ 3  4 45 19 45 58 64 48 43]
# Plaintext :  [29 34 32 46 39 26 36 26 39]
# Plaintext :  digunakan
#
# Ciphertext :  [ 5 37 64 29 20 63 45 62 59]
# Plaintext :  [ 0 39 32 36 26 45 26 39 20]
# Plaintext :  AngkatanU
#
# Ciphertext :  [25 38 65  6 19 42 21 16 53]
# Plaintext :  [29 26 43 26 18 41 26 39 50]
# Plaintext :  daraSpany
#
# Ciphertext :  [54 17 52  0 60 58 63 31 46]
# Plaintext :  [40 37 63 18 30 28 26 43 26]
# Plaintext :  ol.Secara
#
# Ciphertext :  [12 43 39 11 60 66 59 25 48]
# Plaintext :  [46 38 46 38 66 44 41 30 44]
# Plaintext :  umum,spes
#
# Ciphertext :  [31 32 37 21 28 48 58 45  9]
# Plaintext :  [34 31 34 36 26 44 34 50 26]
# Plaintext :  ifikasiya
#
# Ciphertext :  [51  0 36 51 37 21 27 62 10]
# Plaintext :  [39 32 29 34 36 30 39 26 37]
# Plaintext :  ngdikenal
#
# Ciphertext :  [21 20 12 16  9 51  2 40  5]
# Plaintext :  [26 29 26 37 26 33  2 13 54]
# Plaintext :  adalahCN2
#
# Ciphertext :  [46 30 42 31 53  1 65 35 16]
# Plaintext :  [55 57 53 52 52 53 53 52 66]
# Plaintext :  35100110,
#
# Ciphertext :  [56 22  5 63 62  9 36 18 34]
# Plaintext :  [50 26 39 32 38 30 38 34 37]
# Plaintext :  yangmemil
#
# Ciphertext :  [66 46 40 34 17 51 35 30 10]
# Plaintext :  [34 36 34 36 26 41 26 44 34]
# Plaintext :  ikikapasi
#
# Ciphertext :  [19 25 21 54  6 46 10 46 17]
# Plaintext :  [45 26 44 56 57 41 30 39 46]
# Plaintext :  tas45penu
#
# Ciphertext :  [15 25 55 12 17  2 30 60 11]
# Plaintext :  [38 41 26 39 32 29 26 39 54]
# Plaintext :  mpangdan2
#
# Ciphertext :  [ 6 12 33 53 65 28 61 19 24]
# Plaintext :  [36 46 43 44 34 41 34 37 40]
# Plaintext :  kursipilo
#
# Ciphertext :  [37  8 16 28 57 27 65 55 26]
# Plaintext :  [45 63 15 30 44 26 48 26 45]
# Plaintext :  t.Pesawat
#
# Ciphertext :  [26 60 46 37  4 62 27 10 50]
# Plaintext :  [34 39 34 38 30 38 34 37 34]
# Plaintext :  inimemili
#
# Ciphertext :  [56 44 42 55 16 61 43 52 21]
# Plaintext :  [36 34 29 34 38 30 39 44 34]
# Plaintext :  kidimensi
#
# Ciphertext :  [23 38 26 61 49 14 15 55  3]
# Plaintext :  [41 26 39 35 26 39 32 54 53]
# Plaintext :  panjang21
#
# Ciphertext :  [39 61  0 65 55 39 23  0 40]
# Plaintext :  [66 56 38 30 45 30 43 66 27]
# Plaintext :  ,4meter,b
#
# Ciphertext :  [51 15 34 36  2 54 51 22 14]
# Plaintext :  [30 39 45 26 39 32 44 26 50]
# Plaintext :  entangsay
#
# Ciphertext :  [ 8 45  6 59 46  5 13 26 59]
# Plaintext :  [26 41 54 57 66 60 53 38 30]
# Plaintext :  ap25,81me
#
# Ciphertext :  [14 29 65 38  4 55 53 26 38]
# Plaintext :  [45 30 43 66 45 34 39 32 32]
# Plaintext :  ter,tingg
#
# Ciphertext :  [36 31 51 52  4 34 19 33 35]
# Plaintext :  [34 60 66 53 60 38 30 45 30]
# Plaintext :  i8,18mete
#
# Ciphertext :  [ 8 34  7 11 20 51 66 62 10]
# Plaintext :  [43 66 29 26 39 26 43 30 26]
# Plaintext :  r,danarea
#
# Ciphertext :  [35 11  8 52 63 36 40 41 36]
# Plaintext :  [44 26 50 26 41 57 61 63 53]
# Plaintext :  sayap59.1
#
# Ciphertext :  [23  7 26  5 39 39 32  3 22]
# Plaintext :  [38 30 45 30 43 41 30 43 44]
# Plaintext :  meterpers
#
# Ciphertext :  [21 45 35 40 21 13 29  2  2]
# Plaintext :  [30 32 34 63  1 30 43 26 45]
# Plaintext :  egi.Berat
#
# Ciphertext :  [59 52 49  6 16 14 16 66 59]
# Plaintext :  [39 50 26 38 30 39 28 26 41]
# Plaintext :  nyamencap
#
# Ciphertext :  [51  3  6 38  9  0 50 43 18]
# Plaintext :  [26 34 61 63 60 52 52 36 32]
# Plaintext :  ai9.800kg
#
# Ciphertext :  [55 24 37 64 62 46 55 35 55]
# Plaintext :  [29 26 37 26 38 36 30 26 29]
# Plaintext :  dalamkead
#
# Ciphertext :  [21 21 54 45 54 35 33 23 27]
# Plaintext :  [26 26 39 36 40 44 40 39 32]
# Plaintext :  aankosong
#
# Ciphertext :  [31 27 22 14 23  0  2 18 66]
# Plaintext :  [66 29 26 39 53 57 63 57 52]
# Plaintext :  ,dan15.50
#
# Ciphertext :  [48  7 57 24 30 22 23 13 10]
# Plaintext :  [52 29 26 37 26 38 36 30 26]
# Plaintext :  0dalamkea
#
# Ciphertext :  [60  3 63 47 21  1 62 34 42]
# Plaintext :  [29 26 26 39 34 44 34 63  3]
# Plaintext :  daanisi.D
#
# Ciphertext :  [24 55 36 57 50 25 31 64 26]
# Plaintext :  [30 39 32 26 39 38 30 39 32]
# Plaintext :  enganmeng
#
# Ciphertext :  [31 48 10 44 11 14 13  1 25]
# Plaintext :  [32 46 39 26 36 26 39 29 46]
# Plaintext :  gunakandu
#
# Ciphertext :  [45 26 51 57 19 44 38 13  5]
# Plaintext :  [26 38 30 44 34 39 45 30 39]
# Plaintext :  amesinten
#
# Ciphertext :  [29 37 35 43 55 36 10 13 52]
# Plaintext :  [26 32 26 41 30 39 32 32 30]
# Plaintext :  agapengge
#
# Ciphertext :  [25 33 16  7 65 20  6  7 62]
# Plaintext :  [43 26 36  6  4  2 19 59 61]
# Plaintext :  rakGECT79
#
# Ciphertext :  [ 4 20 30 24 57  2 34 64 45]
# Plaintext :  [ 2 45 46 43 27 40 41 43 40]
# Plaintext :  Cturbopro
#
# Ciphertext :  [32 17 24 64 26 29 61 57  7]
# Plaintext :  [41 66 29 30 39 32 26 39 38]
# Plaintext :  p,denganm
#
# Ciphertext :  [37 27 39 16 26 55 30 26  1]
# Plaintext :  [26 44 34 39 32 38 26 44 34]
# Plaintext :  asingmasi
#
# Ciphertext :  [64 63 11 31  5 39 65 51 26]
# Plaintext :  [39 32 53 66 55 61 57 36 22]
# Plaintext :  ng1,395kW
#
# Ciphertext :  [29  8 48 63 51 44 24 52 18]
# Plaintext :  [66 41 30 44 26 48 26 45 34]
# Plaintext :  ,pesawati
#
# Ciphertext :  [22 50 49 53 17 23 48 33 62]
# Plaintext :  [39 34 38 26 38 41 46 38 30]
# Plaintext :  nimampume
#
# Ciphertext :  [34 62  4 11 37 27 43 13 35]
# Plaintext :  [39 30 38 41 46 33 36 30 28]
# Plaintext :  nempuhkec
#
# Ciphertext :  [57 47 42  2 48 49  7 43 45]
# Plaintext :  [30 41 26 45 26 39 38 26 36]
# Plaintext :  epatanmak
#
# Ciphertext :  [15 46  0 52 15 61 41 29 33]
# Plaintext :  [44 34 38 46 38 57 52 61 36]
# Plaintext :  simum509k
#
# Ciphertext :  [34 48 12 23 64 38 38 63 36]
# Plaintext :  [38 41 30 43 35 26 38 63  9]
# Plaintext :  mperjam.J
#
# Ciphertext :  [66  2  6  1  1 58 46  4 60]
# Plaintext :  [26 43 26 36 50 26 39 32 38]
# Plaintext :  arakyangm
#
# Ciphertext :  [23  9 16 34 16 47 58 21 18]
# Plaintext :  [26 38 41 46 29 34 45 30 38]
# Plaintext :  ampuditem
#
# Ciphertext :  [ 9 66 27 24 27 57 55  9 25]
# Plaintext :  [41 46 33 44 30 36 34 45 26]
# Plaintext :  puhsekita
#
# Ciphertext :  [23 57 39  2 40 44 66 28 34]
# Plaintext :  [43 59 61 58 36 38 63 15 30]
# Plaintext :  r796km.Pe
#
# Ciphertext :  [20 25  5 57 10 45  1 39  7]
# Plaintext :  [44 26 48 26 45 34 39 34 44]
# Plaintext :  sawatinis
#
# Ciphertext :  [32 56  3  5 38 47 12 24 25]
# Plaintext :  [30 43 34 39 32 29 34 32 46]
# Plaintext :  eringdigu
#
# Ciphertext :  [ 3 22 61 10 10 23 58 25 17]
# Plaintext :  [39 26 36 26 39 44 30 27 26]
# Plaintext :  nakanseba
#
# Ciphertext :  [18  9 56 49  0 61  3 49 28]
# Plaintext :  [32 26 34 41 30 44 26 48 26]
# Plaintext :  gaipesawa
#
# Ciphertext :  [64  9  0 25 53 13 21 60 20]
# Plaintext :  [45 26 39 32 36 46 45 63 22]
# Plaintext :  tangkut.W
#
# Ciphertext :  [41 60 11 37 17 47 52 62 59]
# Plaintext :  [26 36 34 37 10 30 45 46 26]
# Plaintext :  akilKetua
#
# Ciphertext :  [39  5 30 33 27 17 57 32 16]
# Plaintext :  [10 40 38 34 44 34  8  3 15]
# Plaintext :  KomisiIDP
#
# Ciphertext :  [ 4 33 40 30 44 36 15 44 45]
# Plaintext :  [17 29 26 43 34  5 43 26 36]
# Plaintext :  RdariFrak
#
# Ciphertext :  [49 22 23 23 13  6 42 61 58]
# Plaintext :  [44 34 15  3  8 15 30 43 35]
# Plaintext :  siPDIPerj
#
# Ciphertext :  [38 16  4 27 46 39  6 59  1]
# Plaintext :  [46 26 39 32 26 39 66 19 46]
# Plaintext :  uangan,Tu
#
# Ciphertext :  [43 44 54  0 57 15 56 51 57]
# Plaintext :  [27 26 32 46 44  7 26 44 26]
# Plaintext :  bagusHasa
#
# Ciphertext :  [ 8 43 44 17 63 24 13 41 15]
# Plaintext :  [39 46 29 29 34 39 66 38 30]
# Plaintext :  nuddin,me
#
# Ciphertext :  [59 28 34 49 38 39 45 61 64]
# Plaintext :  [39 32 26 45 26 36 26 39  2]
# Plaintext :  ngatakanC
#
# Ciphertext :  [41 45 55 34 31 12 28  2 63]
# Plaintext :  [13 54 55 57 35 46 32 26 36]
# Plaintext :  N235jugak
#
# Ciphertext :  [46 41 64 21 57  8 29 33 27]
# Plaintext :  [30 43 26 41 29 34 32 46 39]
# Plaintext :  erapdigun
#
# Ciphertext :  [ 2 11 48  1 28 30 20 49 20]
# Plaintext :  [26 36 26 39 46 39 45 46 36]
# Plaintext :  akanuntuk
#
# Ciphertext :  [ 5  3 59 29  7 24 49 34 28]
# Plaintext :  [38 30 39 32 26 39 32 36 46]
# Plaintext :  mengangku
#
# Ciphertext :  [23 59  7  1  6 27 18  2 33]
# Plaintext :  [45 41 26 44 46 36 26 39 63]
# Plaintext :  tpasukan.
#
# Ciphertext :  [49 65 11 36 29 23 59 12 42]
# Plaintext :  [20 39 45 46 36 38 30 39 32]
# Plaintext :  Untukmeng
#
# Ciphertext :  [ 4 14 26 58 55 63 11 49 29]
# Plaintext :  [26 39 32 36 46 45 41 26 44]
# Plaintext :  angkutpas
#
# Ciphertext :  [17 16 16  2 57 63 40 41 48]
# Plaintext :  [46 36 26 39 44 26 38 41 26]
# Plaintext :  ukansampa
#
# Ciphertext :  [30  2  8 48 35 52 56  1 42]
# Plaintext :  [34 54 41 30 37 30 45 40 39]
# Plaintext :  i2peleton
#
# Ciphertext :  [41 56 56 38  3 57 23 53  9]
# Plaintext :  [63  1 34 44 26 35 46 32 26]
# Plaintext :  .Bisajuga
#
# Ciphertext :  [30 55 61 52 57 46 57 53 36]
# Plaintext :  [29 34 41 26 36 26 34 46 39]
# Plaintext :  dipakaiun
#
# Ciphertext :  [10 57 34 23 59 21 63  8 66]
# Plaintext :  [45 46 36 38 30 39 30 43 35]
# Plaintext :  tukmenerj
#
# Ciphertext :  [60 14 52 27 47 45 56 61 59]
# Plaintext :  [46 39 36 26 39 41 26 44 46]
# Plaintext :  unkanpasu
#
# Ciphertext :  [ 2 40 40 45 50 53 33 34 58]
# Plaintext :  [36 26 39 63 15 30 44 26 48]
# Plaintext :  kan.Pesaw
#
# Ciphertext :  [28 38 43 51 32  8 47  4 35]
# Plaintext :  [26 45 44 30 43 27 26 32 46]
# Plaintext :  atserbagu
#
# Ciphertext :  [65 55 55 37 28  5 45 60 39]
# Plaintext :  [39 26 37 26 33 63 11 26 39]
# Plaintext :  nalah.Lan
#
# Ciphertext :  [28 19 28 58 33 37 62 35 12]
# Plaintext :  [29 26 44 26 39 39 50 26 35]
# Plaintext :  dasannyaj
#
# Ciphertext :  [15 35 12 38 52 10 29 58 50]
# Plaintext :  [46 32 26 28 46 36 46 41 41]
# Plaintext :  ugacukupp
#
# Ciphertext :  [11 55 56 35 65 23 36 57 37]
# Plaintext :  [30 39 29 30 36 66 46 35 26]
# Plaintext :  endek,uja
#
# Ciphertext :  [14 56  8 27 59 23  4 14  9]
# Plaintext :  [43 39 50 26 63  2 13 54 55]
# Plaintext :  rnya.CN23
#
# Ciphertext :  [47 17 25 62 31 63 34 28 53]
# Plaintext :  [57 34 45 46 45 30 43 38 26]
# Plaintext :  5ituterma
#
# Ciphertext :  [13  8 46 40 35 47 57 23 46]
# Plaintext :  [44 46 36 41 30 44 26 48 26]
# Plaintext :  sukpesawa
#
# Ciphertext :  [66 26 12 17 54  7 16 51 53]
# Plaintext :  [45 50 26 39 32 27 26 39 29]
# Plaintext :  tyangband
#
# Ciphertext :  [ 9 49 29  6 13  5 41 63 36]
# Plaintext :  [30 37 63 18 30 45 26 33 46]
# Plaintext :  el.Setahu
#
# Ciphertext :  [46 49 44 45 63 27 34 47 27]
# Plaintext :  [44 26 50 26 44 26 38 41 26]
# Plaintext :  sayasampa
#
# Ciphertext :  [62 29 35  6 25 21 59 63 27]
# Plaintext :  [34 44 30 36 26 43 26 39 32]
# Plaintext :  isekarang
#
# Ciphertext :  [ 5 38  7 66 48 24 39 20  7]
# Plaintext :  [27 26 34 36 29 34 18 41 26]
# Plaintext :  baikdiSpa
#
# Ciphertext :  [46 50 39  4 43 31 11 15 35]
# Plaintext :  [39 50 40 37 38 26 46 41 46]
# Plaintext :  nyolmaupu
#
# Ciphertext :  [12 41 28 49 31  8 32 18 53]
# Plaintext :  [39 29 34  8 39 29 40 39 30]
# Plaintext :  ndiIndone
#
# Ciphertext :  [ 4 13 63 53 59 45 36 23 62]
# Plaintext :  [44 34 26 27 30 37 46 38 26]
# Plaintext :  siabeluma
#
# Ciphertext :  [ 2 41  2 16 16 56 34  4  0]
# Plaintext :  [29 26  2 13 54 55 57 50 26]
# Plaintext :  daCN235ya
#
# Ciphertext :  [47 46 11  6 45 27 60  3 58]
# Plaintext :  [39 32 35 26 45 46 33 66 36]
# Plaintext :  ngjatuh,k
#
# Ciphertext :  [ 9 46 50 15 16 16  0 35 35]
# Plaintext :  [26 45 26 19 46 27 26 32 46]
# Plaintext :  ataTubagu
#
# Ciphertext :  [55  8  2 56 38 29 28 66 60]
# Plaintext :  [44 66 50 26 39 32 35 46 32]
# Plaintext :  s,yangjug
#
# Ciphertext :  [51 42 64 60 65 11 31 48 53]
# Plaintext :  [26 27 30 36 26 44 18 30 36]
# Plaintext :  abekasSek
#
# Ciphertext :  [37 24 21 64 60 49 22 44 22]
# Plaintext :  [43 30 45 26 43 34 44 12 34]
# Plaintext :  retarisMi
#
# Ciphertext :  [18  8 33 10 60  2 45 21 11]
# Plaintext :  [37 34 45 30 43 29 34 30 43]
# Plaintext :  literdier
#
# Ciphertext :  [42 38 23  2 22 16 61 17 53]
# Plaintext :  [26 41 30 38 30 43 34 39 45]
# Plaintext :  apemerint
#
# Ciphertext :  [26 49 16 27 10 17 63  6  3]
# Plaintext :  [26 33 26 39 15 43 30 44 34]
# Plaintext :  ahanPresi
#
# Ciphertext :  [13 20  8 15  4 61 46 12 60]
# Plaintext :  [29 30 39 12 30 32 26 48 26]
# Plaintext :  denMegawa
#
# Ciphertext :  [ 8  1 18 27 16 13 49 57 52]
# Plaintext :  [45 34 18 40 30 36 26 43 39]
# Plaintext :  tiSoekarn
#
# Ciphertext :  [28 59 49 33 49 24 49  3 43]
# Plaintext :  [40 41 46 45 43 34 34 39 34]
# Plaintext :  oputriini
#
# Ciphertext :  [14 14 48 42 19  5 16 63 43]
# Plaintext :  [63 23 23 23 23 23 23 23 23]
# Plaintext :  .XXXXXXXX
#
# Plain Text :  MengenalSejarahdanSpesifikasiCN235VIVAnewsDuniadirgantaraIndonesiakembalidilirikberkatpesawatCN235.PesawatbuatanPTDirgantaraIndonesiadiharapkanbisamenjadimotorpembuatanpesawatdalamnegeri.Apalagi,pesawatCN235sudahmenduniadandibeliberbagainegara,antaralainKoreaSelatandanSpanyol.CN235merupakanpesawatangkutturbopropbermesindua,yangmasukkategorikelasmenengah.Pesawatturbopropmerupakanpesawatterbangdenganturbingasyangterhubungkebalingbaling,untukmenggerakkanpesawat.MemilikinamasandiTetukonamalainGatotkaca,CN235merupakanpesawathasilkerjasamaIndustriPesawatTerbangNusantaracikalbakalPTDIdenganCASAdariSpanyol.Pesawatinisebenarnyataklagiberusiamuda.Sebab,CN235telahmelakukanterbangperdanasejak30Desember1983,kemudiandiperkenalkanpada1Maret1988olehMerpatiNusantara.VarianpertamayangdibuatadalahCN23510,yangmenggunakanmesinGECT77A.Pesawatinipunkemudianmemilikisejumlahvariasi.AntaralainCN235330PhoenixyangdigunakanAngkatanUdaraAustraliadanCN235100yangdigunakanAngkatanUdaraSpanyol.Secaraumum,spesifikasiyangdikenaladalahCN235100110,yangmemilikikapasitas45penumpangdan2kursipilot.Pesawatinimemilikidimensipanjang21,4meter,bentangsayap25,81meter,tinggi8,18meter,danareasayap59.1meterpersegi.Beratnyamencapai9.800kgdalamkeadaankosong,dan15.500dalamkeadaanisi.DenganmenggunakanduamesintenagapenggerakGECT79Cturboprop,denganmasingmasing1,395kW,pesawatinimampumenempuhkecepatanmaksimum509kmperjam.Jarakyangmampuditempuhsekitar796km.Pesawatiniseringdigunakansebagaipesawatangkut.WakilKetuaKomisiIDPRdariFraksiPDIPerjuangan,TubagusHasanuddin,mengatakanCN235jugakerapdigunakanuntukmengangkutpasukan.Untukmengangkutpasukansampai2peleton.Bisajugadipakaiuntukmenerjunkanpasukan.Pesawatserbagunalah.Landasannyajugacukuppendek,ujarnya.CN235itutermasukpesawatyangbandel.SetahusayasampaisekarangbaikdiSpanyolmaupundiIndonesiabelumadaCN235yangjatuh,kataTubagus,yangjugabekasSekretarisMiliterdierapemerintahanPresidenMegawatiSoekarnoputriini.XXXXXXXX

# %% [markdown]
# ----
# YANG GAADA ANGKA HEHE MAAF YAH
# -----

# %%
import numpy as np
import math
import random

option = 0

# Kamus Huruf ke Angka
substitusi = {
    'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 'L': 11, 'M': 12,
    'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25,
    'a': 26, 'b': 27, 'c': 28, 'd': 29, 'e': 30, 'f': 31, 'g': 32, 'h': 33, 'i': 34, 'j': 35, 'k': 36, 'l': 37, 'm': 38,
    'n': 39, 'o': 40, 'p': 41, 'q': 42, 'r': 43, 's': 44, 't': 45, 'u': 46, 'v': 47, 'w': 48, 'x': 49, 'y': 50, 'z': 51,
    ' ': 52, '.': 53, '?': 54, '!': 55, ',': 56}

# Membalik Variabel Substitusi menjadi "Angka : Huruf" || 0 : 'A' dst.
inverse_substitution = {angka: huruf for huruf, angka in substitusi.items()}


def encrypt(plain_text, key_matrix):
    # Convert Plain Text ke Huruf Besar
    plain_text = plain_text

    # Merubah karakter Spasi menjadi simbol "_"
    plain_text = plain_text.replace(" ", "_")

    # Menghilangkan karakter selain yang ada di variabel substitusi
    hasil = ""

    for i in plain_text:
        if i in substitusi:
            hasil += i

    plain_text = hasil

    # Jika panjang Plain Text tidak sekelipatan dengan besar matriks kita tambahkan huruf 'X'
    # Jika matriksnya 2x2, contoh : "BA MB AN G" maka akan dirubah menjadi "BA MB AN GX"
    # Jika matriksnya 3x3, contoh : "BAM BAN G" maka akan dirubah menjadi "BAM BAN GXX"
    if len(plain_text) % len(key_matrix) != 0:
        padding_length = len(key_matrix) - (len(plain_text) % len(key_matrix))
        plain_text += 'X' * padding_length

    # Tempat untuk menyimpan Cipher Text
    cipher_text = ''

    print('Plain Text Bersih : ', plain_text)
    print('Key Matrix : \n', key_matrix)

    # Looping Enkripsi
    for i in range(0, len(plain_text), len(key_matrix)):
        # Mengambil plaintext huruf ke i sampai i + len(key_matrix)
        block = plain_text[i:i+len(key_matrix)]

        # Konversi plaintext menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nPlaintext : ", block_vector)

        # Perkalian Vector, kemudian di modulokan 27. 26 dari alphabet 1 untuk karakter spasi.
        # encrypted_vector = np.dot(block_vector, key_matrix) % 27
        encrypted_vector = np.dot(key_matrix, block_vector) % 57
        print("Ciphertext : ", encrypted_vector)

        # Konversi Angka ke Huruf
        encrypted_block = ''.join([inverse_substitution[num]
                                  for num in encrypted_vector])
        print("Ciphertext : ", encrypted_block)

        # Cipher Text ditampung di variabel bernama cipher_text
        cipher_text += encrypted_block

    return cipher_text

# Fungsi untuk mencari modulo invers


def mod_inverse(a, m):
    for x in range(1, m):
        if (a * x) % m == 1:
            return x
    return None


def decrypt(cipher_text, key_matrix):

    # Convert Cipher Text ke Huruf Besar
    cipher_text = cipher_text

    # Mencari determinan dengan menggunakan numpy, kemudian angkanya di bulatkan.
    determinant = int(np.round(np.linalg.det(key_matrix)))
    print("\nDeterminan : ", determinant)

    determinant = determinant % 57
    print("K^-1 : ", determinant)

    # Mencari modulo invers dari determinan
    modulo_inverse = mod_inverse(determinant, 57)

    print("Invers Modulo : ", modulo_inverse)

    if modulo_inverse is None:
        return "Determinan tidak memiliki invers modulo 57"
    else:
        # Membuat variabel penampung baru, besarnya sama seperti key_matrix.
        # Jika key_matrix berukuran 3x3, maka adjoint_matrix akan berukuran 3x3 juga.
        adjoint_matrix = np.zeros_like(key_matrix, dtype=np.int64)

        # key_matrix.shape isinya yaitu ukuran matriks.
        # Jika key_matrix berukuran 3x3, maka key_matrix.shape akan bernilai [3,3]
        for i in range(key_matrix.shape[0]):
            for j in range(key_matrix.shape[1]):
                # Axis 0 artinya baris, Axis 1 artinya kolom.
                # Untuk mendapatkan sub_matrix, kita menghapus baris dan kolom pada matriks itu.
                # Contoh : 2 1 1 | Misal pada posisi pertama i = 0 ; j = 0, kita akan menghapus
                #          3 5 2 | baris dan kolom "2" menyisakan | 5 2 | sebagai sub_matrix nya.
                #          3 3 3 |                                | 3 3 |
                sub_matrix = np.delete(
                    np.delete(key_matrix, i, axis=0), j, axis=1)
                # Kemudian, mencari determinan dari sub_matrix tersebut.
                cofactor = int(np.round(np.linalg.det(sub_matrix)))
                # Melihat apakah i+j ganjil/genap. Jika i+j ganjil, maka angka didepan menjadi "1"
                # Jika i+j genap, maka angka didepan menjadi "-1"
                adjoint_matrix[j, i] = ((-1) ** (i + j)) * cofactor

        # Mencari Kunci Matriks Invers dengan mengalikan adjoint_matrix dengan Modulo Invers dan di modulo 27.
        key_matrix_inv = (adjoint_matrix * modulo_inverse) % 57

    # Tempat untuk menyimpan Plain Text hasil dekripsi
    plain_text = ''

    # Looping Dekripsi
    for i in range(0, len(cipher_text), len(key_matrix)):
        # Mengambil Cipher Text huruf ke i sampai i + len(key_matrix)
        block = cipher_text[i:i+len(key_matrix)]

        # Konversi Cipher Text menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nCiphertext : ", block_vector)

        # Dekripsi dengan mengalikan matriks kunci invers dengan vektor ciphertext
        # decrypted_vector = np.dot(block_vector, key_matrix_inv) % 27
        decrypted_vector = np.dot(key_matrix_inv, block_vector) % 57
        print("Plaintext : ", decrypted_vector)

        # Konversi vektor hasil dekripsi menjadi huruf
        decrypted_block = ''.join([inverse_substitution[num]
                                  for num in decrypted_vector])
        print("Plaintext : ", decrypted_block)

        # Plain Text ditampung di variabel bernama plain_text
        plain_text += decrypted_block

    # Mengreplace karakter "_" dengan spasi " ".
    return plain_text.replace('_', ' ')


def buatkeymatrix(string_input):
    # Menghitung panjang string
    panjang_string = len(string_input)

    # Menghitung ukuran matriks m x m
    m = int(math.sqrt(panjang_string))

    # Memastikan bahwa panjang string sesuai dengan ukuran matriks m x m
    if m * m != panjang_string:
        print("Panjang string tidak cocok dengan ukuran matriks m x m.")
        return
    else:
        # Membuat matriks m x m dengan huruf dari string input
        key_matrix = np.array([substitusi[text]
                              for text in string_input]).reshape(m, m)

        return key_matrix


def generatekey(panjang):
    randomtext = []
    # Mengulang berdasarkan panjang yang diinginkan
    for i in range(panjang):
        # Menghasilkan angka acak dari 0-26, kemudian disimpan kedalam array.
        randomtext.append(random.randint(0, 56))
    # Mengubah angka menjadi huruf sesuai substitusi.
    randomtext_array = np.array(
        [inverse_substitution[text] for text in randomtext])
    # Mengabungkan array menjadi satu string utuh.
    result = ''.join(randomtext_array)

    return result


def cekrekomendasi(kunci):
    result = ""
    cek = 0

    # Looping berdasarkan panjang kunci.
    for i in range(len(kunci)):
        # Looping mencoba kombinasi huruf sebanyak 10000 kali.
        for j in range(10000):
            # Menghasilkan huruf untuk mengreplace bagian belakang.
            huruf = generatekey(i+1)
            # Menghapus string belakang yang kemudian di replace oleh huruf random.
            text = kunci[0:len(kunci)-i-1] + huruf
            # Mengubah text menjadi matriks m x m
            text_vector = np.array([substitusi[huruf] for huruf in text]).reshape(
                int(math.sqrt(len(text))), int(math.sqrt(len(text))))
            # Mencari Determinan
            determinant = int(np.round(np.linalg.det(text_vector)))
            # Mencari Modulo Invers
            modulo_inverse = mod_inverse(determinant, 57)
            # Jika Modulo Invers Ditemukan, return result. cek = 1 untuk keluar dari looping.
            if modulo_inverse is not None:
                result = text
                cek = 1
            if cek == 1:
                break
        if cek == 1:
            break
    return result


while (option != "1" or option != "2" or option != "3"):
    option = input(
        '\nHill Cipher\n1. Encrypt\n2. Decrypt\n3. Cek Kunci\n4. Exit\nInput : ')

    if (option == "1"):
        plain_text = input('Insert Plain Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci.replace(' ', '_')
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        cipher_text = encrypt(plain_text, key_matrix)
        print("\nCipher Text : ", cipher_text)
    elif (option == "2"):
        cipher_text = input('Insert Cipher Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci.replace(' ', '_')
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        plain_text_decrypted = decrypt(cipher_text, key_matrix)
        print("\nPlain Text : ", plain_text_decrypted)
    elif (option == "3"):
        kunci = input('Insert Kunci : ')
        kunci = kunci.replace(' ', '_')
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        determinant = int(np.round(np.linalg.det(key_matrix)))
        result = mod_inverse(determinant, 57)
        if result is not None:
            kunciditemukan = 1
            print('Modulo Invers dari {kunci} adalah ', result)
        else:
            rekomendasi = cekrekomendasi(kunci)
            print('Kunci Tersebut Tidak Memiliki Modulo Invers.')
            print('Rekomendasi : ', rekomendasi)
    elif (option == "4"):
        exit()
