# %% [markdown]
# <a href="https://colab.research.google.com/github/taliyameyswara/crypto-system/blob/main/superEnkripsiQuiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import random
import re

option = 0

# Kamus Huruf ke Angka
substitusi = {
    'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9,
    'K': 10, 'L': 11, 'M': 12, 'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18,
    'T': 19, 'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25, ' ': 26, 'a': 27,
    'b': 28, 'c': 29, 'd': 30, 'e': 31, 'f': 32, 'g': 33, 'h': 34, 'i': 35, 'j': 36,
    'k': 37, 'l': 38, 'm': 39, 'n': 40, 'o': 41, 'p': 42, 'q': 43, 'r': 44, 's': 45,
    't': 46, 'u': 47, 'v': 48, 'w': 49, 'x': 50, 'y': 51, 'z': 52, '!': 53, '?': 54,
    '.': 55, ',': 56}

# Membalik Variabel Substitusi menjadi "Angka : Huruf" || 0 : 'A' dst.
inverse_substitution = {angka: huruf for huruf, angka in substitusi.items()}


def encrypt(plain_text, key_matrix):
    # Convert Plain Text ke Huruf Besar
    plain_text = plain_text

    # Menghilangkan karakter selain yang ada di variabel substitusi
    hasil = ""

    for i in plain_text:
        if i in substitusi:
            hasil += i

    plain_text = hasil

    # Jika panjang Plain Text tidak sekelipatan dengan besar matriks kita tambahkan huruf 'X'
    # Jika matriksnya 2x2, contoh : "BA MB AN G" maka akan dirubah menjadi "BA MB AN GX"
    # Jika matriksnya 3x3, contoh : "BAM BAN G" maka akan dirubah menjadi "BAM BAN GXX"
    if len(plain_text) % len(key_matrix) != 0:
        padding_length = len(key_matrix) - (len(plain_text) % len(key_matrix))
        plain_text += 'X' * padding_length

    # Tempat untuk menyimpan Cipher Text
    cipher_text = ''

    print('Plain Text Bersih : ', plain_text)
    print('Key Matrix : \n', key_matrix)

    # Looping Enkripsi
    for i in range(0, len(plain_text), len(key_matrix)):
        # Mengambil plaintext huruf ke i sampai i + len(key_matrix)
        block = plain_text[i:i+len(key_matrix)]

        # Konversi plaintext menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nPlaintext : ", block_vector)

        # Perkalian Vector, kemudian di modulokan 27. 26 dari alphabet 1 untuk karakter spasi.
        # encrypted_vector = np.dot(block_vector, key_matrix) % 27
        encrypted_vector = np.dot(key_matrix, block_vector) % 57
        print("Ciphertext : ", encrypted_vector)

        # Konversi Angka ke Huruf
        encrypted_block = ''.join([inverse_substitution[num]
                                  for num in encrypted_vector])
        print("Ciphertext : ", encrypted_block)

        # Cipher Text ditampung di variabel bernama cipher_text
        cipher_text += encrypted_block

    return cipher_text

# Fungsi untuk mencari modulo invers


def mod_inverse(a, m):
    for x in range(1, m):
        if (a * x) % m == 1:
            return x
    return None


def decrypt(cipher_text, key_matrix):

    # Convert Cipher Text ke Huruf Besar
    cipher_text = cipher_text

    # Mencari determinan dengan menggunakan numpy, kemudian angkanya di bulatkan.
    determinant = int(np.round(np.linalg.det(key_matrix)))
    print("\nDeterminan : ", determinant)

    determinant = determinant % 57
    print("K^-1 : ", determinant)

    # Mencari modulo invers dari determinan
    modulo_inverse = mod_inverse(determinant, 57)

    print("Invers Modulo : ", modulo_inverse)

    if modulo_inverse is None:
        return "Determinan tidak memiliki invers modulo 57"
    else:
        # Membuat variabel penampung baru, besarnya sama seperti key_matrix.
        # Jika key_matrix berukuran 3x3, maka adjoint_matrix akan berukuran 3x3 juga.
        adjoint_matrix = np.zeros_like(key_matrix, dtype=np.int64)

        # key_matrix.shape isinya yaitu ukuran matriks.
        # Jika key_matrix berukuran 3x3, maka key_matrix.shape akan bernilai [3,3]
        for i in range(key_matrix.shape[0]):
            for j in range(key_matrix.shape[1]):
                # Axis 0 artinya baris, Axis 1 artinya kolom.
                # Untuk mendapatkan sub_matrix, kita menghapus baris dan kolom pada matriks itu.
                # Contoh : 2 1 1 | Misal pada posisi pertama i = 0 ; j = 0, kita akan menghapus
                #          3 5 2 | baris dan kolom "2" menyisakan | 5 2 | sebagai sub_matrix nya.
                #          3 3 3 |                                | 3 3 |
                sub_matrix = np.delete(
                    np.delete(key_matrix, i, axis=0), j, axis=1)
                # Kemudian, mencari determinan dari sub_matrix tersebut.
                cofactor = int(np.round(np.linalg.det(sub_matrix)))
                # Melihat apakah i+j ganjil/genap. Jika i+j ganjil, maka angka didepan menjadi "1"
                # Jika i+j genap, maka angka didepan menjadi "-1"
                adjoint_matrix[j, i] = ((-1) ** (i + j)) * cofactor

        # Mencari Kunci Matriks Invers dengan mengalikan adjoint_matrix dengan Modulo Invers dan di modulo 27.
        key_matrix_inv = (adjoint_matrix * modulo_inverse) % 57

    # Tempat untuk menyimpan Plain Text hasil dekripsi
    plain_text = ''

    # Looping Dekripsi
    for i in range(0, len(cipher_text), len(key_matrix)):
        # Mengambil Cipher Text huruf ke i sampai i + len(key_matrix)
        block = cipher_text[i:i+len(key_matrix)]

        # Konversi Cipher Text menjadi angka.
        block_vector = np.array([substitusi[text] for text in block])
        print("\nCiphertext : ", block_vector)

        # Dekripsi dengan mengalikan matriks kunci invers dengan vektor ciphertext
        # decrypted_vector = np.dot(block_vector, key_matrix_inv) % 27
        decrypted_vector = np.dot(key_matrix_inv, block_vector) % 57
        print("Plaintext : ", decrypted_vector)

        # Konversi vektor hasil dekripsi menjadi huruf
        decrypted_block = ''.join([inverse_substitution[num]
                                  for num in decrypted_vector])
        print("Plaintext : ", decrypted_block)

        # Plain Text ditampung di variabel bernama plain_text
        plain_text += decrypted_block

    # Mengreplace karakter "_" dengan spasi " ".
    return plain_text


def buatkeymatrix(string_input):
    # Menghitung panjang string
    panjang_string = len(string_input)

    # Menghitung ukuran matriks m x m
    m = int(math.sqrt(panjang_string))

    # Memastikan bahwa panjang string sesuai dengan ukuran matriks m x m
    if m * m != panjang_string:
        print("Panjang string tidak cocok dengan ukuran matriks m x m.")
        return
    else:
        # Membuat matriks m x m dengan huruf dari string input
        key_matrix = np.array([substitusi[text]
                              for text in string_input]).reshape(m, m)

        return key_matrix


def generatekey(panjang):
    randomtext = []
    # Mengulang berdasarkan panjang yang diinginkan
    for i in range(panjang):
        # Menghasilkan angka acak dari 0-26, kemudian disimpan kedalam array.
        randomtext.append(random.randint(0, 56))
    # Mengubah angka menjadi huruf sesuai substitusi.
    randomtext_array = np.array(
        [inverse_substitution[text] for text in randomtext])
    # Mengabungkan array menjadi satu string utuh.
    result = ''.join(randomtext_array)

    return result


def cekrekomendasi(kunci):
    result = ""
    cek = 0

    # Looping berdasarkan panjang kunci.
    for i in range(len(kunci)):
        # Looping mencoba kombinasi huruf sebanyak 10000 kali.
        for j in range(10000):
            # Menghasilkan huruf untuk mengreplace bagian belakang.
            huruf = generatekey(i+1)
            # Menghapus string belakang yang kemudian di replace oleh huruf random.
            text = kunci[0:len(kunci)-i-1] + huruf
            # Mengubah text menjadi matriks m x m
            text_vector = np.array([substitusi[huruf] for huruf in text]).reshape(
                int(math.sqrt(len(text))), int(math.sqrt(len(text))))
            # Mencari Determinan
            determinant = int(np.round(np.linalg.det(text_vector)))
            # Mencari Modulo Invers
            modulo_inverse = mod_inverse(determinant, 57)
            # Jika Modulo Invers Ditemukan, return result. cek = 1 untuk keluar dari looping.
            if modulo_inverse is not None:
                result = text
                cek = 1
            if cek == 1:
                break
        if cek == 1:
            break
    return result


while (option != "1" or option != "2" or option != "3"):
    option = input(
        '\nHill Cipher\n1. Encrypt\n2. Decrypt\n3. Cek Kunci\n4. Exit\nInput : ')

    if (option == "1"):
        plain_text = input('Insert Plain Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        cipher_text = encrypt(plain_text, key_matrix)
        print("\nCipher Text : ", cipher_text)
    elif (option == "2"):
        cipher_text = input('Insert Cipher Text : ')
        kunci = input('Insert Kunci : ')
        kunci = kunci
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        plain_text_decrypted = decrypt(cipher_text, key_matrix)
        print("\nPlain Text : ", plain_text_decrypted)
    elif (option == "3"):
        kunci = input('Insert Kunci : ')
        kunci = kunci
        key_matrix = buatkeymatrix(kunci)
        if key_matrix is None:
            break
        determinant = int(np.round(np.linalg.det(key_matrix)))
        result = mod_inverse(determinant, 57)
        if result is not None:
            kunciditemukan = 1
            print('Modulo Invers dari {kunci} adalah ', result)
        else:
            rekomendasi = cekrekomendasi(kunci)
            print('Kunci Tersebut Tidak Memiliki Modulo Invers.')
            print('Rekomendasi : ', rekomendasi)
    elif (option == "4"):
        exit()
# Out:
# Hill Cipher
# 1. Encrypt
# 2. Decrypt
# 3. Cek Kunci
# 4. Exit
# Input : 1
# Insert Plain Text : Perjuangan B.J. Habibie Saat Kuliah di Jerman Perjuangan B.J. Habibie Saat Kuliah di Jerman Ini Akan Menginspirasi Kalian Kali ini kita akan kembali dengan kisah inspiratif dari salah satu orang hebat dari Indonesia yaitu B.J. Habibie. Beliau juga memiliki kisah hidup yang patut untuk diteladani. Salah satunya adalah kisah hidup beliau saat menyelesaikan kuliah di Jerman. Kalian penasaran dengan kisah beliau? Simak ulasannya berikut ini ya! Menimba Ilmu Di Jerman Dengan Biaya Sendiri B.J. Habibie muda merupakan salah satu anak muda Indonesia yang memiliki semangat juang tinggi dalam ilmu pendidikan. Melanjutkan pendidikan di Jerman bisa dibilang sebagai salah satu keputusan hidup yang menantang dalam hidup beliau. Sebelum melanjutkan pendidikan di Jerman, sebenarnya B.J. Habibie sudah mengambil kuliah elektro di ITB selama 6 bulan. Namun setelahnya, beliau memutuskan untuk melanjutkan pendidikan S1 dan S2 nya di Jerman. Beliau bertekad menjadi orang yang berguna bagi bangsanya dan memiliki cita-cita untuk membuat pesawat terbang yang bisa membawa rakyat Indonesia ke titik-titik maritim luas di Indonesia. Tentunya beliau ingin mimpi ini diwujudkan dengan keringat rakyat bukannya biaya hasil ekspor sumber daya alam atau utang luar negeri. Berawal dari cita-cita mulia inilah beliau melanjutkan mimpinya di Jerman. Dalam menempuh pendidikan di Jerman, beliau tidak mendapatkan beasiswa melainkan dengan biaya sendiri dari orang tuanya. Apakah jaman dulu belum ada beasiswa, atau beliau tidak mampu mendapatkannya? Faktanya, orang tua B.J. Habibie merasa bahwa pendidikan anaknya tidak boleh dibiayai oleh orang lain. Semua biaya ditanggung oleh kedua orang tuanya meskipun mereka bukan berasal dari kalangan berada. Ibu beliau memiliki usaha catering dan kos-kosan. Jerih Payah B.J. Habibie Selama Kuliah Di Jerman Demi meringankan beban orang tua dalam membiayai pendidikannya, B.J. Habibie memilih untuk tinggal jauh dari pusat kota dengan tempat tinggal yang memiliki fasilitas seadanya. Bahkan beliau juga rela untuk berjalan kaki dari tempat tinggal ke kampus hanya demi menghemat biaya transportasi. Selain itu, selama menempuh S1 dan S2 di Jerman, beliau sempat dua kali dikira telah meninggal di Jerman selama masa itu. Namun jerih payah beliau akhirnya terbayar karena meskipun menjalani pendidikan dengan biaya yang terbatas, B.J. Habibie berhasil menyelesaikan pendidikan S1 hingga S3 dengan luar biasa baik. Setelah lulus S2 akhirnya beliau bertekad untuk bekerja sebagai asisten professor hingga beliau mendapat kesempatan untuk melanjutkan S3 dengan beasiswa. Tepat saat usia 28 tahun, B.J. Habibie resmi memperoleh gelar Doktor bidang teknologi pesawat terbang di Jerman. Usia 28 tahun dengan gelar Doktor bisa dibilang usia yang sangat belia. Bahkan banyak yang tidak percaya beliau merupakan lulusan S3, mengingat wajah beliau yang baby face. Selama hidup di Jerman, B.J. Habibie menjadi terbiasa untuk mengatasi segala permasalahan sendiri. Bahkan, beliau juga masih menerapkan nilai-nilai yang sudah diajarkan orang tuanya selama di Indonesia dulu saat menjalani kehidupan di Jerman. Salah satu hal yang beliau sukai di Jerman adalah perpustakaannya. Menurut beliau, perpustakaan di Jerman buka lebih lama dan lebih bebas untuk dikunjungi. Hal ini membuat B.J. Habibie merasa memiliki kesempatan yang lebih besar dalam hal menambah wawasan dan pengetahuan selama di Jerman. Lebih dari itu, ada satu cerita lucu yang dialami beliau saat menempuh studi di Jerman. Kemampuan bahasa Jerman B.J. Habibie yang di atas rata-rata untuk orang asing membuat teman-teman beliau mempertanyakan keturunan dan juga asal usul beliau. Bahkan pada akhirnya beliau harus menjawab dengan candaan bahwa ayahnya kanibal pernah makan daging orang Jerman sehingga sejak saat itu beliau memiliki darah Jerman. Komitmen dan tekad beliau untuk menjadi yang terbaik dan melebihi orang-orang di Jerman dalam hal pengetahuan berhasil membuat beliau diakui kemampuannya oleh ...
# Insert Kunci : taliyameyswarataliyameyswarataliyameyswarataliyameyswarataliyameyswarataliyameysO
# Plain Text Bersih :  Perjuangan B.J. Habibie Saat Kuliah di Jerman Perjuangan B.J. Habibie Saat Kuliah di Jerman Ini Akan Menginspirasi Kalian Kali ini kita akan kembali dengan kisah inspiratif dari salah satu orang hebat dari Indonesia yaitu B.J. Habibie. Beliau juga memiliki kisah hidup yang patut untuk diteladani. Salah satunya adalah kisah hidup beliau saat menyelesaikan kuliah di Jerman. Kalian penasaran dengan kisah beliau? Simak ulasannya berikut ini ya! Menimba Ilmu Di Jerman Dengan Biaya Sendiri B.J. Habibie muda merupakan salah satu anak muda Indonesia yang memiliki semangat juang tinggi dalam ilmu pendidikan. Melanjutkan pendidikan di Jerman bisa dibilang sebagai salah satu keputusan hidup yang menantang dalam hidup beliau. Sebelum melanjutkan pendidikan di Jerman, sebenarnya B.J. Habibie sudah mengambil kuliah elektro di ITB selama  bulan. Namun setelahnya, beliau memutuskan untuk melanjutkan pendidikan S dan S nya di Jerman. Beliau bertekad menjadi orang yang berguna bagi bangsanya dan memiliki citacita untuk membuat pesawat terbang yang bisa membawa rakyat Indonesia ke titiktitik maritim luas di Indonesia. Tentunya beliau ingin mimpi ini diwujudkan dengan keringat rakyat bukannya biaya hasil ekspor sumber daya alam atau utang luar negeri. Berawal dari citacita mulia inilah beliau melanjutkan mimpinya di Jerman. Dalam menempuh pendidikan di Jerman, beliau tidak mendapatkan beasiswa melainkan dengan biaya sendiri dari orang tuanya. Apakah jaman dulu belum ada beasiswa, atau beliau tidak mampu mendapatkannya? Faktanya, orang tua B.J. Habibie merasa bahwa pendidikan anaknya tidak boleh dibiayai oleh orang lain. Semua biaya ditanggung oleh kedua orang tuanya meskipun mereka bukan berasal dari kalangan berada. Ibu beliau memiliki usaha catering dan koskosan. Jerih Payah B.J. Habibie Selama Kuliah Di Jerman Demi meringankan beban orang tua dalam membiayai pendidikannya, B.J. Habibie memilih untuk tinggal jauh dari pusat kota dengan tempat tinggal yang memiliki fasilitas seadanya. Bahkan beliau juga rela untuk berjalan kaki dari tempat tinggal ke kampus hanya demi menghemat biaya transportasi. Selain itu, selama menempuh S dan S di Jerman, beliau sempat dua kali dikira telah meninggal di Jerman selama masa itu. Namun jerih payah beliau akhirnya terbayar karena meskipun menjalani pendidikan dengan biaya yang terbatas, B.J. Habibie berhasil menyelesaikan pendidikan S hingga S dengan luar biasa baik. Setelah lulus S akhirnya beliau bertekad untuk bekerja sebagai asisten professor hingga beliau mendapat kesempatan untuk melanjutkan S dengan beasiswa. Tepat saat usia  tahun, B.J. Habibie resmi memperoleh gelar Doktor bidang teknologi pesawat terbang di Jerman. Usia  tahun dengan gelar Doktor bisa dibilang usia yang sangat belia. Bahkan banyak yang tidak percaya beliau merupakan lulusan S, mengingat wajah beliau yang baby face. Selama hidup di Jerman, B.J. Habibie menjadi terbiasa untuk mengatasi segala permasalahan sendiri. Bahkan, beliau juga masih menerapkan nilainilai yang sudah diajarkan orang tuanya selama di Indonesia dulu saat menjalani kehidupan di Jerman. Salah satu hal yang beliau sukai di Jerman adalah perpustakaannya. Menurut beliau, perpustakaan di Jerman buka lebih lama dan lebih bebas untuk dikunjungi. Hal ini membuat B.J. Habibie merasa memiliki kesempatan yang lebih besar dalam hal menambah wawasan dan pengetahuan selama di Jerman. Lebih dari itu, ada satu cerita lucu yang dialami beliau saat menempuh studi di Jerman. Kemampuan bahasa Jerman B.J. Habibie yang di atas ratarata untuk orang asing membuat temanteman beliau mempertanyakan keturunan dan juga asal usul beliau. Bahkan pada akhirnya beliau harus menjawab dengan candaan bahwa ayahnya kanibal pernah makan daging orang Jerman sehingga sejak saat itu beliau memiliki darah Jerman. Komitmen dan tekad beliau untuk menjadi yang terbaik dan melebihi orangorang di Jerman dalam hal pengetahuan berhasil membuat beliau diakui kemampuannya oleh dunia. Bahkan hingga ...
# Key Matrix :
#  [[46 27 38 35 51 27 39 31 51]
#  [45 49 27 44 27 46 27 38 35]
#  [51 27 39 31 51 45 49 27 44]
#  [27 46 27 38 35 51 27 39 31]
#  [51 45 49 27 44 27 46 27 38]
#  [35 51 27 39 31 51 45 49 27]
#  [44 27 46 27 38 35 51 27 39]
#  [31 51 45 49 27 44 27 46 27]
#  [38 35 51 27 39 31 51 45 14]]
#
# Plaintext :  [15 31 44 36 47 27 40 33 27]
# Ciphertext :  [31 40  1 11 43 50 36  3 44]
# Ciphertext :  enBLqxjDr
#
# Plaintext :  [40 26  1 55  9 55 26  7 27]
# Ciphertext :  [51  4 39 34 30 21 50 32  4]
# Ciphertext :  yEmhdVxfE
#
# Plaintext :  [28 35 28 35 31 26 18 27 27]
# Ciphertext :  [31 14 11  5 51  3 21 34 11]
# Ciphertext :  eOLFyDVhL
#
# Plaintext :  [46 26 10 47 38 35 27 34 26]
# Ciphertext :  [44 20 51 39 39 14  2  8 15]
# Ciphertext :  rUymmOCIP
#
# Plaintext :  [30 35 26  9 31 44 39 27 40]
# Ciphertext :  [22 15 44 50 45 22 41 43 11]
# Ciphertext :  WPrxsWoqL
#
# Plaintext :  [26 15 31 44 36 47 27 40 33]
# Ciphertext :  [ 0 44 26 40 22  8 33 51  9]
# Ciphertext :  Ar nWIgyJ
#
# Plaintext :  [27 40 26  1 55  9 55 26  7]
# Ciphertext :  [11 45 43 30 37 24 43 12 16]
# Ciphertext :  LsqdkYqMQ
#
# Plaintext :  [27 28 35 28 35 31 26 18 27]
# Ciphertext :  [18  4  6 10 47 53 14 33 39]
# Ciphertext :  SEGKu!Ogm
#
# Plaintext :  [27 46 26 10 47 38 35 27 34]
# Ciphertext :  [ 9 16 20 17 31 23 22  2  3]
# Ciphertext :  JQUReXWCD
#
# Plaintext :  [26 30 35 26  9 31 44 39 27]
# Ciphertext :  [40 38 13 52 55 49 11 15 11]
# Ciphertext :  nlNz.wLPL
#
# Plaintext :  [40 26  8 40 35 26  0 37 27]
# Ciphertext :  [23 23 31  8  0 50 51  1 38]
# Ciphertext :  XXeIAxyBl
#
# Plaintext :  [40 26 12 31 40 33 35 40 45]
# Ciphertext :  [ 1  0 45 45  1 19 31 42 18]
# Ciphertext :  BAssBTepS
#
# Plaintext :  [42 35 44 27 45 35 26 10 27]
# Ciphertext :  [35  3 44 44 49  7 15 35 15]
# Ciphertext :  iDrrwHPiP
#
# Plaintext :  [38 35 27 40 26 10 27 38 35]
# Ciphertext :  [15 43 11 25 41 26 13 43 52]
# Ciphertext :  PqLZo Nqz
#
# Plaintext :  [26 35 40 35 26 37 35 46 27]
# Ciphertext :  [36 33 25 37 28 22  8 28 21]
# Ciphertext :  jgZkbWIbV
#
# Plaintext :  [26 27 37 27 40 26 37 31 39]
# Ciphertext :  [11 10 55 23 52 27 35 43 27]
# Ciphertext :  LK.Xzaiqa
#
# Plaintext :  [28 27 38 35 26 30 31 40 33]
# Ciphertext :  [10 27 51 11 49 44 38 31 20]
# Ciphertext :  KayLwrleU
#
# Plaintext :  [27 40 26 37 35 45 27 34 26]
# Ciphertext :  [37 51 14  0 10  9 18 38  9]
# Ciphertext :  kyOAKJSlJ
#
# Plaintext :  [35 40 45 42 35 44 27 46 35]
# Ciphertext :  [54 45 55 19 14 10 24 28  0]
# Ciphertext :  ?s.TOKYbA
#
# Plaintext :  [32 26 30 27 44 35 26 45 27]
# Ciphertext :  [ 5 37 38 27 33 48 51 48 28]
# Ciphertext :  Fklagvyvb
#
# Plaintext :  [38 27 34 26 45 27 46 47 26]
# Ciphertext :  [25 33 37  6  6  3 38 12 44]
# Ciphertext :  ZgkGGDlMr
#
# Plaintext :  [41 44 27 40 33 26 34 31 28]
# Ciphertext :  [29 25 19 26  9 38 26 26 54]
# Ciphertext :  cZT Jl  ?
#
# Plaintext :  [27 46 26 30 27 44 35 26  8]
# Ciphertext :  [33 26 30 51 35 23 54 15 53]
# Ciphertext :  g dyiX?P!
#
# Plaintext :  [40 30 41 40 31 45 35 27 26]
# Ciphertext :  [19 12  1 42 16 27 18 26 24]
# Ciphertext :  TMBpQaS Y
#
# Plaintext :  [51 27 35 46 47 26  1 55  9]
# Ciphertext :  [31 27 47 18 16 39 34 30 29]
# Ciphertext :  eauSQmhdc
#
# Plaintext :  [55 26  7 27 28 35 28 35 31]
# Ciphertext :  [29  4 15 53 33 14 12 22 10]
# Ciphertext :  cEP!gOMWK
#
# Plaintext :  [55 26  1 31 38 35 27 47 26]
# Ciphertext :  [16 29 14 52 33 42 17 38 51]
# Ciphertext :  QcOzgpRly
#
# Plaintext :  [36 47 33 27 26 39 31 39 35]
# Ciphertext :  [21 15 53 50 48 50 52  3 17]
# Ciphertext :  VP!xvxzDR
#
# Plaintext :  [38 35 37 35 26 37 35 45 27]
# Ciphertext :  [44 55 37 13 10 27 29 48 51]
# Ciphertext :  r.kNKacvy
#
# Plaintext :  [34 26 34 35 30 47 42 26 51]
# Ciphertext :  [30  0 44 24 22 13 13 12 20]
# Ciphertext :  dArYWNNMU
#
# Plaintext :  [27 40 33 26 42 27 46 47 46]
# Ciphertext :  [15 26  2 54 39 17 12  7 22]
# Ciphertext :  P C?mRMHW
#
# Plaintext :  [26 47 40 46 47 37 26 30 35]
# Ciphertext :  [ 9 18 43 40 50  0 50 14 34]
# Ciphertext :  JSqnxAxOh
#
# Plaintext :  [46 31 38 27 30 27 40 35 55]
# Ciphertext :  [55 49  6 11 32 37 13 15 36]
# Ciphertext :  .wGLfkNPj
#
# Plaintext :  [26 18 27 38 27 34 26 45 27]
# Ciphertext :  [30 14 25 43 53 55 18 39 53]
# Ciphertext :  dOZq!.Sm!
#
# Plaintext :  [46 47 40 51 27 26 27 30 27]
# Ciphertext :  [45 10 27 29 55 56  1  8 32]
# Ciphertext :  sKac.,BIf
#
# Plaintext :  [38 27 34 26 37 35 45 27 34]
# Ciphertext :  [38 20 37 31 44 38 20 44 53]
# Ciphertext :  lUkerlUr!
#
# Plaintext :  [26 34 35 30 47 42 26 28 31]
# Ciphertext :  [31 38 22  6 28 52 28 15 41]
# Ciphertext :  elWGbzbPo
#
# Plaintext :  [38 35 27 47 26 45 27 27 46]
# Ciphertext :  [ 0 47 52 50 42 18 20  7 16]
# Ciphertext :  AuzxpSUHQ
#
# Plaintext :  [26 39 31 40 51 31 38 31 45]
# Ciphertext :  [ 7  5 51 50  3 20  1 18 14]
# Ciphertext :  HFyxDUBSO
#
# Plaintext :  [27 35 37 27 40 26 37 47 38]
# Ciphertext :  [34 51 26 42  2 30  4 51 25]
# Ciphertext :  hy pCdEyZ
#
# Plaintext :  [35 27 34 26 30 35 26  9 31]
# Ciphertext :  [29 47 30 50 47  7 45 50 11]
# Ciphertext :  cudxuHsxL
#
# Plaintext :  [44 39 27 40 55 26 10 27 38]
# Ciphertext :  [34  2 30 39 16 20 31 10 43]
# Ciphertext :  hCdmQUeKq
#
# Plaintext :  [35 27 40 26 42 31 40 27 45]
# Ciphertext :  [14 20 33  4 29  4 46  0 44]
# Ciphertext :  OUgEcEtAr
#
# Plaintext :  [27 44 27 40 26 30 31 40 33]
# Ciphertext :  [ 9 54 14 32 17 33 25 47 37]
# Ciphertext :  J?OfRgZuk
#
# Plaintext :  [27 40 26 37 35 45 27 34 26]
# Ciphertext :  [37 51 14  0 10  9 18 38  9]
# Ciphertext :  kyOAKJSlJ
#
# Plaintext :  [28 31 38 35 27 47 54 26 18]
# Ciphertext :  [41 26 38 23 44  7 20 12 33]
# Ciphertext :  o lXrHUMg
#
# Plaintext :  [35 39 27 37 26 47 38 27 45]
# Ciphertext :  [52 22 54 27 36 12 33 43 39]
# Ciphertext :  zW?ajMgqm
#
# Plaintext :  [27 40 40 51 27 26 28 31 44]
# Ciphertext :  [33 42 35 15  3 43  2 50 26]
# Ciphertext :  gpiPDqCx
#
# Plaintext :  [35 37 47 46 26 35 40 35 26]
# Ciphertext :  [49  1 54 39 32 44 14 36 30]
# Ciphertext :  wB?mfrOjd
#
# Plaintext :  [51 27 53 26 12 31 40 35 39]
# Ciphertext :  [55 33  6 34 36 44 19 21 22]
# Ciphertext :  .gGhjrTVW
#
# Plaintext :  [28 27 26  8 38 39 47 26  3]
# Ciphertext :  [ 5 41 46 35 32 33 50 32 47]
# Ciphertext :  Fotifgxfu
#
# Plaintext :  [35 26  9 31 44 39 27 40 26]
# Ciphertext :  [53 52  2 40 44  4 26 22 27]
# Ciphertext :  !zCnrE Wa
#
# Plaintext :  [ 3 31 40 33 27 40 26  1 35]
# Ciphertext :  [45 56 15 45 43 31  9 39 19]
# Ciphertext :  s,PsqeJmT
#
# Plaintext :  [27 51 27 26 18 31 40 30 35]
# Ciphertext :  [40  0  7 21 20 15  5 10  2]
# Ciphertext :  nAHVUPFKC
#
# Plaintext :  [44 35 26  1 55  9 55 26  7]
# Ciphertext :  [31 52 34 31 52 22 29 56 31]
# Ciphertext :  ezhezWc,e
#
# Plaintext :  [27 28 35 28 35 31 26 39 47]
# Ciphertext :  [36 20 28 24  6 26 50  0 10]
# Ciphertext :  jUbYG xAK
#
# Plaintext :  [30 27 26 39 31 44 47 42 27]
# Ciphertext :  [ 1 20 14 23 33 46 29  7 17]
# Ciphertext :  BUOXgtcHR
#
# Plaintext :  [37 27 40 26 45 27 38 27 34]
# Ciphertext :  [25 24 39 20 44 32 33 15 28]
# Ciphertext :  ZYmUrfgPb
#
# Plaintext :  [26 45 27 46 47 26 27 40 27]
# Ciphertext :  [17 45 37  3  7 46 48 26 33]
# Ciphertext :  RskDHtv g
#
# Plaintext :  [37 26 39 47 30 27 26  8 40]
# Ciphertext :  [34 30 48 25 46 25 35 20 23]
# Ciphertext :  hdvZtZiUX
#
# Plaintext :  [30 41 40 31 45 35 27 26 51]
# Ciphertext :  [24 46 16 10 40 50 23 28 39]
# Ciphertext :  YtQKnxXbm
#
# Plaintext :  [27 40 33 26 39 31 39 35 38]
# Ciphertext :  [ 0  2 36 46 34 35 14  0 46]
# Ciphertext :  ACjthiOAt
#
# Plaintext :  [35 37 35 26 45 31 39 27 40]
# Ciphertext :  [10 26 49 24 16  7 11 33 21]
# Ciphertext :  K wYQHLgV
#
# Plaintext :  [33 27 46 26 36 47 27 40 33]
# Ciphertext :  [16 47 50 46 28 55 14 46  5]
# Ciphertext :  Quxtb.OtF
#
# Plaintext :  [26 46 35 40 33 33 35 26 30]
# Ciphertext :  [43  7 51  9 16 42 27 11 33]
# Ciphertext :  qHyJQpaLg
#
# Plaintext :  [27 38 27 39 26 35 38 39 47]
# Ciphertext :  [48 17  9 44 55 17 32 34  7]
# Ciphertext :  vRJr.RfhH
#
# Plaintext :  [26 42 31 40 30 35 30 35 37]
# Ciphertext :  [11 52 30 33 12 30  9 45 53]
# Ciphertext :  LzdgMdJs!
#
# Plaintext :  [27 40 55 26 12 31 38 27 40]
# Ciphertext :  [15  5 24 45 23 36 39 34 17]
# Ciphertext :  PFYsXjmhR
#
# Plaintext :  [36 47 46 37 27 40 26 42 31]
# Ciphertext :  [10 34 56 41 41  3 36 18 46]
# Ciphertext :  Kh,ooDjSt
#
# Plaintext :  [40 30 35 30 35 37 27 40 26]
# Ciphertext :  [33 55  1 36 22 38 28 31 46]
# Ciphertext :  g.BjWlbet
#
# Plaintext :  [30 35 26  9 31 44 39 27 40]
# Ciphertext :  [22 15 44 50 45 22 41 43 11]
# Ciphertext :  WPrxsWoqL
#
# Plaintext :  [26 28 35 45 27 26 30 35 28]
# Ciphertext :  [17 24 35 41 22 21 25  5  7]
# Ciphertext :  RYioWVZFH
#
# Plaintext :  [35 38 27 40 33 26 45 31 28]
# Ciphertext :  [20 43 33 56 53 17 47  2  6]
# Ciphertext :  Uqg,!RuCG
#
# Plaintext :  [27 33 27 35 26 45 27 38 27]
# Ciphertext :  [45 47  8 14 10  1 25 52  3]
# Ciphertext :  suIOKBZzD
#
# Plaintext :  [34 26 45 27 46 47 26 37 31]
# Ciphertext :  [23  5 16 11 21  1 11 24 46]
# Ciphertext :  XFQLVBLYt
#
# Plaintext :  [42 47 46 47 45 27 40 26 34]
# Ciphertext :  [38 51 23 55 16 26  1 46 24]
# Ciphertext :  lyX.Q BtY
#
# Plaintext :  [35 30 47 42 26 51 27 40 33]
# Ciphertext :  [43 17 39 43 15 25 22 27  4]
# Ciphertext :  qRmqPZWaE
#
# Plaintext :  [26 39 31 40 27 40 46 27 40]
# Ciphertext :  [42  2 37 30  1 49 22  5 28]
# Ciphertext :  pCkdBwWFb
#
# Plaintext :  [33 26 30 27 38 27 39 26 34]
# Ciphertext :  [32 53 26  4 12 16 10 29  3]
# Ciphertext :  f! EMQKcD
#
# Plaintext :  [35 30 47 42 26 28 31 38 35]
# Ciphertext :  [17 30 32 45 56 14 15 54  3]
# Ciphertext :  Rdfs,OP?D
#
# Plaintext :  [27 47 55 26 18 31 28 31 38]
# Ciphertext :  [28 37 49  2  3 43 33 14 24]
# Ciphertext :  bkwCDqgOY
#
# Plaintext :  [47 39 26 39 31 38 27 40 36]
# Ciphertext :  [49 55 12 47 19 21 54 37 27]
# Ciphertext :  w.MuTV?ka
#
# Plaintext :  [47 46 37 27 40 26 42 31 40]
# Ciphertext :  [26  4 47 34 23 45 56  1 49]
# Ciphertext :   EuhXs,Bw
#
# Plaintext :  [30 35 30 35 37 27 40 26 30]
# Ciphertext :  [30  1 15 53 45 18 23 52 34]
# Ciphertext :  dBP!sSXzh
#
# Plaintext :  [35 26  9 31 44 39 27 40 56]
# Ciphertext :  [44 19 11  1 44 16 56 34 48]
# Ciphertext :  rTLBrQ,hv
#
# Plaintext :  [26 45 31 28 31 40 27 44 40]
# Ciphertext :  [ 2  9 15 26 50 46 15 43 37]
# Ciphertext :  CJP xtPqk
#
# Plaintext :  [51 27 26  1 55  9 55 26  7]
# Ciphertext :  [23 32  4 23 49 30  7 36 17]
# Ciphertext :  XfEXwdHjR
#
# Plaintext :  [27 28 35 28 35 31 26 45 47]
# Ciphertext :  [51 20 19 30 54 35 41 48 52]
# Ciphertext :  yUTd?iovz
#
# Plaintext :  [30 27 34 26 39 31 40 33 27]
# Ciphertext :  [39  5 15 19 23  9 36 25 19]
# Ciphertext :  mFPTXJjZT
#
# Plaintext :  [39 28 35 38 26 37 47 38 35]
# Ciphertext :  [19  2 38 20 54 10 38 54  4]
# Ciphertext :  TClU?Kl?E
#
# Plaintext :  [27 34 26 31 38 31 37 46 44]
# Ciphertext :  [37  1 54 12  2 30 56 40 52]
# Ciphertext :  kB?MCd,nz
#
# Plaintext :  [41 26 30 35 26  8 19  1 26]
# Ciphertext :  [43 20  1 51 33  4 15 54  2]
# Ciphertext :  qUBygEP?C
#
# Plaintext :  [45 31 38 27 39 27 26 26 28]
# Ciphertext :  [33  7  7 44  3 20 11 17 49]
# Ciphertext :  gHHrDULRw
#
# Plaintext :  [47 38 27 40 55 26 13 27 39]
# Ciphertext :  [28 33  5 15 15  8 43 46  4]
# Ciphertext :  bgFPPIqtE
#
# Plaintext :  [47 40 26 45 31 46 31 38 27]
# Ciphertext :  [23 54 46 24  2 40 37 51  4]
# Ciphertext :  X?tYCnkyE
#
# Plaintext :  [34 40 51 27 56 26 28 31 38]
# Ciphertext :  [23  0 38 19 45 44 10 36 55]
# Ciphertext :  XAlTsrKj.
#
# Plaintext :  [35 27 47 26 39 31 39 47 46]
# Ciphertext :  [18 41  4 17 31 36 41 14  7]
# Ciphertext :  SoERejoOH
#
# Plaintext :  [47 45 37 27 40 26 47 40 46]
# Ciphertext :  [38 15 31 33 52 24 20 34 17]
# Ciphertext :  lPegzYUhR
#
# Plaintext :  [47 37 26 39 31 38 27 40 36]
# Ciphertext :  [52 14 15 12 43 33  0 49 14]
# Ciphertext :  zOPMqgAwO
#
# Plaintext :  [47 46 37 27 40 26 42 31 40]
# Ciphertext :  [26  4 47 34 23 45 56  1 49]
# Ciphertext :   EuhXs,Bw
#
# Plaintext :  [30 35 30 35 37 27 40 26 18]
# Ciphertext :  [45 37  0 23 45 36 11 13 37]
# Ciphertext :  skAXsjLNk
#
# Plaintext :  [26 30 27 40 26 18 26 40 51]
# Ciphertext :  [41  7 48 27 36 16 29 37 46]
# Ciphertext :  oHvajQckt
#
# Plaintext :  [27 26 30 35 26  9 31 44 39]
# Ciphertext :  [ 9 25  0 19 14 55  4 37  7]
# Ciphertext :  JZATO.EkH
#
# Plaintext :  [27 40 55 26  1 31 38 35 27]
# Ciphertext :  [ 8 13 19 25  2 21 14 39 51]
# Ciphertext :  INTZCVOmy
#
# Plaintext :  [47 26 28 31 44 46 31 37 27]
# Ciphertext :  [34 31  5  2 36 43 11 15 42]
# Ciphertext :  heFCjqLPp
#
# Plaintext :  [30 26 39 31 40 36 27 30 35]
# Ciphertext :  [29 41 20 26 48  1 41 19 53]
# Ciphertext :  coU vBoT!
#
# Plaintext :  [26 41 44 27 40 33 26 51 27]
# Ciphertext :  [24 53 38 13 51 23 35 26  8]
# Ciphertext :  Y!lNyXi I
#
# Plaintext :  [40 33 26 28 31 44 33 47 40]
# Ciphertext :  [54 34 24 29 45 11 34  2  3]
# Ciphertext :  ?hYcsLhCD
#
# Plaintext :  [27 26 28 27 33 35 26 28 27]
# Ciphertext :  [36 12 53 44 48 13  2 35 24]
# Ciphertext :  jM!rvNCiY
#
# Plaintext :  [40 33 45 27 40 51 27 26 30]
# Ciphertext :  [51 43 36 56 26  8 34 18  8]
# Ciphertext :  yqj, IhSI
#
# Plaintext :  [27 40 26 39 31 39 35 38 35]
# Ciphertext :  [ 9 39 42 53 31  0  7  8 36]
# Ciphertext :  Jmp!eAHIj
#
# Plaintext :  [37 35 26 29 35 46 27 29 35]
# Ciphertext :  [14 18 48 42 28 12 16 43 44]
# Ciphertext :  OSvpbMQqr
#
# Plaintext :  [46 27 26 47 40 46 47 37 26]
# Ciphertext :  [13  5 23 38 31  1 47  0 46]
# Ciphertext :  NFXleBuAt
#
# Plaintext :  [39 31 39 28 47 27 46 26 42]
# Ciphertext :  [22 28  8  4 38 34 37 33  2]
# Ciphertext :  WbIElhkgC
#
# Plaintext :  [31 45 27 49 27 46 26 46 31]
# Ciphertext :  [52 40 41 48 43 12 43 56 20]
# Ciphertext :  znovqMq,U
#
# Plaintext :  [44 28 27 40 33 26 51 27 40]
# Ciphertext :  [31 46 24 46  2 49 41 16  7]
# Ciphertext :  etYtCwoQH
#
# Plaintext :  [33 26 28 35 45 27 26 39 31]
# Ciphertext :  [51  8 21 49 20  6 28  2 42]
# Ciphertext :  yIVwUGbCp
#
# Plaintext :  [39 28 27 49 27 26 44 27 37]
# Ciphertext :  [11 46  8 46 31 42 46 41 54]
# Ciphertext :  LtItepto?
#
# Plaintext :  [51 27 46 26  8 40 30 41 40]
# Ciphertext :  [17 29 49 45 13  4  7 27 18]
# Ciphertext :  RcwsNEHaS
#
# Plaintext :  [31 45 35 27 26 37 31 26 46]
# Ciphertext :  [31  1 36  8 42 12 49 17 50]
# Ciphertext :  eBjIpMwRx
#
# Plaintext :  [35 46 35 37 46 35 46 35 37]
# Ciphertext :  [25 11 37 21 40 46 45  0 46]
# Ciphertext :  ZLkVntsAt
#
# Plaintext :  [26 39 27 44 35 46 35 39 26]
# Ciphertext :  [ 0  3 23 55 55 24 19 36 42]
# Ciphertext :  ADX..YTjp
#
# Plaintext :  [38 47 27 45 26 30 35 26  8]
# Ciphertext :  [16 16 42 14 46 41 32 31 33]
# Ciphertext :  QQpOtofeg
#
# Plaintext :  [40 30 41 40 31 45 35 27 55]
# Ciphertext :  [16  1 23 29 35 12  9 11 31]
# Ciphertext :  QBXciMJLe
#
# Plaintext :  [26 19 31 40 46 47 40 51 27]
# Ciphertext :  [51 38 50 47  4 17 56 55 23]
# Ciphertext :  ylxuER,.X
#
# Plaintext :  [26 28 31 38 35 27 47 26 35]
# Ciphertext :  [55  4 44 38 23 53 33 33  4]
# Ciphertext :  .ErlX!ggE
#
# Plaintext :  [40 33 35 40 26 39 35 39 42]
# Ciphertext :  [16 32  9 45  8  7 29 38 35]
# Ciphertext :  QfJsIHcli
#
# Plaintext :  [35 26 35 40 35 26 30 35 49]
# Ciphertext :  [28 36 21 21 38 56 44 36  9]
# Ciphertext :  bjVVl,rjJ
#
# Plaintext :  [47 36 47 30 37 27 40 26 30]
# Ciphertext :  [56 28 49 29  2 16 20 10 22]
# Ciphertext :  ,bwcCQUKW
#
# Plaintext :  [31 40 33 27 40 26 37 31 44]
# Ciphertext :  [11 27 41  5 31 37 47 18 25]
# Ciphertext :  LaoFekuSZ
#
# Plaintext :  [35 40 33 27 46 26 44 27 37]
# Ciphertext :  [ 8 47 22 25 48  8 28  6 34]
# Ciphertext :  IuWZvIbGh
#
# Plaintext :  [51 27 46 26 28 47 37 27 40]
# Ciphertext :  [39 35 38  4  0 40 22 21  1]
# Ciphertext :  milEAnWVB
#
# Plaintext :  [40 51 27 26 28 35 27 51 27]
# Ciphertext :  [23  9 26  6 41 15  5  4 40]
# Ciphertext :  XJ GoPFEn
#
# Plaintext :  [26 34 27 45 35 38 26 31 37]
# Ciphertext :  [45 13 13 39 56 40 12 19  7]
# Ciphertext :  sNNm,nMTH
#
# Plaintext :  [45 42 41 44 26 45 47 39 28]
# Ciphertext :  [32  6 24 21 55  2 12 17 17]
# Ciphertext :  fGYV.CMRR
#
# Plaintext :  [31 44 26 30 27 51 27 26 27]
# Ciphertext :  [40 24 27 56  8  1 13 15 39]
# Ciphertext :  nYa,IBNPm
#
# Plaintext :  [38 27 39 26 27 46 27 47 26]
# Ciphertext :  [38 43 36 24 10 36 21 17 15]
# Ciphertext :  lqjYKjVRP
#
# Plaintext :  [47 46 27 40 33 26 38 47 27]
# Ciphertext :  [48 48 51 12 14 33 29 48  8]
# Ciphertext :  vvyMOgcvI
#
# Plaintext :  [44 26 40 31 33 31 44 35 55]
# Ciphertext :  [ 5 32 44  8 50  0 49  7 41]
# Ciphertext :  FfrIxAwHo
#
# Plaintext :  [26  1 31 44 27 49 27 38 26]
# Ciphertext :  [52 26  0 28 41 27 25 41 11]
# Ciphertext :  z AboaZoL
#
# Plaintext :  [30 27 44 35 26 29 35 46 27]
# Ciphertext :  [54 17 37 47 23 24 43 28 20]
# Ciphertext :  ?RkuXYqbU
#
# Plaintext :  [29 35 46 27 26 39 47 38 35]
# Ciphertext :  [ 6 28  9 53 41 44  9 31 24]
# Ciphertext :  GbJ!orJeY
#
# Plaintext :  [27 26 35 40 35 38 27 34 26]
# Ciphertext :  [31 45 50 40 55 39  4 24 13]
# Ciphertext :  esxn.mEYN
#
# Plaintext :  [28 31 38 35 27 47 26 39 31]
# Ciphertext :  [15 48 45  6  0 20 20 34 56]
# Ciphertext :  PvsGAUUh,
#
# Plaintext :  [38 27 40 36 47 46 37 27 40]
# Ciphertext :  [49 24 33 29  8  9 17 22 10]
# Ciphertext :  wYgcIJRWK
#
# Plaintext :  [26 39 35 39 42 35 40 51 27]
# Ciphertext :  [ 9 23 28  0  3 28 10  0 30]
# Ciphertext :  JXbADbKAd
#
# Plaintext :  [26 30 35 26  9 31 44 39 27]
# Ciphertext :  [40 38 13 52 55 49 11 15 11]
# Ciphertext :  nlNz.wLPL
#
# Plaintext :  [40 55 26  3 27 38 27 39 26]
# Ciphertext :  [35 40 10 48 24 56  5 44 34]
# Ciphertext :  inKvY,Frh
#
# Plaintext :  [39 31 40 31 39 42 47 34 26]
# Ciphertext :  [32 33 25 17 46 16 28  5 18]
# Ciphertext :  fgZRtQbFS
#
# Plaintext :  [42 31 40 30 35 30 35 37 27]
# Ciphertext :  [24 30 23 44 37  6 38 52 26]
# Ciphertext :  YdXrkGlz
#
# Plaintext :  [40 26 30 35 26  9 31 44 39]
# Ciphertext :  [37 40 36 28 50 54  6 41 45]
# Ciphertext :  knjbx?Gos
#
# Plaintext :  [27 40 56 26 28 31 38 35 27]
# Ciphertext :  [55 28 10 28 42 30  3 15 15]
# Ciphertext :  .bKbpdDPP
#
# Plaintext :  [47 26 46 35 30 27 37 26 39]
# Ciphertext :  [22  4 15 27 47 21 56 15 26]
# Ciphertext :  WEPauV,P
#
# Plaintext :  [31 40 30 27 42 27 46 37 27]
# Ciphertext :  [38 36 40 52 43 24 35 41 16]
# Ciphertext :  ljnzqYioQ
#
# Plaintext :  [40 26 28 31 27 45 35 45 49]
# Ciphertext :  [ 2 51  2 41 26 44 15 23 11]
# Ciphertext :  CyCo rPXL
#
# Plaintext :  [27 26 39 31 38 27 35 40 37]
# Ciphertext :  [42 47 53 27 50 51 46 35 12]
# Ciphertext :  pu!axytiM
#
# Plaintext :  [27 40 26 30 31 40 33 27 40]
# Ciphertext :  [13 19 32  4 15  4 51 41 38]
# Ciphertext :  NTfEPEyol
#
# Plaintext :  [26 28 35 27 51 27 26 45 31]
# Ciphertext :  [33 18 40 53 21 49 42 20 35]
# Ciphertext :  gSn!VwpUi
#
# Plaintext :  [40 30 35 44 35 26 30 27 44]
# Ciphertext :  [ 3 40 15 25  4  7 12 31 17]
# Ciphertext :  DnPZEHMeR
#
# Plaintext :  [35 26 41 44 27 40 33 26 46]
# Ciphertext :  [51 37 31  7 19 54  8 32 23]
# Ciphertext :  ykeHT?IfX
#
# Plaintext :  [47 27 40 51 27 55 26  0 42]
# Ciphertext :  [16 52 17 54 45 10 16 34 47]
# Ciphertext :  QzR?sKQhu
#
# Plaintext :  [27 37 27 34 26 36 27 39 27]
# Ciphertext :  [20 51 49 25  4 41 46 28 53]
# Ciphertext :  UywZEotb!
#
# Plaintext :  [40 26 30 47 38 47 26 28 31]
# Ciphertext :  [27 21 48 11 50 11 34 56 16]
# Ciphertext :  aVvLxLh,Q
#
# Plaintext :  [38 47 39 26 27 30 27 26 28]
# Ciphertext :  [53 15  4 55 44  6 25 48 43]
# Ciphertext :  !PE.rGZvq
#
# Plaintext :  [31 27 45 35 45 49 27 56 26]
# Ciphertext :  [55 55  6 48 52 31 10  4 16]
# Ciphertext :  ..GvzeKEQ
#
# Plaintext :  [27 46 27 47 26 28 31 38 35]
# Ciphertext :  [ 9 20  1 44 36 34 51 24  1]
# Ciphertext :  JUBrjhyYB
#
# Plaintext :  [27 47 26 46 35 30 27 37 26]
# Ciphertext :  [ 1 43  2 16 16 42  6 29 53]
# Ciphertext :  BqCQQpGc!
#
# Plaintext :  [39 27 39 42 47 26 39 31 40]
# Ciphertext :  [43 48 50 17  3 30 29  2 49]
# Ciphertext :  qvxRDdcCw
#
# Plaintext :  [30 27 42 27 46 37 27 40 40]
# Ciphertext :  [16 17 26  9 28 41 28 12  6]
# Ciphertext :  QR JbobMG
#
# Plaintext :  [51 27 54 26  5 27 37 46 27]
# Ciphertext :  [38  3 42 44 56 15 19 30 21]
# Ciphertext :  lDpr,PTdV
#
# Plaintext :  [40 51 27 56 26 41 44 27 40]
# Ciphertext :  [ 5 14  0 54 14  1 22 22 15]
# Ciphertext :  FOA?OBWWP
#
# Plaintext :  [33 26 46 47 27 26  1 55  9]
# Ciphertext :  [34 52 24 33 50 43 14 52 30]
# Ciphertext :  hzYgxqOzd
#
# Plaintext :  [55 26  7 27 28 35 28 35 31]
# Ciphertext :  [29  4 15 53 33 14 12 22 10]
# Ciphertext :  cEP!gOMWK
#
# Plaintext :  [26 39 31 44 27 45 27 26 28]
# Ciphertext :  [16  7 40 26 27 30 38 51 21]
# Ciphertext :  QHn adlyV
#
# Plaintext :  [27 34 49 27 26 42 31 40 30]
# Ciphertext :  [ 6 33 37 20 48 27 35 52 47]
# Ciphertext :  GgkUvaizu
#
# Plaintext :  [35 30 35 37 27 40 26 27 40]
# Ciphertext :  [50 29 20 54 48 22 56  2 13]
# Ciphertext :  xcU?vW,CN
#
# Plaintext :  [27 37 40 51 27 26 46 35 30]
# Ciphertext :  [ 7 43 43 28 44  5  2 18 25]
# Ciphertext :  HqqbrFCSZ
#
# Plaintext :  [27 37 26 28 41 38 31 34 26]
# Ciphertext :  [28 26 12 51  5 27 52 33 53]
# Ciphertext :  b MyFazg!
#
# Plaintext :  [30 35 28 35 27 51 27 35 26]
# Ciphertext :  [ 2  5 51  8 47 56 43 19 29]
# Ciphertext :  CFyIu,qTc
#
# Plaintext :  [41 38 31 34 26 41 44 27 40]
# Ciphertext :  [51 44 29  9 51 48 46 31  6]
# Ciphertext :  yrcJyvteG
#
# Plaintext :  [33 26 38 27 35 40 55 26 18]
# Ciphertext :  [ 0 31 52 30 10  7 56 25 35]
# Ciphertext :  AezdKH,Zi
#
# Plaintext :  [31 39 47 27 26 28 35 27 51]
# Ciphertext :  [11 52 38 13  5 49 37 30 36]
# Ciphertext :  LzlNFwkdj
#
# Plaintext :  [27 26 30 35 46 27 40 33 33]
# Ciphertext :  [22 39  0 11 15 43 11 32 28]
# Ciphertext :  WmALPqLfb
#
# Plaintext :  [47 40 33 26 41 38 31 34 26]
# Ciphertext :  [28 34 13 44 24 22 27 54 24]
# Ciphertext :  bhNrYWa?Y
#
# Plaintext :  [37 31 30 47 27 26 41 44 27]
# Ciphertext :  [ 1 26 28  8 41 43 39 30 27]
# Ciphertext :  B bIoqmda
#
# Plaintext :  [40 33 26 46 47 27 40 51 27]
# Ciphertext :  [34 20 56  6 28 46 35 20 29]
# Ciphertext :  hU,GbtiUc
#
# Plaintext :  [26 39 31 45 37 35 42 47 40]
# Ciphertext :  [30  2 23 18 56 16 14 29 11]
# Ciphertext :  dCXS,QOcL
#
# Plaintext :  [26 39 31 44 31 37 27 26 28]
# Ciphertext :  [ 4 32 55 43 44 31 24 35 43]
# Ciphertext :  Ef.qreYiq
#
# Plaintext :  [47 37 27 40 26 28 31 44 27]
# Ciphertext :  [48  5 29  4 35 23  7 16 16]
# Ciphertext :  vFcEiXHQQ
#
# Plaintext :  [45 27 38 26 30 27 44 35 26]
# Ciphertext :  [25 54 47 54 53 11 47 25 28]
# Ciphertext :  Z?u?!LuZb
#
# Plaintext :  [37 27 38 27 40 33 27 40 26]
# Ciphertext :  [27 15 37 40 26 37 36 17 27]
# Ciphertext :  aPkn kjRa
#
# Plaintext :  [28 31 44 27 30 27 55 26  8]
# Ciphertext :  [43 42 26 51  7 16 10 45 44]
# Ciphertext :  qp yHQKsr
#
# Plaintext :  [28 47 26 28 31 38 35 27 47]
# Ciphertext :  [46 13 13 47  4 39 22 30  6]
# Ciphertext :  tNNuEmWdG
#
# Plaintext :  [26 39 31 39 35 38 35 37 35]
# Ciphertext :  [44 47  6 51 17 16 28 55 13]
# Ciphertext :  ruGyRQb.N
#
# Plaintext :  [26 47 45 27 34 27 26 29 27]
# Ciphertext :  [43 12 38 25 34 40  9 22 56]
# Ciphertext :  qMlZhnJW,
#
# Plaintext :  [46 31 44 35 40 33 26 30 27]
# Ciphertext :  [18 17 13 34 42  9  9 18 31]
# Ciphertext :  SRNhpJJSe
#
# Plaintext :  [40 26 37 41 45 37 41 45 27]
# Ciphertext :  [52 16 34 24 12 47 38 50 52]
# Ciphertext :  zQhYMulxz
#
# Plaintext :  [40 55 26  9 31 44 35 34 26]
# Ciphertext :  [27 30 15  2 16 37  4 12 37]
# Ciphertext :  adPCQkEMk
#
# Plaintext :  [15 27 51 27 34 26  1 55  9]
# Ciphertext :  [49 46 34 11 45  5  3  5 53]
# Ciphertext :  wthLsFDF!
#
# Plaintext :  [55 26  7 27 28 35 28 35 31]
# Ciphertext :  [29  4 15 53 33 14 12 22 10]
# Ciphertext :  cEP!gOMWK
#
# Plaintext :  [26 18 31 38 27 39 27 26 10]
# Ciphertext :  [40 31 49 20 12 42 50 45 54]
# Ciphertext :  newUMpxs?
#
# Plaintext :  [47 38 35 27 34 26  3 35 26]
# Ciphertext :  [53  0 49  9 47 25  0 32 50]
# Ciphertext :  !AwJuZAfx
#
# Plaintext :  [ 9 31 44 39 27 40 26  3 31]
# Ciphertext :  [28  7 28 41 39  3  4 56 20]
# Ciphertext :  bHbomDE,U
#
# Plaintext :  [39 35 26 39 31 44 35 40 33]
# Ciphertext :  [ 8  0 26 19 18  8 38 41 21]
# Ciphertext :  IA TSIloV
#
# Plaintext :  [27 40 37 27 40 26 28 31 28]
# Ciphertext :  [ 9  7 45  7 27 23 55 26 21]
# Ciphertext :  JHsHaX. V
#
# Plaintext :  [27 40 26 41 44 27 40 33 26]
# Ciphertext :  [56 12 55 32 29  5 18 47 15]
# Ciphertext :  ,M.fcFSuP
#
# Plaintext :  [46 47 27 26 30 27 38 27 39]
# Ciphertext :  [32 30 43  6 11  2 53  3  6]
# Ciphertext :  fdqGLC!DG
#
# Plaintext :  [26 39 31 39 28 35 27 51 27]
# Ciphertext :  [ 4 41  3 20 18 41 56  3 42]
# Ciphertext :  EoDUSo,Dp
#
# Plaintext :  [35 26 42 31 40 30 35 30 35]
# Ciphertext :  [10  2  1 38 29 26 27 33 48]
# Ciphertext :  KCBlc agv
#
# Plaintext :  [37 27 40 40 51 27 56 26  1]
# Ciphertext :  [37 38 11 15  5  7 15 13 25]
# Ciphertext :  klLPFHPNZ
#
# Plaintext :  [55  9 55 26  7 27 28 35 28]
# Ciphertext :  [33 10  5 34 54  5 26 38 43]
# Ciphertext :  gKFh?F lq
#
# Plaintext :  [35 31 26 39 31 39 35 38 35]
# Ciphertext :  [20 15 36 26 34 49  2 25 25]
# Ciphertext :  UPj hwCZZ
#
# Plaintext :  [34 26 47 40 46 47 37 26 46]
# Ciphertext :  [39  9 31 37 52 11 49 35 34]
# Ciphertext :  mJekzLwih
#
# Plaintext :  [35 40 33 33 27 38 26 36 27]
# Ciphertext :  [ 8 27 11 40 44 25 20 30 29]
# Ciphertext :  IaLnrZUdc
#
# Plaintext :  [47 34 26 30 27 44 35 26 42]
# Ciphertext :  [26 46 56 10 40  3 55 29 14]
# Ciphertext :   t,KnD.cO
#
# Plaintext :  [47 45 27 46 26 37 41 46 27]
# Ciphertext :  [29 53 12 39  3 19 10 51 26]
# Ciphertext :  c!MmDTKy
#
# Plaintext :  [26 30 31 40 33 27 40 26 46]
# Ciphertext :  [23 47 28  3  4 39 23  2 18]
# Ciphertext :  XubDEmXCS
#
# Plaintext :  [31 39 42 27 46 26 46 35 40]
# Ciphertext :  [48 11 18  3 35 53 47 55 12]
# Ciphertext :  vLSDi!u.M
#
# Plaintext :  [33 33 27 38 26 51 27 40 33]
# Ciphertext :  [44 42 26  5 43 39 13 48 45]
# Ciphertext :  rp FqmNvs
#
# Plaintext :  [26 39 31 39 35 38 35 37 35]
# Ciphertext :  [44 47  6 51 17 16 28 55 13]
# Ciphertext :  ruGyRQb.N
#
# Plaintext :  [26 32 27 45 35 38 35 46 27]
# Ciphertext :  [12 36 23  9  6 10 33 10 19]
# Ciphertext :  MjXJGKgKT
#
# Plaintext :  [45 26 45 31 27 30 27 40 51]
# Ciphertext :  [51 51 34 34 54 46 27  5 55]
# Ciphertext :  yyhh?taF.
#
# Plaintext :  [27 55 26  1 27 34 37 27 40]
# Ciphertext :  [48  0  1 52 38 15 28 33 41]
# Ciphertext :  vABzlPbgo
#
# Plaintext :  [26 28 31 38 35 27 47 26 36]
# Ciphertext :  [49 39 31 12  4 23 15  3 18]
# Ciphertext :  wmeMEXPDS
#
# Plaintext :  [47 33 27 26 44 31 38 27 26]
# Ciphertext :  [30  9 38 22  4  9 55 36 42]
# Ciphertext :  dJlWEJ.jp
#
# Plaintext :  [47 40 46 47 37 26 28 31 44]
# Ciphertext :  [12  1 22  3 53 33  5 45  6]
# Ciphertext :  MBWD!gFsG
#
# Plaintext :  [36 27 38 27 40 26 37 27 37]
# Ciphertext :  [55 37  9 45 28 40 50 46 22]
# Ciphertext :  .kJsbnxtW
#
# Plaintext :  [35 26 30 27 44 35 26 46 31]
# Ciphertext :  [36  8 52 43 23 25 24 10 15]
# Ciphertext :  jIzqXZYKP
#
# Plaintext :  [39 42 27 46 26 46 35 40 33]
# Ciphertext :  [51  8 21 48  6 42  0 55 31]
# Ciphertext :  yIVvGpA.e
#
# Plaintext :  [33 27 38 26 37 31 26 37 27]
# Ciphertext :  [33 25 43 30 33 11 12 50 10]
# Ciphertext :  gZqdgLMxK
#
# Plaintext :  [39 42 47 45 26 34 27 40 51]
# Ciphertext :  [32 24  3 52 39  0 26 21 40]
# Ciphertext :  fYDzmA Vn
#
# Plaintext :  [27 26 30 31 39 35 26 39 31]
# Ciphertext :  [20 50  8 44 55 30 28 14 50]
# Ciphertext :  UxIr.dbOx
#
# Plaintext :  [40 33 34 31 39 27 46 26 28]
# Ciphertext :  [55 32 13 15 43 40 48  7 55]
# Ciphertext :  .fNPqnvH.
#
# Plaintext :  [35 27 51 27 26 46 44 27 40]
# Ciphertext :  [14 39 43 41  5 27 49  4 37]
# Ciphertext :  OmqoFawEk
#
# Plaintext :  [45 42 41 44 46 27 45 35 55]
# Ciphertext :  [31  1 19 31 21 33 16 28 50]
# Ciphertext :  eBTeVgQbx
#
# Plaintext :  [26 18 31 38 27 35 40 26 35]
# Ciphertext :  [ 4 47 10 30 27 15  9 40 31]
# Ciphertext :  EuKdaPJne
#
# Plaintext :  [46 47 56 26 45 31 38 27 39]
# Ciphertext :  [12 34 10 36 34 29 45  8 28]
# Ciphertext :  MhKjhcsIb
#
# Plaintext :  [27 26 39 31 40 31 39 42 47]
# Ciphertext :  [11 21 56 56  9 10 55 51 21]
# Ciphertext :  LV,,JK.yV
#
# Plaintext :  [34 26 18 26 30 27 40 26 18]
# Ciphertext :  [55  7 54  3 16 22 23 47  0]
# Ciphertext :  .H?DQWXuA
#
# Plaintext :  [26 30 35 26  9 31 44 39 27]
# Ciphertext :  [40 38 13 52 55 49 11 15 11]
# Ciphertext :  nlNz.wLPL
#
# Plaintext :  [40 56 26 28 31 38 35 27 47]
# Ciphertext :  [43 25 13 44 52  6 52  6 36]
# Ciphertext :  qZNrzGzGj
#
# Plaintext :  [26 45 31 39 42 27 46 26 30]
# Ciphertext :  [42 13 52  9 32 27 26  7 37]
# Ciphertext :  pNzJfa Hk
#
# Plaintext :  [47 27 26 37 27 38 35 26 30]
# Ciphertext :  [49 56 27 17 37 30  4 54  3]
# Ciphertext :  w,aRkdE?D
#
# Plaintext :  [35 37 35 44 27 26 46 31 38]
# Ciphertext :  [53 31 55 49 43 11 25 15 45]
# Ciphertext :  !e.wqLZPs
#
# Plaintext :  [27 34 26 39 31 40 35 40 33]
# Ciphertext :  [ 5 25  5 15 51 17 27 12 33]
# Ciphertext :  FZFPyRaMg
#
# Plaintext :  [33 27 38 26 30 35 26  9 31]
# Ciphertext :  [32  8 27 47 27 45 27 54 25]
# Ciphertext :  fIauasa?Z
#
# Plaintext :  [44 39 27 40 26 45 31 38 27]
# Ciphertext :  [ 9  9 20 21 41 23 20 41  1]
# Ciphertext :  JJUVoXUoB
#
# Plaintext :  [39 27 26 39 27 45 27 26 35]
# Ciphertext :  [54  8 52  2 36 17 23 17 31]
# Ciphertext :  ?IzCjRXRe
#
# Plaintext :  [46 47 55 26 13 27 39 47 40]
# Ciphertext :  [27  9 46 36  5 29 14 11 26]
# Ciphertext :  aJtjFcOL
#
# Plaintext :  [26 36 31 44 35 34 26 42 27]
# Ciphertext :  [53  2 40  2 10 48 47 27 29]
# Ciphertext :  !CnCKvuac
#
# Plaintext :  [51 27 34 26 28 31 38 35 27]
# Ciphertext :  [29 48 25 54  2 12 38 18 34]
# Ciphertext :  cvZ?CMlSh
#
# Plaintext :  [47 26 27 37 34 35 44 40 51]
# Ciphertext :  [26 56  9 48 34 18 16 20 43]
# Ciphertext :   ,JvhSQUq
#
# Plaintext :  [27 26 46 31 44 28 27 51 27]
# Ciphertext :  [46 11 28 38  5 44 16  6 11]
# Ciphertext :  tLblFrQGL
#
# Plaintext :  [44 26 37 27 44 31 40 27 26]
# Ciphertext :  [25 13 44 38 31  3 38 25 37]
# Ciphertext :  ZNrleDlZk
#
# Plaintext :  [39 31 45 37 35 42 47 40 26]
# Ciphertext :  [15 39 22 18 40 42 31  8 36]
# Ciphertext :  PmWSnpeIj
#
# Plaintext :  [39 31 40 36 27 38 27 40 35]
# Ciphertext :  [36 33 49 12 41 13 29 14 20]
# Ciphertext :  jgwMoNcOU
#
# Plaintext :  [26 42 31 40 30 35 30 35 37]
# Ciphertext :  [11 52 30 33 12 30  9 45 53]
# Ciphertext :  LzdgMdJs!
#
# Plaintext :  [27 40 26 30 31 40 33 27 40]
# Ciphertext :  [13 19 32  4 15  4 51 41 38]
# Ciphertext :  NTfEPEyol
#
# Plaintext :  [26 28 35 27 51 27 26 51 27]
# Ciphertext :  [15 49 26 49 31  7 48 17 21]
# Ciphertext :  Pw weHvRV
#
# Plaintext :  [40 33 26 46 31 44 28 27 46]
# Ciphertext :  [ 4 27  4 41 46 12 16 48 45]
# Ciphertext :  EaEotMQvs
#
# Plaintext :  [27 45 56 26  1 55  9 55 26]
# Ciphertext :  [39 20  6 47 35 35  0 23 29]
# Ciphertext :  mUGuiiAXc
#
# Plaintext :  [ 7 27 28 35 28 35 31 26 28]
# Ciphertext :  [36 42 29 52 24 17 42 21 12]
# Ciphertext :  jpczYRpVM
#
# Plaintext :  [31 44 34 27 45 35 38 26 39]
# Ciphertext :  [56  5 29 14 45 34 28  4 47]
# Ciphertext :  ,FcOshbEu
#
# Plaintext :  [31 40 51 31 38 31 45 27 35]
# Ciphertext :  [27 44 23 39 17 52  5 10 33]
# Ciphertext :  arXmRzFKg
#
# Plaintext :  [37 27 40 26 42 31 40 30 35]
# Ciphertext :  [31 45  4 36  3  8 53 44  1]
# Ciphertext :  esEjDI!rB
#
# Plaintext :  [30 35 37 27 40 26 18 26 34]
# Ciphertext :  [ 1 46 44 35 44 24 40 39 50]
# Ciphertext :  BtrirYnmx
#
# Plaintext :  [35 40 33 33 27 26 18 26 30]
# Ciphertext :  [13 10 24 55 51 12  8 47 38]
# Ciphertext :  NKY.yMIul
#
# Plaintext :  [31 40 33 27 40 26 38 47 27]
# Ciphertext :  [21 10  2 15 34  8 38 37 45]
# Ciphertext :  VKCPhIlks
#
# Plaintext :  [44 26 28 35 27 45 27 26 28]
# Ciphertext :  [ 7 45 40  4 27 21 41 54 25]
# Ciphertext :  HsnEaVo?Z
#
# Plaintext :  [27 35 37 55 26 18 31 46 31]
# Ciphertext :  [32 35 46 18 41  0 26 11 51]
# Ciphertext :  fitSoA Ly
#
# Plaintext :  [38 27 34 26 38 47 38 47 45]
# Ciphertext :  [10 16 55 14 22 47  7 31 21]
# Ciphertext :  KQ.OWuHeV
#
# Plaintext :  [26 18 26 27 37 34 35 44 40]
# Ciphertext :  [17 34  1 42  2 46 25 45  7]
# Ciphertext :  RhBpCtZsH
#
# Plaintext :  [51 27 26 28 31 38 35 27 47]
# Ciphertext :  [51 11 19 33 49 52 38  8  9]
# Ciphertext :  yLTgwzlIJ
#
# Plaintext :  [26 28 31 44 46 31 37 27 30]
# Ciphertext :  [35  0  3 13 40 11 18 42 13]
# Ciphertext :  iADNnLSpN
#
# Plaintext :  [26 47 40 46 47 37 26 28 31]
# Ciphertext :  [28 30 41  9 15 22 11 42  2]
# Ciphertext :  bdoJPWLpC
#
# Plaintext :  [37 31 44 36 27 26 45 31 28]
# Ciphertext :  [ 9 25  8 56 16 18 50  0 20]
# Ciphertext :  JZI,QSxAU
#
# Plaintext :  [27 33 27 35 26 27 45 35 45]
# Ciphertext :  [ 3 50 50 23 43  4 22 37 24]
# Ciphertext :  DxxXqEWkY
#
# Plaintext :  [46 31 40 26 42 44 41 32 31]
# Ciphertext :  [ 3 10  0 24 29 28 49 27  2]
# Ciphertext :  DKAYcbwaC
#
# Plaintext :  [45 45 41 44 26 34 35 40 33]
# Ciphertext :  [33 49 10 38 14 36  2 56 25]
# Ciphertext :  gwKlOjC,Z
#
# Plaintext :  [33 27 26 28 31 38 35 27 47]
# Ciphertext :  [21 56 13  3 43 49 44 20  9]
# Ciphertext :  V,NDqwrUJ
#
# Plaintext :  [26 39 31 40 30 27 42 27 46]
# Ciphertext :  [51 43 15  6 54 31 53 24 21]
# Ciphertext :  yqPG?e!YV
#
# Plaintext :  [26 37 31 45 31 39 42 27 46]
# Ciphertext :  [34  3 23 10 11 26 22 38 41]
# Ciphertext :  hDXKL Wlo
#
# Plaintext :  [27 40 26 47 40 46 47 37 26]
# Ciphertext :  [ 3 15 32  9 46 56 18 17  7]
# Ciphertext :  DPfJt,SRH
#
# Plaintext :  [39 31 38 27 40 36 47 46 37]
# Ciphertext :  [11 53 13  7  8 17 10 46 13]
# Ciphertext :  L!NHIRKtN
#
# Plaintext :  [27 40 26 18 26 30 31 40 33]
# Ciphertext :  [ 5  3 40 11 49 27 18 31 50]
# Ciphertext :  FDnLwaSex
#
# Plaintext :  [27 40 26 28 31 27 45 35 45]
# Ciphertext :  [50 22 10 56 55 45 52 27 53]
# Ciphertext :  xWK,.sza!
#
# Plaintext :  [49 27 55 26 19 31 42 27 46]
# Ciphertext :  [13 10 16 10 26 18 49 56 47]
# Ciphertext :  NKQK Sw,u
#
# Plaintext :  [26 45 27 27 46 26 47 45 35]
# Ciphertext :  [17 21  9  1 11  8 52 54 40]
# Ciphertext :  RVJBLIz?n
#
# Plaintext :  [27 26 26 46 27 34 47 40 56]
# Ciphertext :  [55  2 49 48 56 43  7  7 21]
# Ciphertext :  .Cwv,qHHV
#
# Plaintext :  [26  1 55  9 55 26  7 27 28]
# Ciphertext :  [40 53 24 13 27 14  2 39 37]
# Ciphertext :  n!YNaOCmk
#
# Plaintext :  [35 28 35 31 26 44 31 45 39]
# Ciphertext :  [32 38 26 25 25 27 17  7  5]
# Ciphertext :  fl ZZaRHF
#
# Plaintext :  [35 26 39 31 39 42 31 44 41]
# Ciphertext :  [12 54 21 18 14 54 52 14 54]
# Ciphertext :  M?VSO?zO?
#
# Plaintext :  [38 31 34 26 33 31 38 27 44]
# Ciphertext :  [14 28 29 49 55 40 40 45 38]
# Ciphertext :  Obcw.nnsl
#
# Plaintext :  [26  3 41 37 46 41 44 26 28]
# Ciphertext :  [19 19  8 35 47 25 45 30 53]
# Ciphertext :  TTIiuZsd!
#
# Plaintext :  [35 30 27 40 33 26 46 31 37]
# Ciphertext :  [17 50 34 51 24 11  5 35 17]
# Ciphertext :  RxhyYLFiR
#
# Plaintext :  [40 41 38 41 33 35 26 42 31]
# Ciphertext :  [39 40 48 49 48 50 14 13 52]
# Ciphertext :  mnvwvxONz
#
# Plaintext :  [45 27 49 27 46 26 46 31 44]
# Ciphertext :  [30  2  8 43 26 32 25  2 15]
# Ciphertext :  dCIq fZCP
#
# Plaintext :  [28 27 40 33 26 30 35 26  9]
# Ciphertext :  [53 40 26  4 13  6 49 36 47]
# Ciphertext :  !n ENGwju
#
# Plaintext :  [31 44 39 27 40 55 26 20 45]
# Ciphertext :  [12 13 41 52 10 20  0 23 43]
# Ciphertext :  MNozKUAXq
#
# Plaintext :  [35 27 26 26 46 27 34 47 40]
# Ciphertext :  [51 46 50 25 55  7 23 39  0]
# Ciphertext :  ytxZ.HXmA
#
# Plaintext :  [26 30 31 40 33 27 40 26 33]
# Ciphertext :  [44 48 26 56 23 30 29 50  7]
# Ciphertext :  rv ,XdcxH
#
# Plaintext :  [31 38 27 44 26  3 41 37 46]
# Ciphertext :  [ 3 55  3 50 32 41 24 40 35]
# Ciphertext :  D.DxfoYni
#
# Plaintext :  [41 44 26 28 35 45 27 26 30]
# Ciphertext :  [31 32  4 32 27 11 40 32 20]
# Ciphertext :  efEfaLnfU
#
# Plaintext :  [35 28 35 38 27 40 33 26 47]
# Ciphertext :  [ 3 29 51 25 33 15  5 53 38]
# Ciphertext :  DcyZgPF!l
#
# Plaintext :  [45 35 27 26 51 27 40 33 26]
# Ciphertext :  [49 19 28 47 47 39 12 20 44]
# Ciphertext :  wTbuumMUr
#
# Plaintext :  [45 27 40 33 27 46 26 28 31]
# Ciphertext :  [42  5 22  7  8 25 24 27 27]
# Ciphertext :  pFWHIZYaa
#
# Plaintext :  [38 35 27 55 26  1 27 34 37]
# Ciphertext :  [47 36 51 42  0 10 16 24 26]
# Ciphertext :  ujypAKQY
#
# Plaintext :  [27 40 26 28 27 40 51 27 37]
# Ciphertext :  [ 3 33  3 10 43 18 19 12 20]
# Ciphertext :  DgDKqSTMU
#
# Plaintext :  [26 51 27 40 33 26 46 35 30]
# Ciphertext :  [51 11 56 29 10 33 11 24 36]
# Ciphertext :  yL,cKgLYj
#
# Plaintext :  [27 37 26 42 31 44 29 27 51]
# Ciphertext :  [10  6 50 18 33 13 32 43 46]
# Ciphertext :  KGxSgNfqt
#
# Plaintext :  [27 26 28 31 38 35 27 47 26]
# Ciphertext :  [39 11 38 25 42 19 27 43 22]
# Ciphertext :  mLlZpTaqW
#
# Plaintext :  [39 31 44 47 42 27 37 27 40]
# Ciphertext :  [29 19 35 21 56  3 23  5 19]
# Ciphertext :  cTiV,DXFT
#
# Plaintext :  [26 38 47 38 47 45 27 40 26]
# Ciphertext :  [29 45 51  0 19  4 49 17 27]
# Ciphertext :  csyATEwRa
#
# Plaintext :  [18 56 26 39 31 40 33 35 40]
# Ciphertext :  [24 15 44 11 51 51 33 19  4]
# Ciphertext :  YPrLyygTE
#
# Plaintext :  [33 27 46 26 49 27 36 27 34]
# Ciphertext :  [24  3  4 46 47 31 12 44  8]
# Ciphertext :  YDEtueMrI
#
# Plaintext :  [26 28 31 38 35 27 47 26 51]
# Ciphertext :  [16 51  7 21  4 29 30  9  0]
# Ciphertext :  QyHVEcdJA
#
# Plaintext :  [27 40 33 26 28 27 28 51 26]
# Ciphertext :  [40 39 28 39 52 25 56 41 54]
# Ciphertext :  nmbmzZ,o?
#
# Plaintext :  [32 27 29 31 55 26 18 31 38]
# Ciphertext :  [39 40 20 45 50 45  0 44 13]
# Ciphertext :  mnUsxsArN
#
# Plaintext :  [27 39 27 26 34 35 30 47 42]
# Ciphertext :  [51 22 44 45 44 48 24 23 56]
# Ciphertext :  yWrsrvYX,
#
# Plaintext :  [26 30 35 26  9 31 44 39 27]
# Ciphertext :  [40 38 13 52 55 49 11 15 11]
# Ciphertext :  nlNz.wLPL
#
# Plaintext :  [40 56 26  1 55  9 55 26  7]
# Ciphertext :  [15 46 55 34 52 41 21 34 44]
# Ciphertext :  Pt.hzoVhr
#
# Plaintext :  [27 28 35 28 35 31 26 39 31]
# Ciphertext :  [18 30  8 41 25 50 53 24 14]
# Ciphertext :  SdIoZx!YO
#
# Plaintext :  [40 36 27 30 35 26 46 31 44]
# Ciphertext :  [ 5 29 38 27  6 11 10 21 38]
# Ciphertext :  FclaGLKVl
#
# Plaintext :  [28 35 27 45 27 26 47 40 46]
# Ciphertext :  [20 38  7 45 52 18 42 42 10]
# Ciphertext :  UlHszSppK
#
# Plaintext :  [47 37 26 39 31 40 33 27 46]
# Ciphertext :  [48 10 32 22  3 38 16 28 51]
# Ciphertext :  vKfWDlQby
#
# Plaintext :  [27 45 35 26 45 31 33 27 38]
# Ciphertext :  [35 54 45  9 15 39  4 34  5]
# Ciphertext :  i?sJPmEhF
#
# Plaintext :  [27 26 42 31 44 39 27 45 27]
# Ciphertext :  [ 5 10 34 29  1 32 55 34 49]
# Ciphertext :  FKhcBf.hw
#
# Plaintext :  [38 27 34 27 40 26 45 31 40]
# Ciphertext :  [14 36 17  0 11 12 17 10 11]
# Ciphertext :  OjRALMRKL
#
# Plaintext :  [30 35 44 35 55 26  1 27 34]
# Ciphertext :  [53  1 11  6 52 46 23 54 44]
# Ciphertext :  !BLGztX?r
#
# Plaintext :  [37 27 40 56 26 28 31 38 35]
# Ciphertext :  [24  1 43 19  1  3 21 49 52]
# Ciphertext :  YBqTBDVwz
#
# Plaintext :  [27 47 26 36 47 33 27 26 39]
# Ciphertext :  [39 45 30 12 39 46 51 11 31]
# Ciphertext :  msdMmtyLe
#
# Plaintext :  [27 45 35 34 26 39 31 40 31]
# Ciphertext :  [43  0 28  7  3 15 39 50 56]
# Ciphertext :  qAbHDPmx,
#
# Plaintext :  [44 27 42 37 27 40 26 40 35]
# Ciphertext :  [56 54  4 16 21 20 51 51 39]
# Ciphertext :  ,?EQVUyym
#
# Plaintext :  [38 27 35 40 35 38 27 35 26]
# Ciphertext :  [25  0 38 23  4 11 29  6 55]
# Ciphertext :  ZAlXELcG.
#
# Plaintext :  [51 27 40 33 26 45 47 30 27]
# Ciphertext :  [ 5 21 56 34 28  5 44  9 36]
# Ciphertext :  FV,hbFrJj
#
# Plaintext :  [34 26 30 35 27 36 27 44 37]
# Ciphertext :  [55  6 28 25 29 49 44 53  5]
# Ciphertext :  .GbZcwr!F
#
# Plaintext :  [27 40 26 41 44 27 40 33 26]
# Ciphertext :  [56 12 55 32 29  5 18 47 15]
# Ciphertext :  ,M.fcFSuP
#
# Plaintext :  [46 47 27 40 51 27 26 45 31]
# Ciphertext :  [21 39 11 35 31 14 50  5 35]
# Ciphertext :  VmLieOxFi
#
# Plaintext :  [38 27 39 27 26 30 35 26  8]
# Ciphertext :  [43 50 39 45 46 11 14 37 29]
# Ciphertext :  qxmstLOkc
#
# Plaintext :  [40 30 41 40 31 45 35 27 26]
# Ciphertext :  [19 12  1 42 16 27 18 26 24]
# Ciphertext :  TMBpQaS Y
#
# Plaintext :  [30 47 38 47 26 45 27 27 46]
# Ciphertext :  [32  2 55 56 29 20 42 11  9]
# Ciphertext :  fC.,cUpLJ
#
# Plaintext :  [26 39 31 40 36 27 38 27 40]
# Ciphertext :  [ 9  1 32 36 20 46 14 30 24]
# Ciphertext :  JBfjUtOdY
#
# Plaintext :  [35 26 37 31 34 35 30 47 42]
# Ciphertext :  [53  7 19  9 36 16 50 18 37]
# Ciphertext :  !HTJjQxSk
#
# Plaintext :  [27 40 26 30 35 26  9 31 44]
# Ciphertext :  [29 39 25 31 52  6  7 32 26]
# Ciphertext :  cmZezGHf
#
# Plaintext :  [39 27 40 55 26 18 27 38 27]
# Ciphertext :  [45 54 28 24  2 40 14 39 45]
# Ciphertext :  s?bYCnOms
#
# Plaintext :  [34 26 45 27 46 47 26 34 27]
# Ciphertext :  [11 36 44 55 16 31  2  6 26]
# Ciphertext :  Ljr.QeCG
#
# Plaintext :  [38 26 51 27 40 33 26 28 31]
# Ciphertext :  [42 54 16 32 33 45 15 24  1]
# Ciphertext :  p?QfgsPYB
#
# Plaintext :  [38 35 27 47 26 45 47 37 27]
# Ciphertext :  [ 7 17 10 49 54 40 56 38 23]
# Ciphertext :  HRKw?n,lX
#
# Plaintext :  [35 26 30 35 26  9 31 44 39]
# Ciphertext :  [35 43  9  7 23 50 14  0 26]
# Ciphertext :  iqJHXxOA
#
# Plaintext :  [27 40 26 27 30 27 38 27 34]
# Ciphertext :  [22 42 25 53 54 54 11  9 28]
# Ciphertext :  WpZ!??LJb
#
# Plaintext :  [26 42 31 44 42 47 45 46 27]
# Ciphertext :  [21 38 17 31 40  5 12 24 12]
# Ciphertext :  VlRenFMYM
#
# Plaintext :  [37 27 27 40 40 51 27 55 26]
# Ciphertext :  [46 35 29 30 45 19  4 45 24]
# Ciphertext :  ticdsTEsY
#
# Plaintext :  [12 31 40 47 44 47 46 26 28]
# Ciphertext :  [11 25 17 49 11  7 18 23 18]
# Ciphertext :  LZRwLHSXS
#
# Plaintext :  [31 38 35 27 47 56 26 42 31]
# Ciphertext :  [50 21 46 46 55  4  3  5 43]
# Ciphertext :  xVtt.EDFq
#
# Plaintext :  [44 42 47 45 46 27 37 27 27]
# Ciphertext :  [27 30 46  5 11  2 41  2 40]
# Ciphertext :  adtFLCoCn
#
# Plaintext :  [40 26 30 35 26  9 31 44 39]
# Ciphertext :  [37 40 36 28 50 54  6 41 45]
# Ciphertext :  knjbx?Gos
#
# Plaintext :  [27 40 26 28 47 37 27 26 38]
# Ciphertext :  [26 12 14 15 34 10 32 38 22]
# Ciphertext :   MOPhKflW
#
# Plaintext :  [31 28 35 34 26 38 27 39 27]
# Ciphertext :  [34 41 13 37 21 40 18 27 18]
# Ciphertext :  hoNkVnSaS
#
# Plaintext :  [26 30 27 40 26 38 31 28 35]
# Ciphertext :  [44 46 51 47 45 13 36 11 43]
# Ciphertext :  rtyusNjLq
#
# Plaintext :  [34 26 28 31 28 27 45 26 47]
# ...
#
# Ciphertext :  [11 36 44 55 16 31  2  6 26]
# Plaintext :  [34 26 45 27 46 47 26 34 27]
# Plaintext :  h satu ha
#
# Ciphertext :  [42 54 16 32 33 45 15 24  1]
# Plaintext :  [38 26 51 27 40 33 26 28 31]
# Plaintext :  l yang be
#
# Ciphertext :  [ 7 17 10 49 54 40 56 38 23]
# Plaintext :  [38 35 27 47 26 45 47 37 27]
# Plaintext :  liau suka
#
# Ciphertext :  [35 43  9  7 23 50 14  0 26]
# Plaintext :  [35 26 30 35 26  9 31 44 39]
# Plaintext :  i di Jerm
#
# Ciphertext :  [22 42 25 53 54 54 11  9 28]
# Plaintext :  [27 40 26 27 30 27 38 27 34]
# Plaintext :  an adalah
#
# Ciphertext :  [21 38 17 31 40  5 12 24 12]
# Plaintext :  [26 42 31 44 42 47 45 46 27]
# Plaintext :   perpusta
#
# Ciphertext :  [46 35 29 30 45 19  4 45 24]
# Plaintext :  [37 27 27 40 40 51 27 55 26]
# Plaintext :  kaannya.
#
# Ciphertext :  [11 25 17 49 11  7 18 23 18]
# Plaintext :  [12 31 40 47 44 47 46 26 28]
# Plaintext :  Menurut b
#
# Ciphertext :  [50 21 46 46 55  4  3  5 43]
# Plaintext :  [31 38 35 27 47 56 26 42 31]
# Plaintext :  eliau, pe
#
# Ciphertext :  [27 30 46  5 11  2 41  2 40]
# Plaintext :  [44 42 47 45 46 27 37 27 27]
# Plaintext :  rpustakaa
#
# Ciphertext :  [37 40 36 28 50 54  6 41 45]
# Plaintext :  [40 26 30 35 26  9 31 44 39]
# Plaintext :  n di Jerm
#
# Ciphertext :  [26 12 14 15 34 10 32 38 22]
# Plaintext :  [27 40 26 28 47 37 27 26 38]
# Plaintext :  an buka l
#
# Ciphertext :  [34 41 13 37 21 40 18 27 18]
# Plaintext :  [31 28 35 34 26 38 27 39 27]
# Plaintext :  ebih lama
#
# Ciphertext :  [44 46 51 47 45 13 36 11 43]
# Plaintext :  [26 30 27 40 26 38 31 28 35]
# Plaintext :   dan lebi
#
# Ciphertext :  [16 54 23  2  4  8 47 10 31]
# Plaintext :  [34 26 28 31 28 27 45 26 47]
# Plaintext :  h bebas u
#
# Ciphertext :  [41 33 40 15 24 56 50  0 38]
# Plaintext :  [40 46 47 37 26 30 35 37 47]
# Plaintext :  ntuk diku
#
# Ciphertext :  [21 13 52  9 56 43 35 26 48]
# Plaintext :  [40 36 47 40 33 35 55 26  7]
# Plaintext :  njungi. H
#
# Ciphertext :  [41 49  9 48 38 37 29 42 14]
# Plaintext :  [27 38 26 35 40 35 26 39 31]
# Plaintext :  al ini me
#
# Ciphertext :  [44 23 31 48 50 20 47 32 10]
# Plaintext :  [39 28 47 27 46 26  1 55  9]
# Plaintext :  mbuat B.J
#
# Ciphertext :  [29  4 15 53 33 14 12 22 10]
# Plaintext :  [55 26  7 27 28 35 28 35 31]
# Plaintext :  . Habibie
#
# Ciphertext :  [ 7 50 11 25 46 42 11  6  4]
# Plaintext :  [26 39 31 44 27 45 27 26 39]
# Plaintext :   merasa m
#
# Ciphertext :  [11 56 18  9 22  9 37 16 53]
# Plaintext :  [31 39 35 38 35 37 35 26 37]
# Plaintext :  emiliki k
#
# Ciphertext :  [15 56 33 37 10  8 36 22 13]
# Plaintext :  [31 45 31 39 42 27 46 27 40]
# Plaintext :  esempatan
#
# Ciphertext :  [26 29 38 51 28 50 44 26 47]
# Plaintext :  [26 51 27 40 33 26 38 31 28]
# Plaintext :   yang leb
#
# Ciphertext :  [34 50 47 19 56 55 26  5 40]
# Plaintext :  [35 34 26 28 31 45 27 44 26]
# Plaintext :  ih besar
#
# Ciphertext :  [ 4 36  5 26 34 33 33  7 15]
# Plaintext :  [30 27 38 27 39 26 34 27 38]
# Plaintext :  dalam hal
#
# Ciphertext :  [33  1 43 48  1 52 32 54 21]
# Plaintext :  [26 39 31 40 27 39 28 27 34]
# Plaintext :   menambah
#
# Ciphertext :  [14 45 29 26 34  5 46 19 49]
# Plaintext :  [26 49 27 49 27 45 27 40 26]
# Plaintext :   wawasan
#
# Ciphertext :  [54 46  8 11 31 30 12 28 42]
# Plaintext :  [30 27 40 26 42 31 40 33 31]
# Plaintext :  dan penge
#
# Ciphertext :  [31 19  6 20 41  2 20 23 32]
# Plaintext :  [46 27 34 47 27 40 26 45 31]
# Plaintext :  tahuan se
#
# Ciphertext :  [37 28 26 19 27 38 53  7 43]
# Plaintext :  [38 27 39 27 26 30 35 26  9]
# Plaintext :  lama di J
#
# Ciphertext :  [45 36 37  8 33 56  9 29 12]
# Plaintext :  [31 44 39 27 40 55 26 11 31]
# Plaintext :  erman. Le
#
# Ciphertext :  [48 29 38 26 34  1 15 11 28]
# Plaintext :  [28 35 34 26 30 27 44 35 26]
# Plaintext :  bih dari
#
# Ciphertext :  [16 54 54 14 43 42 34 52 10]
# Plaintext :  [35 46 47 56 26 27 30 27 26]
# Plaintext :  itu, ada
#
# Ciphertext :  [ 5  2 43 55 22 40 33 47 36]
# Plaintext :  [45 27 46 47 26 29 31 44 35]
# Plaintext :  satu ceri
#
# Ciphertext :  [17 43 25 47  5 48 39 24 31]
# Plaintext :  [46 27 26 38 47 29 47 26 51]
# Plaintext :  ta lucu y
#
# Ciphertext :  [24 32 20 14 54 11 49 20 43]
# Plaintext :  [27 40 33 26 30 35 27 38 27]
# Plaintext :  ang diala
#
# Ciphertext :  [ 0 34 22 20 25 40 11 44  4]
# Plaintext :  [39 35 26 28 31 38 35 27 47]
# Plaintext :  mi beliau
#
# Ciphertext :  [39 18 29 21 25  9 31 13 41]
# Plaintext :  [26 45 27 27 46 26 39 31 40]
# Plaintext :   saat men
#
# Ciphertext :  [54  6 12 50 51  4 23 11 56]
# Plaintext :  [31 39 42 47 34 26 45 46 47]
# Plaintext :  empuh stu
#
# Ciphertext :  [32 43 43 53 37 27  4 41 22]
# Plaintext :  [30 35 26 30 35 26  9 31 44]
# Plaintext :  di di Jer
#
# Ciphertext :  [16  3  5 48 54 32 22 12 46]
# Plaintext :  [39 27 40 55 26 10 31 39 27]
# Plaintext :  man. Kema
#
# Ciphertext :  [37  4  3 39 28 40 26 16 49]
# Plaintext :  [39 42 47 27 40 26 28 27 34]
# Plaintext :  mpuan bah
#
# Ciphertext :  [16 32 43 40 47  6 35 52 52]
# Plaintext :  [27 45 27 26  9 31 44 39 27]
# Plaintext :  asa Jerma
#
# Ciphertext :  [51  4 39 34 30 21 50 32  4]
# Plaintext :  [40 26  1 55  9 55 26  7 27]
# Plaintext :  n B.J. Ha
#
# Ciphertext :  [43 49 34 45 11 15 45 22 52]
# Plaintext :  [28 35 28 35 31 26 51 27 40]
# Plaintext :  bibie yan
#
# Ciphertext :  [52  9  3  1 11 47 13  2 22]
# Plaintext :  [33 26 30 35 26 27 46 27 45]
# Plaintext :  g di atas
#
# Ciphertext :  [41 56 19 10 15 17 53 47 46]
# Plaintext :  [26 44 27 46 27 44 27 46 27]
# Plaintext :   ratarata
#
# Ciphertext :  [11 10 52  7  5 41 14 22 28]
# Plaintext :  [26 47 40 46 47 37 26 41 44]
# Plaintext :   untuk or
#
# Ciphertext :  [23  1  1 44 44 22 12 51 20]
# Plaintext :  [27 40 33 26 27 45 35 40 33]
# Plaintext :  ang asing
#
# Ciphertext :  [ 8 26 22  7 55 39 17 46  4]
# Plaintext :  [26 39 31 39 28 47 27 46 26]
# Plaintext :   membuat
#
# Ciphertext :  [31 35 16  3  6 36  3  9 53]
# Plaintext :  [46 31 39 27 40 46 31 39 27]
# Plaintext :  temantema
#
# Ciphertext :  [10 26 17 34 21 18 29 47  3]
# Plaintext :  [40 26 28 31 38 35 27 47 26]
# Plaintext :  n beliau
#
# Ciphertext :  [27 50 45 22  8 34  9  1 15]
# Plaintext :  [39 31 39 42 31 44 46 27 40]
# Plaintext :  mempertan
#
# Ciphertext :  [36 12 42  3 54  8 40 38 49]
# Plaintext :  [51 27 37 27 40 26 37 31 46]
# Plaintext :  yakan ket
#
# Ciphertext :  [ 2  2 54 34  7 25 29 23  9]
# Plaintext :  [47 44 47 40 27 40 26 30 27]
# Plaintext :  urunan da
#
# Ciphertext :  [29 36  1  0 32 11 53 42  0]
# Plaintext :  [40 26 36 47 33 27 26 27 45]
# Plaintext :  n juga as
#
# Ciphertext :  [40 20 27 46 24 11 24 26 35]
# Plaintext :  [27 38 26 47 45 47 38 26 28]
# Plaintext :  al usul b
#
# Ciphertext :  [30 44 29 39 23  2 16 19 49]
# Plaintext :  [31 38 35 27 47 55 26  1 27]
# Plaintext :  eliau. Ba
#
# Ciphertext :  [36 51 49 55 43 43 27 47 34]
# Plaintext :  [34 37 27 40 26 42 27 30 27]
# Plaintext :  hkan pada
#
# Ciphertext :  [42  7 17 39 45 30 34 10 39]
# Plaintext :  [26 27 37 34 35 44 40 51 27]
# Plaintext :   akhirnya
#
# Ciphertext :  [ 4 26  0  7 42 26 51  6 47]
# Plaintext :  [26 28 31 38 35 27 47 26 34]
# Plaintext :   beliau h
#
# Ciphertext :  [29 22  4  3  7 54 30 16 31]
# Plaintext :  [27 44 47 45 26 39 31 40 36]
# Plaintext :  arus menj
#
# Ciphertext :  [ 9 56  5 34 32 48  7 56  2]
# Plaintext :  [27 49 27 28 26 30 31 40 33]
# Plaintext :  awab deng
#
# Ciphertext :  [20 15 47 26 35 39 10 22 33]
# Plaintext :  [27 40 26 29 27 40 30 27 27]
# Plaintext :  an candaa
#
# Ciphertext :  [14 22 24 10 42 20 16 47 40]
# Plaintext :  [40 26 28 27 34 49 27 26 27]
# Plaintext :  n bahwa a
#
# Ciphertext :  [38 55  6 29 45 55 22  5 36]
# Plaintext :  [51 27 34 40 51 27 26 37 27]
# Plaintext :  yahnya ka
#
# Ciphertext :  [22 19 28  5 48 11 29 12  0]
# Plaintext :  [40 35 28 27 38 26 42 31 44]
# Plaintext :  nibal per
#
# Ciphertext :  [10 18 38  2 49 20 15 39 34]
# Plaintext :  [40 27 34 26 39 27 37 27 40]
# Plaintext :  nah makan
#
# Ciphertext :  [ 7 33  7 18  2 47 28  9 21]
# Plaintext :  [26 30 27 33 35 40 33 26 41]
# Plaintext :   daging o
#
# Ciphertext :  [45 52 25 34 51 38 45 55  4]
# Plaintext :  [44 27 40 33 26  9 31 44 39]
# Plaintext :  rang Jerm
#
# Ciphertext :  [44 22 26 42 36 23 27  6 48]
# Plaintext :  [27 40 26 45 31 34 35 40 33]
# Plaintext :  an sehing
#
# Ciphertext :  [ 2 27 31 13  8  2 46 43 40]
# Plaintext :  [33 27 26 45 31 36 27 37 26]
# Plaintext :  ga sejak
#
# Ciphertext :  [28 39 18 53 54 31  8 49  0]
# Plaintext :  [45 27 27 46 26 35 46 47 26]
# Plaintext :  saat itu
#
# Ciphertext :  [15 48 45  6  0 20 20 34 56]
# Plaintext :  [28 31 38 35 27 47 26 39 31]
# Plaintext :  beliau me
#
# Ciphertext :  [47 32 37 35  6 43  2 27  0]
# Plaintext :  [39 35 38 35 37 35 26 30 27]
# Plaintext :  miliki da
#
# Ciphertext :  [ 8 47 13 31 48 43 49 33 26]
# Plaintext :  [44 27 34 26  9 31 44 39 27]
# Plaintext :  rah Jerma
#
# Ciphertext :  [47 56 30 37 26 44 41 45 52]
# Plaintext :  [40 55 26 10 41 39 35 46 39]
# Plaintext :  n. Komitm
#
# Ciphertext :  [21 24 34 17  6 51 51 43  7]
# Plaintext :  [31 40 26 30 27 40 26 46 31]
# Plaintext :  en dan te
#
# Ciphertext :  [31 51 10 24  4 41 36 31 39]
# Plaintext :  [37 27 30 26 28 31 38 35 27]
# Plaintext :  kad belia
#
# Ciphertext :  [52  7 44  0 50 49  6 21 31]
# Plaintext :  [47 26 47 40 46 47 37 26 39]
# Plaintext :  u untuk m
#
# Ciphertext :  [37  6 47 37 53  8  6 44 54]
# Plaintext :  [31 40 36 27 30 35 26 51 27]
# Plaintext :  enjadi ya
#
# Ciphertext :  [13 41 33 42 27  0 43 36  5]
# Plaintext :  [40 33 26 46 31 44 28 27 35]
# Plaintext :  ng terbai
#
# Ciphertext :  [23  1 28 51 51  7  5 45 27]
# Plaintext :  [37 26 30 27 40 26 39 31 38]
# Plaintext :  k dan mel
#
# Ciphertext :  [15 15 12 28 17 12 48  8 24]
# Plaintext :  [31 28 35 34 35 26 41 44 27]
# Plaintext :  ebihi ora
#
# Ciphertext :  [53 45 56 25 38 40 21 55  6]
# Plaintext :  [40 33 41 44 27 40 33 26 30]
# Plaintext :  ngorang d
#
# Ciphertext :  [53 52  2 40 44  4 26 22 27]
# Plaintext :  [35 26  9 31 44 39 27 40 26]
# Plaintext :  i Jerman
#
# Ciphertext :  [ 4 36  5 26 34 33 33  7 15]
# Plaintext :  [30 27 38 27 39 26 34 27 38]
# Plaintext :  dalam hal
#
# Ciphertext :  [51 29 40 18 43 52 10 47  4]
# Plaintext :  [26 42 31 40 33 31 46 27 34]
# Plaintext :   pengetah
#
# Ciphertext :  [48 40 37  3 56 27 18 52 50]
# Plaintext :  [47 27 40 26 28 31 44 34 27]
# Plaintext :  uan berha
#
# Ciphertext :  [42 10 24 44 42 46 37 50 51]
# Plaintext :  [45 35 38 26 39 31 39 28 47]
# Plaintext :  sil membu
#
# Ciphertext :  [30 33 49 31 22 10  8  5 47]
# Plaintext :  [27 46 26 28 31 38 35 27 47]
# Plaintext :  at beliau
#
# Ciphertext :  [38 47 16 21 50 31 45 41 38]
# Plaintext :  [26 30 35 27 37 47 35 26 37]
# Plaintext :   diakui k
#
# Ciphertext :  [17 42 35 40 17 54  0 45  6]
# Plaintext :  [31 39 27 39 42 47 27 40 40]
# Plaintext :  emampuann
#
# Ciphertext :  [22 18 39 50 28 37 11 51 25]
# Plaintext :  [51 27 26 41 38 31 34 26 30]
# Plaintext :  ya oleh d
#
# Ciphertext :  [ 6 17 15 34 31 56 48 39 19]
# Plaintext :  [47 40 35 27 55 26  1 27 34]
# Plaintext :  unia. Bah
#
# Ciphertext :  [ 7  0 54 15 49  0  6 31 34]
# Plaintext :  [37 27 40 26 34 35 40 33 33]
# Plaintext :  kan hingg
#
# Ciphertext :  [14 54 13 48  1  2 41 28 13]
# Plaintext :  [27 26 45 27 27 46 26 35 40]
# Plaintext :  a saat in
#
# Ciphertext :  [ 8 29 47 13 51 14 37  6 41]
# Plaintext :  [35 26 28 31 38 35 27 47 26]
# Plaintext :  i beliau
#
# Ciphertext :  [27 53 24 36 35  3 36 33 52]
# Plaintext :  [30 35 37 31 40 27 38 26 45]
# Plaintext :  dikenal s
#
# Ciphertext :  [13 19 30 21 42  5 42 26  1]
# Plaintext :  [31 28 27 33 27 35 26 45 41]
# Plaintext :  ebagai so
#
# Ciphertext :  [21 13 10 23  9 45  7 35 23]
# Plaintext :  [45 41 37 26 51 27 40 33 26]
# Plaintext :  sok yang
#
# Ciphertext :  [30 29 16  0 25 38 14 17 35]
# Plaintext :  [36 31 40 35 47 45 26 30 27]
# Plaintext :  jenius da
#
# Ciphertext :  [ 1 22 47 20 53 11 40 11 15]
# Plaintext :  [40 26 30 35 37 27 33 47 39]
# Plaintext :  n dikagum
#
# Ciphertext :  [13  2 44 10 37  2 34  3 10]
# Plaintext :  [35 26 41 38 31 34 26 30 47]
# Plaintext :  i oleh du
#
# Ciphertext :  [41 35 53  4 11  3 36 20 32]
# Plaintext :  [40 35 27 26 37 34 47 45 47]
# Plaintext :  nia khusu
#
# Ciphertext :  [32 47  6 50  4 40 13 32  8]
# Plaintext :  [45 40 51 27 26 42 27 44 27]
# Plaintext :  snya para
#
# Ciphertext :  [23 34 39 30 33 33 12 42 53]
# Plaintext :  [26 42 31 40 30 47 30 47 37]
# Plaintext :   penduduk
#
# Ciphertext :  [ 7 51 42 52 50 19 18 15 34]
# Plaintext :  [26 27 45 38 35 26  9 31 44]
# Plaintext :   asli Jer
#
# Ciphertext :  [31 38  5 49 47 27 10 14 53]
# Plaintext :  [39 27 40 26 38 34 41 55 23]
# Plaintext :  man lho.X
#
# Plain Text :  Perjuangan B.J. Habibie Saat Kuliah di Jerman Perjuangan B.J. Habibie Saat Kuliah di Jerman Ini Akan Menginspirasi Kalian Kali ini kita akan kembali dengan kisah inspiratif dari salah satu orang hebat dari Indonesia yaitu B.J. Habibie. Beliau juga memiliki kisah hidup yang patut untuk diteladani. Salah satunya adalah kisah hidup beliau saat menyelesaikan kuliah di Jerman. Kalian penasaran dengan kisah beliau? Simak ulasannya berikut ini ya! Menimba Ilmu Di Jerman Dengan Biaya Sendiri B.J. Habibie muda merupakan salah satu anak muda Indonesia yang memiliki semangat juang tinggi dalam ilmu pendidikan. Melanjutkan pendidikan di Jerman bisa dibilang sebagai salah satu keputusan hidup yang menantang dalam hidup beliau. Sebelum melanjutkan pendidikan di Jerman, sebenarnya B.J. Habibie sudah mengambil kuliah elektro di ITB selama  bulan. Namun setelahnya, beliau memutuskan untuk melanjutkan pendidikan S dan S nya di Jerman. Beliau bertekad menjadi orang yang berguna bagi bangsanya dan memiliki citacita untuk membuat pesawat terbang yang bisa membawa rakyat Indonesia ke titiktitik maritim luas di Indonesia. Tentunya beliau ingin mimpi ini diwujudkan dengan keringat rakyat bukannya biaya hasil ekspor sumber daya alam atau utang luar negeri. Berawal dari citacita mulia inilah beliau melanjutkan mimpinya di Jerman. Dalam menempuh pendidikan di Jerman, beliau tidak mendapatkan beasiswa melainkan dengan biaya sendiri dari orang tuanya. Apakah jaman dulu belum ada beasiswa, atau beliau tidak mampu mendapatkannya? Faktanya, orang tua B.J. Habibie merasa bahwa pendidikan anaknya tidak boleh dibiayai oleh orang lain. Semua biaya ditanggung oleh kedua orang tuanya meskipun mereka bukan berasal dari kalangan berada. Ibu beliau memiliki usaha catering dan koskosan. Jerih Payah B.J. Habibie Selama Kuliah Di Jerman Demi meringankan beban orang tua dalam membiayai pendidikannya, B.J. Habibie memilih untuk tinggal jauh dari pusat kota dengan tempat tinggal yang memiliki fasilitas seadanya. Bahkan beliau juga rela untuk berjalan kaki dari tempat tinggal ke kampus hanya demi menghemat biaya transportasi. Selain itu, selama menempuh S dan S di Jerman, beliau sempat dua kali dikira telah meninggal di Jerman selama masa itu. Namun jerih payah beliau akhirnya terbayar karena meskipun menjalani pendidikan dengan biaya yang terbatas, B.J. Habibie berhasil menyelesaikan pendidikan S hingga S dengan luar biasa baik. Setelah lulus S akhirnya beliau bertekad untuk bekerja sebagai asisten professor hingga beliau mendapat kesempatan untuk melanjutkan S dengan beasiswa. Tepat saat usia  tahun, B.J. Habibie resmi memperoleh gelar Doktor bidang teknologi pesawat terbang di Jerman. Usia  tahun dengan gelar Doktor bisa dibilang usia yang sangat belia. Bahkan banyak yang tidak percaya beliau merupakan lulusan S, mengingat wajah beliau yang baby face. Selama hidup di Jerman, B.J. Habibie menjadi terbiasa untuk mengatasi segala permasalahan sendiri. Bahkan, beliau juga masih menerapkan nilainilai yang sudah diajarkan orang tuanya selama di Indonesia dulu saat menjalani kehidupan di Jerman. Salah satu hal yang beliau sukai di Jerman adalah perpustakaannya. Menurut beliau, perpustakaan di Jerman buka lebih lama dan lebih bebas untuk dikunjungi. Hal ini membuat B.J. Habibie merasa memiliki kesempatan yang lebih besar dalam hal menambah wawasan dan pengetahuan selama di Jerman. Lebih dari itu, ada satu cerita lucu yang dialami beliau saat menempuh studi di Jerman. Kemampuan bahasa Jerman B.J. Habibie yang di atas ratarata untuk orang asing membuat temanteman beliau mempertanyakan keturunan dan juga asal usul beliau. Bahkan pada akhirnya beliau harus menjawab dengan candaan bahwa ayahnya kanibal pernah makan daging orang Jerman sehingga sejak saat itu beliau memiliki darah Jerman. Komitmen dan tekad beliau untuk menjadi yang terbaik dan melebihi orangorang di Jerman dalam hal pengetahuan berhasil membuat beliau diakui kemampuannya oleh dunia. Bahkan hingga saat i ...
